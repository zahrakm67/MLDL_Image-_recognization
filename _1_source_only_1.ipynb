# %% [markdown]
# # 1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.5)

# %%
from colorama import Fore
import skimage.io as io
import os
import pandas as pd
import random
# torch 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.models as models
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import math
 
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/MyDrive/domian_adoptation
# Out:
# /content/drive/MyDrive/domian_adoptation

# %%
# from  mean_and_std import get_mean_and_std
from dataloader.dataloader import CustomImageDataset ,roteted_dataset
from visualization.data_plot import plot_pic

# %% [markdown]
# # 2. parameters

# %%
# first set of parameters:
save_dir = '/content/drive/MyDrive/domian_adoptation/result/source_only' 
BATCH_size = 64
dropout = 0.5
weight_rot  = 1
learning_rate = 0.0003
moment = 0.9
W_decay = 0.05
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# second set of parameters:
# save_dir = '/content/drive/MyDrive/domian_adoptation/result/source_only_2' 
# BATCH_size = 64
# dropout = 0.5
# weight_rot  = 1
# learning_rate = 0.0001
# moment = 0.9
# W_decay = 0.05
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)


# third set of parameters:
# save_dir = '/content/drive/MyDrive/domian_adoptation/result/source_only_3' 
# BATCH_size = 64
# dropout = 0.2
# weight_rot  = 1
# learning_rate = 0.0003
# moment = 0.9
# W_decay = 0.05
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)
# Out:
# cuda:0

# %% [markdown]
# # 3. Datasets

# %%
# ! wget 'https://www.dropbox.com/s/xdy5cfu7m63pk46/?dl=1' -O \ ROD-synROD.tar
# ! rm ' ROD-synROD.tar'
# !  cp ' ROD-synROD.tar'  /content/drive/MyDrive/domian_adoptation

# %%
if not os.path.isfile('/content/ROD-synROD/ROD/rgb-washington/apple/apple_1/apple_1_1_101_crop.png'):
        print(Fore.RED, 'This might take several minuets......')
        ! tar -xf     /content/drive/MyDrive/domian_adoptation/' ROD-synROD.tar'  -C /content
       
else:
         print(Fore.CYAN, 'dataset file already exist')
# Out:
#  dataset file already exist

# %% [markdown]
# # 2.1 ROD dataset
#
#
# ---
#
#
#
# 1.   Rod without label as a trainset
# 2.   Rod with label as testset

# %%
with open("/content/ROD-synROD/ROD/wrgbd_40k-split_sync.txt") as f:
 
    lines = f.read() 
    imgs = lines.split('\n')
imgs.remove('')
print(imgs[0])

all_labels = [imgs[i].split('/')[0] for i in range(len(imgs))]
all_labels=list(set(all_labels))
labelmap ={}
for i in range(len(all_labels)):
   labelmap[all_labels[i]] =i
print('total number of labels: ',Fore.RED,len(labelmap) )
print(Fore.BLUE,labelmap)

ROD_dataset = CustomImageDataset(dt= 'ROD',annotations_list = imgs,label_map=labelmap,
                                img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                                depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]), 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                                                        
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                     
                                    
                                )

ROD_dataloader = DataLoader(ROD_dataset, batch_size= BATCH_size,shuffle=True)
# Out:
# rubber_eraser/rubber_eraser_4/rubber_eraser_4_1_136_***.png 38
# total number of labels:   47
#  {'sponge': 0, 'flashlight': 1, 'food_bag': 2, 'pliers': 3, 'cell_phone': 4, 'glue_stick': 5, 'toothbrush': 6, 'apple': 7, 'cereal_box': 8, 'banana': 9, 'keyboard': 10, 'bell_pepper': 11, 'calculator': 12, 'mushroom': 13, 'plate': 14, 'coffee_mug': 15, 'greens': 16, 'lightbulb': 17, 'food_can': 18, 'cap': 19, 'pear': 20, 'binder': 21, 'lemon': 22, 'scissors': 23, 'dry_battery': 24, 'notebook': 25, 'bowl': 26, 'comb': 27, 'stapler': 28, 'orange': 29, 'pitcher': 30, 'food_box': 31, 'toothpaste': 32, 'shampoo': 33, 'ball': 34, 'camera': 35, 'instant_noodles': 36, 'rubber_eraser': 37, 'food_jar': 38, 'marker': 39, 'soda_can': 40, 'potato': 41, 'kleenex': 42, 'garlic': 43, 'water_bottle': 44, 'hand_towel': 45, 'food_cup': 46}

# %%
# visulasioan of ROD
X  = plot_pic(ROD_dataloader,labelmap)
X.savefig('ROD')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
labelmap_rorated = {
    '0 degree' :0,
    '90 degree' :1,
    '180 degree' :2,
    '270 degree' :3

}

# %% [markdown]
# # 2.2 SynROD dataset
#
#
# ---
#
#
#
# 1.   SynROD  with label as a trainset

# %%
with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_train1.txt") as f:
    lines = f.read() 
    syn_imgs = lines.split('\n')
syn_imgs.remove('')

with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_test1.txt") as f:
    lines = f.read() 
    syn_imgs_test = lines.split('\n')
# syn_imgs.remove('')

syn_imgs_test.remove('')


syn_all_labels = [syn_imgs[i].split('/')[0] for i in range(len(syn_imgs))]
syn_all_labels=list(set(syn_all_labels))

syn_all_labels_test = [syn_imgs_test[i].split('/')[0] for i in range(len(syn_imgs_test))]
syn_all_labels_test=list(set(syn_all_labels_test))

# checking labesls oncistency 
if set(syn_all_labels) == set(syn_all_labels_test):
  print('rod and synrod labels match')
else :
  for i in syn_all_labels :
    if i not in  syn_all_labels_test:
      print(i,"exist in synrod trainset but not testset")
  for i in syn_all_labels_test :
    if i not in  syn_all_labels:
      print(i," exist in synrod testset but not trainset")

if set(syn_all_labels) == set(all_labels):
  print(' datasets labels completly match')
else:
  print('sth is wrong')
  for i in syn_all_labels :
    if i not in  all_labels:
      print(i,"does not exist in ROD")
  for i in all_labels :
    if i not in  syn_all_labels:
      print(i," does not exist in synrod")
# Out:
# rod and synrod labels match
# sth is wrong
# bell_papper does not exist in ROD
# bell_pepper  does not exist in synrod

# %%
SynROD_train = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs,label_map=labelmap,
                                  img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))

   

SynROD_test = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs_test,label_map=labelmap,img_dir ='/content/ROD-synROD/synROD',
                                 depth_dir ="/content/ROD-synROD/synROD",
         transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))





SynROD_dataloader_train = DataLoader(SynROD_train, batch_size=BATCH_size,shuffle=True)

SynROD_dataloader_test = DataLoader(SynROD_test, batch_size=BATCH_size,shuffle=True)

# %%
SynROD_rotated = roteted_dataset(dt = 'SYNROD',annotations_list = syn_imgs,
                                 img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                 
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))

SynROD_rotated_dataloader = DataLoader(SynROD_rotated, batch_size=BATCH_size,shuffle=True)

X  = plot_pic(SynROD_dataloader_train ,labelmap)
# X.savefig('SynROD')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X  = plot_pic(SynROD_rotated_dataloader ,labelmap_rorated,r =True)
# X.savefig('SynROD_rotated')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # models

# %%
# helper function
def load_cnn_model(model_name, pretrained=True):
    "Load and return a convolutional neural network."
    assert model_name in ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']
    return models.__dict__[model_name](pretrained= True)

# %%
class E(nn.Module):
    def __init__(self, model_name):
      
        super(E, self).__init__()  
        # load cnn and remove 2 last layers
        cnn = load_cnn_model(model_name)
        modules = list(cnn.children())[:-2]  # remove 2 last layers
        
        self.cnn = nn.Sequential(*modules)             
    
        
    def forward(self, x):
        x = self.cnn(x)  
              
        return x

class feature_extract(nn.Module):
    def __init__(self):
      
        super(feature_extract, self).__init__()  
        self.E_c = E(model_name ='resnet18')
        self.E_d = E(model_name ='resnet18') 
                
    def forward(self,  images, depths):
        features_c = self.E_c(images)
        features_d = self.E_d(depths)        
        X = torch.cat([features_c,features_d], dim=1 )     
              
        return X

class main_head(nn.Module):
    def __init__(self,num_classes,dropout):
      super(main_head, self).__init__() 
      self.gap = nn.AdaptiveAvgPool2d(output_size=(1, 1)) 

      self.fc1 = nn.Sequential(
          nn.Dropout(dropout),
          nn.Linear(1024, 1000),
          nn.BatchNorm1d(1000, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
      )
      self.fc2 = nn.Linear(1000, num_classes)
      self.initilise_weight()
      

    def forward(self, features):
        x = self.gap(features)
        x = torch.squeeze(x)
        x = self.fc1(x)
        x = self.fc2(x)   
        # x = F.softmax(x, dim=1)   
          
              
        return x
    
    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)


     

class pretext(nn.Module):
    def __init__(self,dropout):
      super(pretext, self).__init__() 
      self.p_conv_1x1 = nn.Sequential(
          nn.Conv2d(1024 ,100, [1,1], stride=[1,1]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
          )
      self.p_conv_3x3 = nn.Sequential(
          nn.Conv2d(100, 100, [3,3], stride=[2,2]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
          )
      self.p_fc1 = nn.Sequential(
          nn.Linear(100*3*3, 100),
          nn.BatchNorm1d(100, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
          )
      self.p_fc2 = nn.Linear(100, 4)
      self.initilise_weight()
      
     
      

    def forward(self, features):
      
        y = self.p_conv_1x1(features)
        y = self.p_conv_3x3(y)
        y = y.view(y.size(0), -1)
        y = self.p_fc1(y)
        y = self.p_fc2(y)
      
      #  y = F.softmax(y, dim=1) 
       
        return y


    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

F_model = feature_extract()

main_model =  main_head(num_classes = len(labelmap),dropout =dropout)

# pr_model =  pretext(dropout =dropout)

# %% [markdown]
# # model training

# %%
loss_fn_1 = torch.nn.CrossEntropyLoss()

optimizer1 = torch.optim.SGD(F_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
optimizer2 = torch.optim.SGD(main_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
# optimizer3 = torch.optim.SGD(pr_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)

# %%
F_model.to(device)
main_model.to(device)
# pr_model.to(device)
# Out:
# main_head(
#   (gap): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=1024, out_features=1000, bias=True)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Dropout(p=0.5, inplace=False)
#   )
#   (fc2): Linear(in_features=1000, out_features=47, bias=True)
# )

# %%
swtt_batch = math.ceil(len(syn_imgs)/BATCH_size)
def train_one_epoch(epoch_index, tb_writer):
    running_loss_1 = 0.
    last_loss_1 = 0.
    running_loss_2 = 0.
    last_loss_2 = 0.
    acc = 0
    tot = 0
    cor = 0
    acc2 = 0
    tot2 = 0
    cor2 = 0
    training_loss = 0

    # Here, we use enumerate(training_loader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for i, data in enumerate(SynROD_dataloader_train ,0):


      # Zero your gradients for every batch!
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        
       
       
        image_s,depth_s,label_s = data
        image_s,depth_s,label_s = image_s.to(device),depth_s.to(device),label_s.to(device)
        

        # Make predictions for this batch
        feat = F_model(image_s,depth_s)
        outputs = main_model(feat)
          
        

        loss_1 = loss_fn_1(outputs,label_s) 
       
       
        pr =  F.softmax(outputs, dim=1) 
        _, pr= torch.max( pr.data, 1)
        _, real= torch.max(label_s.data, 1)

        tot += label_s.size(0)
        cor += (pr ==  real).sum().item()
        acc = 100 * cor / tot    

        # image_s_r,depth_s_r,rotation_syn = next(iter(SynROD_rotated_dataloader))
             
        
        # image_s_r,depth_s_r,rotation_syn =  image_s_r.to(device),depth_s_r.to(device),rotation_syn.to(device)      
      
        # feat2 = F_model( image_s_r,depth_s_r)
       
        
        # outputs2 =pr_model( feat2 )        
        
       
        # loss_2 = loss_fn_1(outputs2,rotation_syn) 

        loss =  loss_1
        
                            
          
        loss.backward()
        running_loss = loss_1.item() 
        training_loss   +=  loss_1.item()
        optimizer1.step()
        optimizer2.step()
        # optimizer3.step()   
               

        if i % 50 == 49:
          last_loss = running_loss / 50 # loss per batch
          
          print(Fore.CYAN,'  batch {}/ {} source_train_loss: {}  and source_train_acc is {}   time is {}'.format(i + 1,swtt_batch, '%.6f' % last_loss, '%.4f'% acc,'%.2f' %(time.time() - start_time)))
          
          running_loss = 0.
         
        
    
   
    # model_name = F_model.module._get_name() if isinstance(F_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': F_model.state_dict(),
    #               'optimizer_state_dict': optimizer1.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = main_model.module._get_name() if isinstance(main_model, torch.nn.DataParallel) else main_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': main_model.state_dict(),
    #               'optimizer_state_dict': optimizer2.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = pr_model.module._get_name() if isinstance(pr_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint2 = {'epoch':epoch,
    #               'model_state_dict': pr_model.state_dict(),
    #               'optimizer_state_dict': optimizer3.state_dict(),
    #                'loss':  loss
                   
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint2,fpath)
    



    return  training_loss/(i + 1),acc

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('runs/ROD_{}'.format(timestamp))
epoch_number = 0
import time
start_time = time.time()

EPOCHS = 20
best_vloss = 1_000_000.

source_train_loss =[]
source_train_accuracy =[]

source_test_loss =[]
source_test_accuracy =[]



target_test_loss = []
target_test_accuracy =[]


for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    F_model.train(True)
    main_model.train(True)
   
   

    avg_loss, test_acc= train_one_epoch(epoch_number, writer)
    source_train_loss.append(avg_loss)
    source_train_accuracy.append(test_acc)

    # We don't need gradients on to do reporting
    F_model.train(False)
    main_model.train(False)

    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(SynROD_dataloader_test ):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    source_test_loss.append(avg_vloss)
    source_test_accuracy.append(accuracy)


    print(Fore.GREEN,'for main taks,loss source_test {},..... acc source_test {}'.format(avg_vloss, accuracy))   
   

    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(ROD_dataloader):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    target_test_loss.append(avg_vloss)
    target_test_accuracy.append(accuracy)

    print(Fore.RED,'for main taks, loss target_test {} , .... acc target_test {}'.format( avg_vloss, accuracy))
    
    E= [i for i in range(len(target_test_loss))]

    fig, (axs, ax2) = plt.subplots(2)
    t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
    s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]

    axs.plot(E, t_target_loss,label="target")
    axs.plot(E,s_test_loss,label="source_test")
    
    axs.set_xlabel('epoch')
    axs.set_ylabel('loss')
    axs.grid(True)

    # t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
    # s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]

    ax2.plot(E, target_test_accuracy,label="target" )
    ax2.plot(E,source_test_accuracy,label="source_test")

    
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('accuracy')
    ax2.grid(True)

    fig.tight_layout()
   
    plt.savefig('source_only.png')
  

    # Track best performance, and save the model's state
    # if avg_vloss < best_vloss:
    #     best_vloss = avg_vloss
    #     F_model_path = 'result/source_only_2/F_model_{}_{}'.format(timestamp, epoch_number)
    #     torch.save(F_model.state_dict(), F_model_path)

    #     M_model_path = 'result/source_only_2/main_model_{}_{}'.format(timestamp, epoch_number)
    #     torch.save(main_model.state_dict(), M_model_path)

    #     Fr_model_path = 'result/source_only_2/pr_model_{}_{}'.format(timestamp, epoch_number)
    #     torch.save(pr_model.state_dict(),Fr_model_path)

   



      

    epoch_number += 1
# Out:
# EPOCH 1:
#    batch 50/ 586 source_train_loss: 0.076927  and source_train_acc is 2.7500   time is 44.66
#    batch 100/ 586 source_train_loss: 0.075993  and source_train_acc is 3.3906   time is 87.35
#    batch 150/ 586 source_train_loss: 0.074491  and source_train_acc is 4.8438   time is 129.50
#    batch 200/ 586 source_train_loss: 0.070757  and source_train_acc is 6.4688   time is 174.25
#    batch 250/ 586 source_train_loss: 0.070152  and source_train_acc is 8.2500   time is 217.69
#    batch 300/ 586 source_train_loss: 0.069133  and source_train_acc is 10.1094   time is 262.53
#    batch 350/ 586 source_train_loss: 0.065695  and source_train_acc is 12.2768   time is 307.44
#    batch 400/ 586 source_train_loss: 0.065905  and source_train_acc is 14.4688   time is 353.01
#    batch 450/ 586 source_train_loss: 0.063432  and source_train_acc is 16.5625   time is 397.91
#    batch 500/ 586 source_train_loss: 0.059988  and source_train_acc is 18.4500   time is 442.50
#    batch 550/ 586 source_train_loss: 0.060511  and source_train_acc is 20.3097   time is 486.84
#  for main taks,loss source_test 2.933349609375,..... acc source_test 43.92049348869089
#  for main taks, loss target_test 3.289489269256592 , .... acc target_test 27.518783101367163
# EPOCH 2:
#    batch 50/ 586 source_train_loss: 0.055279  and source_train_acc is 44.5625   time is 950.73
#    batch 100/ 586 source_train_loss: 0.054366  and source_train_acc is 45.2656   time is 997.59
#    batch 150/ 586 source_train_loss: 0.049830  and source_train_acc is 46.0729   time is 1043.19
#    batch 200/ 586 source_train_loss: 0.046587  and source_train_acc is 47.2500   time is 1089.20
#    batch 250/ 586 source_train_loss: 0.048368  and source_train_acc is 48.1500   time is 1133.83
#    batch 300/ 586 source_train_loss: 0.045503  and source_train_acc is 49.0521   time is 1178.12
#    batch 350/ 586 source_train_loss: 0.042973  and source_train_acc is 49.8705   time is 1222.90
#    batch 400/ 586 source_train_loss: 0.043795  and source_train_acc is 50.6992   time is 1266.65
#    batch 450/ 586 source_train_loss: 0.039761  and source_train_acc is 51.5833   time is 1310.47
#    batch 500/ 586 source_train_loss: 0.044049  and source_train_acc is 52.2281   time is 1354.40
#    batch 550/ 586 source_train_loss: 0.042484  and source_train_acc is 52.9545   time is 1399.36
#  for main taks,loss source_test 2.144214630126953,..... acc source_test 54.17409184372858
#  for main taks, loss target_test 2.7975852489471436 , .... acc target_test 36.18364330582584
# EPOCH 3:
#    batch 50/ 586 source_train_loss: 0.037843  and source_train_acc is 61.4688   time is 1862.57
#    batch 100/ 586 source_train_loss: 0.040892  and source_train_acc is 62.1406   time is 1909.56
#    batch 150/ 586 source_train_loss: 0.032048  and source_train_acc is 63.3646   time is 1956.12
#    batch 200/ 586 source_train_loss: 0.039559  and source_train_acc is 64.3750   time is 2001.12
#    batch 250/ 586 source_train_loss: 0.034926  and source_train_acc is 64.7313   time is 2045.61
#    batch 300/ 586 source_train_loss: 0.031000  and source_train_acc is 65.2812   time is 2090.42
#    batch 350/ 586 source_train_loss: 0.031701  and source_train_acc is 65.8036   time is 2134.41
#    batch 400/ 586 source_train_loss: 0.032557  and source_train_acc is 66.2461   time is 2178.97
#    batch 450/ 586 source_train_loss: 0.032539  and source_train_acc is 66.7083   time is 2224.59
#    batch 500/ 586 source_train_loss: 0.029342  and source_train_acc is 67.0781   time is 2268.25
#    batch 550/ 586 source_train_loss: 0.033345  and source_train_acc is 67.4034   time is 2312.08
#  for main taks,loss source_test 1.7384791374206543,..... acc source_test 61.6860863605209
#  for main taks, loss target_test 2.566181182861328 , .... acc target_test 39.45682965882498
# EPOCH 4:
#    batch 50/ 586 source_train_loss: 0.027368  and source_train_acc is 71.8125   time is 2772.74
#    batch 100/ 586 source_train_loss: 0.025915  and source_train_acc is 71.8906   time is 2819.94
#    batch 150/ 586 source_train_loss: 0.025218  and source_train_acc is 71.8438   time is 2865.49
#    batch 200/ 586 source_train_loss: 0.026159  and source_train_acc is 72.7109   time is 2910.37
#    batch 250/ 586 source_train_loss: 0.023377  and source_train_acc is 73.0062   time is 2955.46
#    batch 300/ 586 source_train_loss: 0.025149  and source_train_acc is 73.3646   time is 2998.94
#    batch 350/ 586 source_train_loss: 0.028087  and source_train_acc is 73.8036   time is 3044.48
#    batch 400/ 586 source_train_loss: 0.025931  and source_train_acc is 74.0391   time is 3089.55
#    batch 450/ 586 source_train_loss: 0.026551  and source_train_acc is 74.4514   time is 3133.95
#    batch 500/ 586 source_train_loss: 0.024432  and source_train_acc is 74.5875   time is 3178.33
#    batch 550/ 586 source_train_loss: 0.020658  and source_train_acc is 74.7756   time is 3221.91
#  for main taks,loss source_test 1.5502578020095825,..... acc source_test 65.14050719671008
#  for main taks, loss target_test 2.485605478286743 , .... acc target_test 39.681611035841854
# EPOCH 5:
#    batch 50/ 586 source_train_loss: 0.022493  and source_train_acc is 78.2188   time is 3681.94
#    batch 100/ 586 source_train_loss: 0.025990  and source_train_acc is 78.7969   time is 3728.56
#    batch 150/ 586 source_train_loss: 0.022677  and source_train_acc is 77.9896   time is 3773.93
#    batch 200/ 586 source_train_loss: 0.023212  and source_train_acc is 78.4062   time is 3818.19
#    batch 250/ 586 source_train_loss: 0.024124  and source_train_acc is 78.5187   time is 3862.80
#    batch 300/ 586 source_train_loss: 0.022313  and source_train_acc is 78.6458   time is 3906.90
#    batch 350/ 586 source_train_loss: 0.019549  and source_train_acc is 78.9509   time is 3950.41
#    batch 400/ 586 source_train_loss: 0.019701  and source_train_acc is 79.1211   time is 3994.40
#    batch 450/ 586 source_train_loss: 0.023514  and source_train_acc is 79.2951   time is 4038.57
#    batch 500/ 586 source_train_loss: 0.022465  and source_train_acc is 79.4469   time is 4083.12
#    batch 550/ 586 source_train_loss: 0.022899  and source_train_acc is 79.5455   time is 4126.84
#  for main taks,loss source_test 1.4384061098098755,..... acc source_test 67.12816997943797
#  for main taks, loss target_test 2.5189783573150635 , .... acc target_test 38.123537381450916
# EPOCH 6:
#    batch 50/ 586 source_train_loss: 0.017918  and source_train_acc is 82.3125   time is 4585.79
#    batch 100/ 586 source_train_loss: 0.020105  and source_train_acc is 82.1562   time is 4632.58
#    batch 150/ 586 source_train_loss: 0.021488  and source_train_acc is 81.8854   time is 4678.96
#    batch 200/ 586 source_train_loss: 0.019100  and source_train_acc is 82.0391   time is 4723.50
#    batch 250/ 586 source_train_loss: 0.017930  and source_train_acc is 81.9875   time is 4767.86
#    batch 300/ 586 source_train_loss: 0.017313  and source_train_acc is 82.1667   time is 4811.66
#    batch 350/ 586 source_train_loss: 0.019167  and source_train_acc is 82.3527   time is 4856.93
#    batch 400/ 586 source_train_loss: 0.018665  and source_train_acc is 82.4141   time is 4901.53
#    batch 450/ 586 source_train_loss: 0.016999  and source_train_acc is 82.7535   time is 4946.05
#    batch 500/ 586 source_train_loss: 0.023236  and source_train_acc is 82.7438   time is 4989.95
#    batch 550/ 586 source_train_loss: 0.017968  and source_train_acc is 82.9006   time is 5033.71
#  for main taks,loss source_test 1.391159176826477,..... acc source_test 67.854694996573
#  for main taks, loss target_test 2.6231894493103027 , .... acc target_test 34.006651065402146
# EPOCH 7:
#    batch 50/ 586 source_train_loss: 0.018189  and source_train_acc is 86.2812   time is 5493.92
#    batch 100/ 586 source_train_loss: 0.020080  and source_train_acc is 85.5938   time is 5540.69
#    batch 150/ 586 source_train_loss: 0.018307  and source_train_acc is 85.5833   time is 5586.22
#    batch 200/ 586 source_train_loss: 0.023176  and source_train_acc is 85.5156   time is 5631.15
#    batch 250/ 586 source_train_loss: 0.017327  and source_train_acc is 85.4813   time is 5675.71
#    batch 300/ 586 source_train_loss: 0.019341  and source_train_acc is 85.4688   time is 5719.95
#    batch 350/ 586 source_train_loss: 0.016024  and source_train_acc is 85.5714   time is 5764.09
#    batch 400/ 586 source_train_loss: 0.020303  and source_train_acc is 85.5273   time is 5807.95
#    batch 450/ 586 source_train_loss: 0.015218  and source_train_acc is 85.5868   time is 5851.87
#    batch 500/ 586 source_train_loss: 0.018951  and source_train_acc is 85.5875   time is 5895.86
#    batch 550/ 586 source_train_loss: 0.017433  and source_train_acc is 85.7301   time is 5940.09
#  for main taks,loss source_test 1.3564146757125854,..... acc source_test 69.17066483893078
#  for main taks, loss target_test 2.7014524936676025 , .... acc target_test 32.380835078211604
# EPOCH 8:
#    batch 50/ 586 source_train_loss: 0.021273  and source_train_acc is 86.9688   time is 6398.78
#    batch 100/ 586 source_train_loss: 0.012517  and source_train_acc is 87.3906   time is 6445.54
#    batch 150/ 586 source_train_loss: 0.014697  and source_train_acc is 87.5208   time is 6491.75
#    batch 200/ 586 source_train_loss: 0.018562  and source_train_acc is 87.6406   time is 6537.01
#    batch 250/ 586 source_train_loss: 0.020749  and source_train_acc is 87.5500   time is 6583.36
#    batch 300/ 586 source_train_loss: 0.013728  and source_train_acc is 87.5885   time is 6627.28
#    batch 350/ 586 source_train_loss: 0.016490  and source_train_acc is 87.5402   time is 6671.58
#    batch 400/ 586 source_train_loss: 0.015029  and source_train_acc is 87.5625   time is 6715.66
#    batch 450/ 586 source_train_loss: 0.015965  and source_train_acc is 87.6424   time is 6759.44
#    batch 500/ 586 source_train_loss: 0.018539  and source_train_acc is 87.6750   time is 6804.06
#    batch 550/ 586 source_train_loss: 0.017911  and source_train_acc is 87.8210   time is 6847.69
#  for main taks,loss source_test 1.333020806312561,..... acc source_test 69.97943797121316
#  for main taks, loss target_test 2.8184006214141846 , .... acc target_test 28.842837787904916
# EPOCH 9:
#    batch 50/ 586 source_train_loss: 0.016101  and source_train_acc is 88.7188   time is 7306.81
#    batch 100/ 586 source_train_loss: 0.012980  and source_train_acc is 88.6562   time is 7352.87
#    batch 150/ 586 source_train_loss: 0.017249  and source_train_acc is 88.7083   time is 7398.25
#    batch 200/ 586 source_train_loss: 0.016324  and source_train_acc is 88.9375   time is 7443.40
#    batch 250/ 586 source_train_loss: 0.013266  and source_train_acc is 89.0625   time is 7487.83
#    batch 300/ 586 source_train_loss: 0.016627  and source_train_acc is 89.1094   time is 7532.30
#    batch 350/ 586 source_train_loss: 0.013491  and source_train_acc is 89.2098   time is 7576.13
#    batch 400/ 586 source_train_loss: 0.012765  and source_train_acc is 89.2734   time is 7620.68
#    batch 450/ 586 source_train_loss: 0.015140  and source_train_acc is 89.3681   time is 7664.93
#    batch 500/ 586 source_train_loss: 0.013497  and source_train_acc is 89.4000   time is 7710.20
#    batch 550/ 586 source_train_loss: 0.015517  and source_train_acc is 89.3949   time is 7753.95
#  for main taks,loss source_test 1.3521649837493896,..... acc source_test 69.45853324194654
#  for main taks, loss target_test 2.8854479789733887 , .... acc target_test 28.263948762162826
# EPOCH 10:
#    batch 50/ 586 source_train_loss: 0.014345  and source_train_acc is 90.0625   time is 8214.20
#    batch 100/ 586 source_train_loss: 0.016642  and source_train_acc is 90.2812   time is 8261.75
#    batch 150/ 586 source_train_loss: 0.013194  and source_train_acc is 90.4375   time is 8309.25
#    batch 200/ 586 source_train_loss: 0.015333  and source_train_acc is 90.7031   time is 8354.63
#    batch 250/ 586 source_train_loss: 0.014704  and source_train_acc is 90.8250   time is 8398.67
#    batch 300/ 586 source_train_loss: 0.018698  and source_train_acc is 90.9062   time is 8442.90
#    batch 350/ 586 source_train_loss: 0.014119  and source_train_acc is 90.9911   time is 8486.42
#    batch 400/ 586 source_train_loss: 0.014077  and source_train_acc is 91.0977   time is 8530.22
#    batch 450/ 586 source_train_loss: 0.013505  and source_train_acc is 91.1389   time is 8574.02
#    batch 500/ 586 source_train_loss: 0.019660  and source_train_acc is 91.2062   time is 8618.12
#    batch 550/ 586 source_train_loss: 0.013241  and source_train_acc is 91.1193   time is 8661.94
#  for main taks,loss source_test 1.3586838245391846,..... acc source_test 70.22618231665524
#  for main taks, loss target_test 2.975877523422241 , .... acc target_test 25.35410764872521
# EPOCH 11:
#    batch 50/ 586 source_train_loss: 0.014291  and source_train_acc is 92.9062   time is 9126.92
#    batch 100/ 586 source_train_loss: 0.011458  and source_train_acc is 92.6562   time is 9174.12
#    batch 150/ 586 source_train_loss: 0.017484  and source_train_acc is 92.5625   time is 9220.53
#    batch 200/ 586 source_train_loss: 0.011695  and source_train_acc is 92.5234   time is 9265.87
#    batch 250/ 586 source_train_loss: 0.014816  and source_train_acc is 92.4062   time is 9310.88
#    batch 300/ 586 source_train_loss: 0.013506  and source_train_acc is 92.4635   time is 9355.35
#    batch 350/ 586 source_train_loss: 0.012732  and source_train_acc is 92.5000   time is 9399.39
#    batch 400/ 586 source_train_loss: 0.013955  and source_train_acc is 92.4727   time is 9445.16
#    batch 450/ 586 source_train_loss: 0.013014  and source_train_acc is 92.4688   time is 9489.13
#    batch 500/ 586 source_train_loss: 0.011553  and source_train_acc is 92.4594   time is 9534.01
#    batch 550/ 586 source_train_loss: 0.013009  and source_train_acc is 92.4347   time is 9578.65
#  for main taks,loss source_test 1.3908745050430298,..... acc source_test 70.58259081562714
#  for main taks, loss target_test 3.0027496814727783 , .... acc target_test 25.65894814632344
# EPOCH 12:
#    batch 50/ 586 source_train_loss: 0.015159  and source_train_acc is 93.5000   time is 10043.41
#    batch 100/ 586 source_train_loss: 0.014204  and source_train_acc is 93.2812   time is 10090.92
#    batch 150/ 586 source_train_loss: 0.013494  and source_train_acc is 93.3125   time is 10136.62
#    batch 200/ 586 source_train_loss: 0.011946  and source_train_acc is 93.4141   time is 10181.82
#    batch 250/ 586 source_train_loss: 0.013661  and source_train_acc is 93.5563   time is 10226.77
#    batch 300/ 586 source_train_loss: 0.013469  and source_train_acc is 93.6198   time is 10270.59
#    batch 350/ 586 source_train_loss: 0.014942  and source_train_acc is 93.5580   time is 10315.30
#    batch 400/ 586 source_train_loss: 0.015778  and source_train_acc is 93.5078   time is 10359.77
#    batch 450/ 586 source_train_loss: 0.012256  and source_train_acc is 93.4410   time is 10404.02
#    batch 500/ 586 source_train_loss: 0.015390  and source_train_acc is 93.4906   time is 10448.12
#    batch 550/ 586 source_train_loss: 0.014162  and source_train_acc is 93.4688   time is 10492.19
#  for main taks,loss source_test 1.4156171083450317,..... acc source_test 70.56888279643591
#  for main taks, loss target_test 3.086231231689453 , .... acc target_test 23.700578889025742
# EPOCH 13:
#    batch 50/ 586 source_train_loss: 0.015764  and source_train_acc is 94.7500   time is 10953.58
#    batch 100/ 586 source_train_loss: 0.012041  and source_train_acc is 94.4062   time is 11000.54
#    batch 150/ 586 source_train_loss: 0.011647  and source_train_acc is 94.6771   time is 11046.88
#    batch 200/ 586 source_train_loss: 0.012413  and source_train_acc is 94.6328   time is 11091.61
#    batch 250/ 586 source_train_loss: 0.015653  and source_train_acc is 94.6562   time is 11136.11
#    batch 300/ 586 source_train_loss: 0.011609  and source_train_acc is 94.7917   time is 11180.54
#    batch 350/ 586 source_train_loss: 0.012828  and source_train_acc is 94.6696   time is 11226.03
#    batch 400/ 586 source_train_loss: 0.010339  and source_train_acc is 94.5938   time is 11270.51
#    batch 450/ 586 source_train_loss: 0.012259  and source_train_acc is 94.5799   time is 11314.61
#    batch 500/ 586 source_train_loss: 0.012978  and source_train_acc is 94.5406   time is 11358.59
#    batch 550/ 586 source_train_loss: 0.012277  and source_train_acc is 94.5739   time is 11403.24
#  for main taks,loss source_test 1.4495460987091064,..... acc source_test 70.07539410555175
#  for main taks, loss target_test 3.1195225715637207 , .... acc target_test 21.8561399187092
# EPOCH 14:
#    batch 50/ 586 source_train_loss: 0.011642  and source_train_acc is 95.5625   time is 11865.56
#    batch 100/ 586 source_train_loss: 0.012562  and source_train_acc is 95.0312   time is 11912.56
#    batch 150/ 586 source_train_loss: 0.012958  and source_train_acc is 95.2500   time is 11958.60
#    batch 200/ 586 source_train_loss: 0.013331  and source_train_acc is 95.1641   time is 12003.33
#    batch 250/ 586 source_train_loss: 0.013811  and source_train_acc is 95.3500   time is 12047.49
#    batch 300/ 586 source_train_loss: 0.013263  and source_train_acc is 95.1615   time is 12091.68
#    batch 350/ 586 source_train_loss: 0.012937  and source_train_acc is 95.1562   time is 12135.03
#    batch 400/ 586 source_train_loss: 0.011155  and source_train_acc is 95.1797   time is 12178.26
#    batch 450/ 586 source_train_loss: 0.013147  and source_train_acc is 95.1875   time is 12222.65
#    batch 500/ 586 source_train_loss: 0.012477  and source_train_acc is 95.2594   time is 12266.40
#    batch 550/ 586 source_train_loss: 0.010415  and source_train_acc is 95.3125   time is 12310.73
#  for main taks,loss source_test 1.5126209259033203,..... acc source_test 69.66415352981494
#  for main taks, loss target_test 3.194727659225464 , .... acc target_test 21.33575563493041
# EPOCH 15:
#    batch 50/ 586 source_train_loss: 0.012817  and source_train_acc is 96.6875   time is 12766.32
#    batch 100/ 586 source_train_loss: 0.013597  and source_train_acc is 96.4531   time is 12813.32
#    batch 150/ 586 source_train_loss: 0.010947  and source_train_acc is 96.4896   time is 12858.55
#    batch 200/ 586 source_train_loss: 0.012778  and source_train_acc is 96.3750   time is 12903.88
#    batch 250/ 586 source_train_loss: 0.010949  and source_train_acc is 96.3812   time is 12947.86
#    batch 300/ 586 source_train_loss: 0.013740  and source_train_acc is 96.3698   time is 12992.67
#    batch 350/ 586 source_train_loss: 0.013533  and source_train_acc is 96.3304   time is 13037.06
#    batch 400/ 586 source_train_loss: 0.011909  and source_train_acc is 96.2773   time is 13080.67
#    batch 450/ 586 source_train_loss: 0.012018  and source_train_acc is 96.2222   time is 13124.83
#    batch 500/ 586 source_train_loss: 0.010893  and source_train_acc is 96.2344   time is 13168.41
#    batch 550/ 586 source_train_loss: 0.012585  and source_train_acc is 96.2159   time is 13212.09
#  for main taks,loss source_test 1.5500963926315308,..... acc source_test 69.32145305003426
#  for main taks, loss target_test 3.194025993347168 , .... acc target_test 21.87461510038182
# EPOCH 16:
#    batch 50/ 586 source_train_loss: 0.012969  and source_train_acc is 97.2188   time is 13666.67
#    batch 100/ 586 source_train_loss: 0.014007  and source_train_acc is 97.0938   time is 13712.73
#    batch 150/ 586 source_train_loss: 0.011646  and source_train_acc is 97.1562   time is 13758.65
#    batch 200/ 586 source_train_loss: 0.011575  and source_train_acc is 97.1094   time is 13803.85
#    batch 250/ 586 source_train_loss: 0.011828  and source_train_acc is 96.9875   time is 13847.94
#    batch 300/ 586 source_train_loss: 0.011703  and source_train_acc is 97.0156   time is 13892.41
#    batch 350/ 586 source_train_loss: 0.013263  and source_train_acc is 97.0268   time is 13937.14
#    batch 400/ 586 source_train_loss: 0.012242  and source_train_acc is 97.0625   time is 13981.10
#    batch 450/ 586 source_train_loss: 0.010846  and source_train_acc is 97.0139   time is 14025.33
#    batch 500/ 586 source_train_loss: 0.014057  and source_train_acc is 97.0375   time is 14070.41
#    batch 550/ 586 source_train_loss: 0.012532  and source_train_acc is 96.9886   time is 14114.51
#  for main taks,loss source_test 1.5940691232681274,..... acc source_test 68.91021247429747
#  for main taks, loss target_test 3.270498275756836 , .... acc target_test 18.398201748983865
# EPOCH 17:
#    batch 50/ 586 source_train_loss: 0.010560  and source_train_acc is 97.8125   time is 14571.92
#    batch 100/ 586 source_train_loss: 0.011381  and source_train_acc is 97.8750   time is 14618.15
#    batch 150/ 586 source_train_loss: 0.012921  and source_train_acc is 97.9062   time is 14663.36
#    batch 200/ 586 source_train_loss: 0.012285  and source_train_acc is 97.8438   time is 14707.91
#    batch 250/ 586 source_train_loss: 0.011750  and source_train_acc is 97.8063   time is 14752.19
#    batch 300/ 586 source_train_loss: 0.011509  and source_train_acc is 97.8177   time is 14796.76
#    batch 350/ 586 source_train_loss: 0.012212  and source_train_acc is 97.8393   time is 14840.49
#    batch 400/ 586 source_train_loss: 0.012122  and source_train_acc is 97.8008   time is 14884.71
#    batch 450/ 586 source_train_loss: 0.010953  and source_train_acc is 97.7396   time is 14929.21
#    batch 500/ 586 source_train_loss: 0.013807  and source_train_acc is 97.7094   time is 14973.32
#    batch 550/ 586 source_train_loss: 0.014289  and source_train_acc is 97.6278   time is 15016.52
#  for main taks,loss source_test 1.6555991172790527,..... acc source_test 67.71761480466073
#  for main taks, loss target_test 3.2416646480560303 , .... acc target_test 19.43589111959601
# EPOCH 18:
#    batch 50/ 586 source_train_loss: 0.012797  and source_train_acc is 98.3438   time is 15471.91
#    batch 100/ 586 source_train_loss: 0.012694  and source_train_acc is 98.2656   time is 15518.21
#    batch 150/ 586 source_train_loss: 0.011090  and source_train_acc is 98.3333   time is 15565.14
#    batch 200/ 586 source_train_loss: 0.012913  and source_train_acc is 98.2734   time is 15611.94
#    batch 250/ 586 source_train_loss: 0.010270  and source_train_acc is 98.2250   time is 15655.99
#    batch 300/ 586 source_train_loss: 0.012973  and source_train_acc is 98.1927   time is 15701.38
#    batch 350/ 586 source_train_loss: 0.012519  and source_train_acc is 98.1384   time is 15746.49
#    batch 400/ 586 source_train_loss: 0.013402  and source_train_acc is 98.1523   time is 15791.50
#    batch 450/ 586 source_train_loss: 0.011357  and source_train_acc is 98.1528   time is 15835.93
#    batch 500/ 586 source_train_loss: 0.013318  and source_train_acc is 98.0750   time is 15879.91
#    batch 550/ 586 source_train_loss: 0.012978  and source_train_acc is 98.0625   time is 15923.43
#  for main taks,loss source_test 1.638396143913269,..... acc source_test 69.52707333790268
#  for main taks, loss target_test 3.2954506874084473 , .... acc target_test 19.201872151742826
# EPOCH 19:
#    batch 50/ 586 source_train_loss: 0.011413  and source_train_acc is 98.8125   time is 16380.43
#    batch 100/ 586 source_train_loss: 0.012277  and source_train_acc is 98.6250   time is 16426.90
#    batch 150/ 586 source_train_loss: 0.013017  and source_train_acc is 98.5729   time is 16472.67
#    batch 200/ 586 source_train_loss: 0.011864  and source_train_acc is 98.6172   time is 16518.22
#    batch 250/ 586 source_train_loss: 0.011546  and source_train_acc is 98.6188   time is 16563.10
#    batch 300/ 586 source_train_loss: 0.014088  and source_train_acc is 98.5573   time is 16609.29
#    batch 350/ 586 source_train_loss: 0.014494  and source_train_acc is 98.5268   time is 16654.49
#    batch 400/ 586 source_train_loss: 0.012117  and source_train_acc is 98.5039   time is 16699.08
#    batch 450/ 586 source_train_loss: 0.013208  and source_train_acc is 98.5069   time is 16743.37
#    batch 500/ 586 source_train_loss: 0.013388  and source_train_acc is 98.4594   time is 16787.64
#    batch 550/ 586 source_train_loss: 0.015705  and source_train_acc is 98.4574   time is 16832.21
#  for main taks,loss source_test 1.687296748161316,..... acc source_test 68.89650445510624
#  for main taks, loss target_test 3.3389651775360107 , .... acc target_test 18.456706490947163
# EPOCH 20:
#    batch 50/ 586 source_train_loss: 0.012993  and source_train_acc is 98.9062   time is 17290.56
#    batch 100/ 586 source_train_loss: 0.011597  and source_train_acc is 98.8125   time is 17337.43
#    batch 150/ 586 source_train_loss: 0.014093  and source_train_acc is 98.7917   time is 17382.94
#    batch 200/ 586 source_train_loss: 0.011199  and source_train_acc is 98.7969   time is 17427.81
#    batch 250/ 586 source_train_loss: 0.011419  and source_train_acc is 98.7750   time is 17473.13
#    batch 300/ 586 source_train_loss: 0.014070  and source_train_acc is 98.7865   time is 17518.00
#    batch 350/ 586 source_train_loss: 0.012933  and source_train_acc is 98.7634   time is 17562.72
#    batch 400/ 586 source_train_loss: 0.011054  and source_train_acc is 98.7305   time is 17608.33
#    batch 450/ 586 source_train_loss: 0.013492  and source_train_acc is 98.7188   time is 17653.14
#    batch 500/ 586 source_train_loss: 0.013376  and source_train_acc is 98.6844   time is 17697.03
#    batch 550/ 586 source_train_loss: 0.013248  and source_train_acc is 98.6250   time is 17741.26
#  for main taks,loss source_test 1.7258886098861694,..... acc source_test 67.62165867032213
#  for main taks, loss target_test 3.258495330810547 , .... acc target_test 20.119472841482942
