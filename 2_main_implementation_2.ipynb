# %% [markdown]
# # 1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.5

# %%
from colorama import Fore
import skimage.io as io
import os
import pandas as pd
import random
# torch 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.models as models
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import math
 
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/MyDrive/domian_adoptation
# Out:
# /content/drive/MyDrive/domian_adoptation

# %%
# from  mean_and_std import get_mean_and_std
from dataloader.dataloader import CustomImageDataset ,roteted_dataset
from visualization.data_plot import plot_pic

# %% [markdown]
# # 2. parameters

# %%
# save_dir = '/content/drive/MyDrive/domian_adoptation/result' 

# weight_rot = 1
# weight_ent = 0.1
# BATCH_size = 64
# learning_rate = 0.0003
# moment = 0.9
# W_decay = 0.05
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)
# dropout =0.5

save_dir = '/content/drive/MyDrive/domian_adoptation/result' 

weight_rot = 2
weight_ent = 0.1
BATCH_size = 64
learning_rate = 0.0003
moment = 0.9
W_decay = 0.04
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
dropout =0.5
# Out:
# cuda:0

# %% [markdown]
# # 3. Datasets

# %%
# ! wget 'https://www.dropbox.com/s/xdy5cfu7m63pk46/?dl=1' -O \ ROD-synROD.tar
# ! rm ' ROD-synROD.tar'
# !  cp ' ROD-synROD.tar'  /content/drive/MyDrive/domian_adoptation

# %%
if not os.path.isfile('/content/ROD-synROD/ROD/rgb-washington/apple/apple_1/apple_1_1_101_crop.png'):
        print(Fore.RED, 'This might take several minuets......')
        ! tar -xf     /content/drive/MyDrive/domian_adoptation/' ROD-synROD.tar'  -C /content
       
else:
         print(Fore.CYAN, 'dataset file already exist')
# Out:
#  This might take several minuets......

# %% [markdown]
# # 2.1 ROD dataset
#
#
# ---
#
#
#
# 1.   Rod without label as a trainset
# 2.   Rod with label as testset

# %%
with open("/content/ROD-synROD/ROD/wrgbd_40k-split_sync.txt") as f:
 
    lines = f.read() 
    imgs = lines.split('\n')
imgs.remove('')
print(imgs[0])

all_labels = [imgs[i].split('/')[0] for i in range(len(imgs))]
all_labels=list(set(all_labels))
labelmap ={}
for i in range(len(all_labels)):
   labelmap[all_labels[i]] =i
print('total number of labels: ',Fore.RED,len(labelmap) )
print(Fore.BLUE,labelmap)

ROD_dataset = CustomImageDataset(dt= 'ROD',annotations_list = imgs,label_map=labelmap,
                                img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                                depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]), 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                                                        
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                     
                                    
                                )

ROD_dataloader = DataLoader(ROD_dataset, batch_size= BATCH_size,shuffle=True)
# Out:
# rubber_eraser/rubber_eraser_4/rubber_eraser_4_1_136_***.png 38
# total number of labels:   47
#  {'instant_noodles': 0, 'pliers': 1, 'orange': 2, 'plate': 3, 'camera': 4, 'food_box': 5, 'bowl': 6, 'food_can': 7, 'coffee_mug': 8, 'garlic': 9, 'notebook': 10, 'scissors': 11, 'apple': 12, 'keyboard': 13, 'shampoo': 14, 'comb': 15, 'pear': 16, 'banana': 17, 'cap': 18, 'calculator': 19, 'hand_towel': 20, 'soda_can': 21, 'food_jar': 22, 'mushroom': 23, 'toothpaste': 24, 'cell_phone': 25, 'glue_stick': 26, 'kleenex': 27, 'cereal_box': 28, 'food_bag': 29, 'binder': 30, 'marker': 31, 'potato': 32, 'bell_pepper': 33, 'stapler': 34, 'greens': 35, 'rubber_eraser': 36, 'sponge': 37, 'water_bottle': 38, 'pitcher': 39, 'dry_battery': 40, 'lemon': 41, 'flashlight': 42, 'food_cup': 43, 'ball': 44, 'toothbrush': 45, 'lightbulb': 46}

# %%
# visulasioan of ROD
X  = plot_pic(ROD_dataloader,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ROD_rotated = roteted_dataset(dt= 'ROD',annotations_list = imgs,
                               img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                               depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),                                
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                             
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                           )

ROD_rotated_dataloader = DataLoader(ROD_rotated, batch_size = BATCH_size,shuffle=True)

labelmap_rorated = {
    '0 degree' :0,
    '90 degree' :1,
    '180 degree' :2,
    '270 degree' :3

}

# %%
X  = plot_pic(ROD_rotated_dataloader ,labelmap_rorated,r =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2.2 SynROD dataset
#
#
# ---
#
#
#
# 1.   SynROD  with label as a trainset

# %%
with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_train1.txt") as f:
    lines = f.read() 
    syn_imgs = lines.split('\n')
syn_imgs.remove('')

with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_test1.txt") as f:
    lines = f.read() 
    syn_imgs_test = lines.split('\n')
# syn_imgs.remove('')

syn_imgs_test.remove('')


syn_all_labels = [syn_imgs[i].split('/')[0] for i in range(len(syn_imgs))]
syn_all_labels=list(set(syn_all_labels))

syn_all_labels_test = [syn_imgs_test[i].split('/')[0] for i in range(len(syn_imgs_test))]
syn_all_labels_test=list(set(syn_all_labels_test))

# checking labesls oncistency 
if set(syn_all_labels) == set(syn_all_labels_test):
  print('rod and synrod labels match')
else :
  for i in syn_all_labels :
    if i not in  syn_all_labels_test:
      print(i,"exist in synrod trainset but not testset")
  for i in syn_all_labels_test :
    if i not in  syn_all_labels:
      print(i," exist in synrod testset but not trainset")

if set(syn_all_labels) == set(all_labels):
  print(' datasets labels completly match')
else:
  print('sth is wrong')
  for i in syn_all_labels :
    if i not in  all_labels:
      print(i,"does not exist in ROD")
  for i in all_labels :
    if i not in  syn_all_labels:
      print(i," does not exist in synrod")
# Out:
# rod and synrod labels match
# sth is wrong
# bell_papper does not exist in ROD
# bell_pepper  does not exist in synrod

# %%
SynROD_train = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs,label_map=labelmap,
                                  img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))

   

SynROD_test = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs_test,label_map=labelmap,img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
         transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]))

SynROD_rotated = roteted_dataset(dt = 'SYNROD',annotations_list = syn_imgs,
                                 img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                 
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))





SynROD_dataloader_train = DataLoader(SynROD_train, batch_size=BATCH_size,shuffle=True)

SynROD_dataloader_test = DataLoader(SynROD_test, batch_size=BATCH_size,shuffle=True)

SynROD_rotated_dataloader = DataLoader(SynROD_rotated, batch_size=BATCH_size,shuffle=True)

# %%
X  = plot_pic(SynROD_dataloader_train ,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X  = plot_pic(SynROD_rotated_dataloader ,labelmap_rorated,r =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # models

# %%
# helper function
def load_cnn_model(model_name, pretrained=True):
    "Load and return a convolutional neural network."
    assert model_name in ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']
    return models.__dict__[model_name](pretrained= True)

# %%
class E(nn.Module):
    def __init__(self, model_name):
      
        super(E, self).__init__()  
        # load cnn and remove 2 last layers
        cnn = load_cnn_model(model_name)
        modules = list(cnn.children())[:-2]  # remove 2 last layers
        
        self.cnn = nn.Sequential(*modules)             
    
        
    def forward(self, x):
        x = self.cnn(x)  
              
        return x

class feature_extract(nn.Module):
    def __init__(self):
      
        super(feature_extract, self).__init__()  
        self.E_c = E(model_name ='resnet18')
        self.E_d = E(model_name ='resnet18') 
                
    def forward(self,  images, depths):
        features_c = self.E_c(images)
        features_d = self.E_d(depths)        
        X = torch.cat([features_c,features_d], dim=1 )     
              
        return X

class main_head(nn.Module):
    def __init__(self,num_classes,dropout):
      super(main_head, self).__init__() 
      self.gap = nn.AdaptiveAvgPool2d(output_size=(1, 1)) 

      self.fc1 = nn.Sequential(
          nn.Dropout(dropout),
          nn.Linear(1024, 1000),
          nn.BatchNorm1d(1000, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
      )
      self.fc2 = nn.Linear(1000, num_classes)
      self.initilise_weight()
      

    def forward(self, features):
        x = self.gap(features)
        x = torch.squeeze(x)
        x = self.fc1(x)
        x = self.fc2(x)   
     
          
              
        return x
    
    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)


class pretext(nn.Module):
    def __init__(self):
      super(pretext, self).__init__() 
      self.p_conv_1x1 = nn.Sequential(
          nn.Conv2d(1024 ,100, [1,1], stride=[1,1]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_conv_3x3 = nn.Sequential(
          nn.Conv2d(100, 100, [3,3], stride=[2,2]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_fc1 = nn.Sequential(
          nn.Linear(100*3*3, 100),
          nn.BatchNorm1d(100, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(p=0.5)
          )
      self.p_fc2 = nn.Linear(100, 4)
      self.initilise_weight()
      
     
      

    def forward(self, features):
      
        y = self.p_conv_1x1(features)
        y = self.p_conv_3x3(y)
        y = y.view(y.size(0), -1)
        y = self.p_fc1(y)
        y = self.p_fc2(y)
      
     
        return y


    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

F_model = feature_extract()

main_model =  main_head(num_classes = len(labelmap),dropout =dropout)

pr_model =  pretext()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# # model training

# %%
def entropy_loss(logits):
    p_softmax = F.softmax(logits, dim=1)
    mask = p_softmax.ge(0.000001)  # greater or equal to
    mask_out = torch.masked_select(p_softmax, mask)
    entropy = -(torch.sum(mask_out * torch.log(mask_out)))
    return entropy / float(p_softmax.size(0))

# %%
loss_fn_1 = torch.nn.CrossEntropyLoss()
loss_fn_2 = torch.nn.CrossEntropyLoss()

optimizer1 = torch.optim.SGD(F_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
optimizer2 = torch.optim.SGD(main_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
optimizer3 = torch.optim.SGD(pr_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)

# %%
F_model.to(device)
main_model.to(device)
pr_model.to(device)
# Out:
# pretext(
#   (p_conv_1x1): Sequential(
#     (0): Conv2d(1024, 100, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_conv_3x3): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_fc1): Sequential(
#     (0): Linear(in_features=900, out_features=100, bias=True)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (p_fc2): Linear(in_features=100, out_features=4, bias=True)
# )

# %%
swtt_batch = math.ceil(len(syn_imgs)/BATCH_size)
def train_one_epoch(epoch_index, tb_writer):
    running_loss_1 = 0.
    last_loss_1 = 0.
    running_loss_2 = 0.
    last_loss_2 = 0.
    acc = 0
    tot = 0
    cor = 0
    acc2 = 0
    tot2 = 0
    cor2 = 0

    # Here, we use enumerate(training_loader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for i, data in enumerate(SynROD_dataloader_train ,0):


      # Zero your gradients for every batch!
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        optimizer3.zero_grad()
       
       
        image_s,depth_s,label_s = data
        image_s,depth_s,label_s = image_s.to(device),depth_s.to(device),label_s.to(device)
        

        # Make predictions for this batch
        feat = F_model(image_s,depth_s)
        outputs = main_model(feat)
  
       
        if weight_ent >0:

                img_rgb, img_depth, _ = next(iter(ROD_dataloader))
                img_rgb, img_depth =img_rgb.to(device),img_depth.to(device)                
                logits = F_model(img_rgb, img_depth)
                logits_M = main_model(logits)
                loss_ent = entropy_loss(logits_M)

        else:
            loss_ent =0
         

        loss_1 = loss_fn_1(outputs,label_s) + (weight_ent) * loss_ent
      
       
        pr =  F.softmax(outputs, dim=1) 
        _, pr= torch.max( pr.data, 1)
        _, real= torch.max(label_s.data, 1)

        tot += label_s.size(0)
        cor += (pr ==  real).sum().item()
        acc = 100 * cor / tot    
        

        image_s_r,depth_s_r,rotation_syn = next(iter(SynROD_rotated_dataloader))
        image_rod_r,depth_rod_r,rotation_rod = next(iter(ROD_rotated_dataloader) )       
        
        image_s_r,depth_s_r,rotation_syn =  image_s_r.to(device),depth_s_r.to(device),rotation_syn.to(device)      
        image_rod_r,depth_rod_r,rotation_rod = image_rod_r.to(device),depth_rod_r.to(device),rotation_rod.to(device)
        # print(Fore.CYAN,',rotation_rod',rotation_rod)
        feat2 = F_model( image_s_r,depth_s_r)
        feat3= F_model(image_rod_r,depth_rod_r)
        
        outputs2 =pr_model( feat2 )        
        outputs3 =  pr_model(feat3)
       
        loss_2 = (loss_fn_2(outputs2,rotation_syn) + loss_fn_2(outputs3,rotation_rod))
             
        loss =  loss_1+ weight_rot *loss_2        
        loss.backward()


        optimizer1.step()
        optimizer2.step()
        optimizer3.step()
         
        pr2 =  F.softmax(outputs2, dim=1) 
        _, pr2= torch.max(pr2.data, 1)
        _, real2= torch.max(rotation_syn.data, 1)
        tot2 += rotation_syn.size(0)
        cor2 += (pr2 == real2).sum().item()
        acc2 = 100 * cor2 / tot2
        

        running_loss_2 += loss_2.item()  
        running_loss_1 += loss_1.item()      
        
        
       

        if i % 50 == 49:
          last_loss_1 = running_loss_1 / 50 # loss per batch
          last_loss_2 = running_loss_2 / 50
          print(Fore.BLUE,'  batch {}/ {} source_train_loss_1: {} source_train_loss_2: {} and main_accu is {}  pretex_accu is {} time is {}'.format(i + 1,swtt_batch, '%.5f' % last_loss_1,'%.5f' % last_loss_2,'%.4f' %acc,'%.4f' %acc2,'%.5f' %(time.time() - start_time)))
          
          running_loss_1 = 0.
          running_loss_2 = 0. 

        
    
   
    # model_name = F_model.module._get_name() if isinstance(F_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': F_model.state_dict(),
    #               'optimizer_state_dict': optimizer1.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = main_model.module._get_name() if isinstance(main_model, torch.nn.DataParallel) else main_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': main_model.state_dict(),
    #               'optimizer_state_dict': optimizer2.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = pr_model.module._get_name() if isinstance(pr_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint2 = {'epoch':epoch,
    #               'model_state_dict': pr_model.state_dict(),
    #               'optimizer_state_dict': optimizer3.state_dict(),
    #                'loss':  loss
                   
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint2,fpath)
    



    return last_loss_1,last_loss_2

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('runs/ROD_{}'.format(timestamp))
epoch_number = 0
import time
start_time = time.time()

EPOCHS = 20
best_vloss = 1_000_000.

source_test_loss =[]
source_test_accuracy =[]



target_test_loss = []
target_test_accuracy =[]
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    F_model.train(True)
    main_model.train(True)
    pr_model.train(True)
   

    avg_loss,avg_loss2= train_one_epoch(epoch_number, writer)

    # We don't need gradients on to do reporting
    F_model.train(False)
    main_model.train(False)
    pr_model.train(False)
   
   

    running_vloss = 0.0
    correct =0
    total = 0.
    for i, vdata in enumerate(SynROD_dataloader_test ):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    source_test_loss.append(avg_vloss)
    source_test_accuracy.append(accuracy)


    print(Fore.GREEN,'for main taks,loss source_test {},..... acc source_test {}'.format(avg_vloss, accuracy))


    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(ROD_dataloader):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    target_test_loss.append(avg_vloss)
    target_test_accuracy.append(accuracy)
    print(Fore.RED,'for main taks, loss target_test {} , .... acc target_test {}'.format( avg_vloss, accuracy))

    try:
            E= [i for i in range(len(target_test_loss))]

            fig, (axs, ax2) = plt.subplots(2)
            try:     
              t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              t_target_loss = [target_test_loss[i]  for i  in range(len(target_test_loss))]
            try:
                  s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                  s_test_loss =  [source_test_loss[i]  for i  in range(len(target_test_loss))]

            axs.plot(E, t_target_loss,label="target")
            axs.plot(E,s_test_loss,label="source_test")
            
            axs.set_xlabel('epoch')
            axs.set_ylabel('loss')
            axs.grid(True)
            
            try:
              t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                t_target_acc = [target_test_accuracy[i]  for i  in range(len(target_test_loss))]

            try:
                s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              s_test_acc =  [source_test_accuracy[i]  for i  in range(len(target_test_loss))]

            
            

            ax2.plot(E, t_target_acc,label="target" )
            ax2.plot(E,s_test_acc,label="source_test")

            
            ax2.set_xlabel('epoch')
            ax2.set_ylabel('accuracy')
            ax2.grid(True)

            fig.tight_layout()
          
            plt.savefig('main22.png')

    except:
            print(Fore.RED,'sth was wrng with saving')

    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        F_model_path = 'result/main/F_model2_{}_{}'.format(timestamp, epoch_number)
        torch.save(F_model.state_dict(), F_model_path)

        M_model_path = 'result/main/main_model2_{}_{}'.format(timestamp, epoch_number)
        torch.save(main_model.state_dict(), M_model_path)

        Fr_model_path = 'result/main/pr_model2_{}_{}'.format(timestamp, epoch_number)
        torch.save(pr_model.state_dict(),Fr_model_path)

    epoch_number += 1
# Out:
# EPOCH 1:
#    batch 50/ 586 source_train_loss_1: 4.24038 source_train_loss_2: 2.77682 and main_accu is 2.4688  pretex_accu is 26.0000 time is 187.36340
#    batch 100/ 586 source_train_loss_1: 4.16750 source_train_loss_2: 2.77450 and main_accu is 3.7031  pretex_accu is 25.7344 time is 350.81342
#    batch 150/ 586 source_train_loss_1: 4.08188 source_train_loss_2: 2.77286 and main_accu is 5.2812  pretex_accu is 25.7083 time is 511.62560
#    batch 200/ 586 source_train_loss_1: 4.00833 source_train_loss_2: 2.76727 and main_accu is 6.7969  pretex_accu is 26.2500 time is 669.49255
#    batch 250/ 586 source_train_loss_1: 3.91200 source_train_loss_2: 2.76702 and main_accu is 9.0500  pretex_accu is 26.3875 time is 827.96510
#    batch 300/ 586 source_train_loss_1: 3.82493 source_train_loss_2: 2.75036 and main_accu is 11.0469  pretex_accu is 26.6198 time is 984.44039
#    batch 350/ 586 source_train_loss_1: 3.72575 source_train_loss_2: 2.73491 and main_accu is 13.1339  pretex_accu is 26.8259 time is 1141.07783
#    batch 400/ 586 source_train_loss_1: 3.61415 source_train_loss_2: 2.71218 and main_accu is 15.2422  pretex_accu is 27.1406 time is 1296.04349
#    batch 450/ 586 source_train_loss_1: 3.50482 source_train_loss_2: 2.63827 and main_accu is 17.3368  pretex_accu is 27.9965 time is 1451.58007
#    batch 500/ 586 source_train_loss_1: 3.41308 source_train_loss_2: 2.53517 and main_accu is 19.0437  pretex_accu is 28.8344 time is 1606.95110
#    batch 550/ 586 source_train_loss_1: 3.30169 source_train_loss_2: 2.36012 and main_accu is 20.8494  pretex_accu is 30.0256 time is 1761.89481
#  for main taks,loss source_test 2.8330328464508057,..... acc source_test 41.97395476353667
#  for main taks, loss target_test 3.0998375415802 , .... acc target_test 36.217514472225645
# EPOCH 2:
#    batch 50/ 586 source_train_loss_1: 3.11274 source_train_loss_2: 2.11818 and main_accu is 43.6875  pretex_accu is 43.5938 time is 2402.34277
#    batch 100/ 586 source_train_loss_1: 3.02635 source_train_loss_2: 2.02633 and main_accu is 44.9531  pretex_accu is 43.9531 time is 2557.04209
#    batch 150/ 586 source_train_loss_1: 2.90635 source_train_loss_2: 1.96796 and main_accu is 45.8021  pretex_accu is 43.7188 time is 2713.68393
#    batch 200/ 586 source_train_loss_1: 2.84103 source_train_loss_2: 1.92086 and main_accu is 46.5156  pretex_accu is 44.0391 time is 2869.34587
#    batch 250/ 586 source_train_loss_1: 2.74646 source_train_loss_2: 1.87869 and main_accu is 47.1500  pretex_accu is 44.9875 time is 3023.35489
#    batch 300/ 586 source_train_loss_1: 2.66985 source_train_loss_2: 1.84857 and main_accu is 47.9740  pretex_accu is 45.5156 time is 3176.09532
#    batch 350/ 586 source_train_loss_1: 2.57900 source_train_loss_2: 1.81676 and main_accu is 48.7277  pretex_accu is 45.9152 time is 3328.33269
#    batch 400/ 586 source_train_loss_1: 2.51898 source_train_loss_2: 1.80045 and main_accu is 49.5156  pretex_accu is 46.2305 time is 3483.37487
#    batch 450/ 586 source_train_loss_1: 2.42330 source_train_loss_2: 1.77487 and main_accu is 50.3611  pretex_accu is 46.5139 time is 3638.02881
#    batch 500/ 586 source_train_loss_1: 2.35887 source_train_loss_2: 1.74041 and main_accu is 51.1063  pretex_accu is 46.9656 time is 3790.47468
#    batch 550/ 586 source_train_loss_1: 2.32981 source_train_loss_2: 1.74142 and main_accu is 51.6477  pretex_accu is 47.2699 time is 3942.09894
#  for main taks,loss source_test 2.0447280406951904,..... acc source_test 51.322823851953395
#  for main taks, loss target_test 2.27791690826416 , .... acc target_test 46.50819066387486
# EPOCH 3:
#    batch 50/ 586 source_train_loss_1: 2.21034 source_train_loss_2: 1.71796 and main_accu is 60.8750  pretex_accu is 52.0938 time is 4568.06114
#    batch 100/ 586 source_train_loss_1: 2.16056 source_train_loss_2: 1.67894 and main_accu is 60.7344  pretex_accu is 51.8438 time is 4719.70930
#    batch 150/ 586 source_train_loss_1: 2.11328 source_train_loss_2: 1.68284 and main_accu is 61.1458  pretex_accu is 51.7500 time is 4874.47222
#    batch 200/ 586 source_train_loss_1: 2.04934 source_train_loss_2: 1.64061 and main_accu is 61.9219  pretex_accu is 52.3125 time is 5028.73664
#    batch 250/ 586 source_train_loss_1: 1.97906 source_train_loss_2: 1.62070 and main_accu is 62.6063  pretex_accu is 52.8375 time is 5182.19647
#    batch 300/ 586 source_train_loss_1: 1.95034 source_train_loss_2: 1.61019 and main_accu is 63.1979  pretex_accu is 53.0833 time is 5337.06815
#    batch 350/ 586 source_train_loss_1: 1.90243 source_train_loss_2: 1.58334 and main_accu is 63.7366  pretex_accu is 53.7054 time is 5492.27551
#    batch 400/ 586 source_train_loss_1: 1.86807 source_train_loss_2: 1.55074 and main_accu is 64.0117  pretex_accu is 54.1016 time is 5647.58264
#    batch 450/ 586 source_train_loss_1: 1.84800 source_train_loss_2: 1.54186 and main_accu is 64.3819  pretex_accu is 54.4931 time is 5802.24335
#    batch 500/ 586 source_train_loss_1: 1.79669 source_train_loss_2: 1.50187 and main_accu is 64.7969  pretex_accu is 54.8750 time is 5956.31477
#    batch 550/ 586 source_train_loss_1: 1.74147 source_train_loss_2: 1.47767 and main_accu is 65.2642  pretex_accu is 55.2841 time is 6109.43801
#  for main taks,loss source_test 1.6988890171051025,..... acc source_test 57.98492117888965
#  for main taks, loss target_test 1.8694467544555664 , .... acc target_test 51.58270722995443
# EPOCH 4:
#    batch 50/ 586 source_train_loss_1: 1.70910 source_train_loss_2: 1.41265 and main_accu is 69.4062  pretex_accu is 61.3750 time is 6739.42074
#    batch 100/ 586 source_train_loss_1: 1.64599 source_train_loss_2: 1.36675 and main_accu is 70.2812  pretex_accu is 62.0938 time is 6893.11277
#    batch 150/ 586 source_train_loss_1: 1.62772 source_train_loss_2: 1.37086 and main_accu is 70.4583  pretex_accu is 61.9583 time is 7046.39329
#    batch 200/ 586 source_train_loss_1: 1.61618 source_train_loss_2: 1.31712 and main_accu is 70.7109  pretex_accu is 62.9062 time is 7200.28861
#    batch 250/ 586 source_train_loss_1: 1.60868 source_train_loss_2: 1.29626 and main_accu is 70.7062  pretex_accu is 63.3188 time is 7353.07917
#    batch 300/ 586 source_train_loss_1: 1.56758 source_train_loss_2: 1.25667 and main_accu is 71.0833  pretex_accu is 63.7760 time is 7506.57542
#    batch 350/ 586 source_train_loss_1: 1.54685 source_train_loss_2: 1.21354 and main_accu is 71.4464  pretex_accu is 64.2188 time is 7660.49524
#    batch 400/ 586 source_train_loss_1: 1.53131 source_train_loss_2: 1.16889 and main_accu is 71.5664  pretex_accu is 64.8008 time is 7814.71784
#    batch 450/ 586 source_train_loss_1: 1.49548 source_train_loss_2: 1.14695 and main_accu is 71.6979  pretex_accu is 65.1771 time is 7968.96289
#    batch 500/ 586 source_train_loss_1: 1.50897 source_train_loss_2: 1.11200 and main_accu is 71.7438  pretex_accu is 65.6469 time is 8123.33069
#    batch 550/ 586 source_train_loss_1: 1.43719 source_train_loss_2: 1.04887 and main_accu is 72.0142  pretex_accu is 66.0767 time is 8277.47351
#  for main taks,loss source_test 1.524788737297058,..... acc source_test 61.02810143934202
#  for main taks, loss target_test 1.7179970741271973 , .... acc target_test 52.28476413351398
# EPOCH 5:
#    batch 50/ 586 source_train_loss_1: 1.45561 source_train_loss_2: 0.99493 and main_accu is 73.2812  pretex_accu is 71.4688 time is 8917.05478
#    batch 100/ 586 source_train_loss_1: 1.42421 source_train_loss_2: 0.96642 and main_accu is 73.8125  pretex_accu is 71.5625 time is 9071.98557
#    batch 150/ 586 source_train_loss_1: 1.38337 source_train_loss_2: 0.91181 and main_accu is 74.3958  pretex_accu is 72.9167 time is 9226.13610
#    batch 200/ 586 source_train_loss_1: 1.38566 source_train_loss_2: 0.89145 and main_accu is 74.6797  pretex_accu is 73.2109 time is 9380.30873
#    batch 250/ 586 source_train_loss_1: 1.34949 source_train_loss_2: 0.83764 and main_accu is 75.0687  pretex_accu is 73.7438 time is 9535.03481
#    batch 300/ 586 source_train_loss_1: 1.31840 source_train_loss_2: 0.77409 and main_accu is 75.4896  pretex_accu is 74.3021 time is 9688.61704
#    batch 350/ 586 source_train_loss_1: 1.33768 source_train_loss_2: 0.77699 and main_accu is 75.4375  pretex_accu is 74.7054 time is 9843.46074
#    batch 400/ 586 source_train_loss_1: 1.30214 source_train_loss_2: 0.73802 and main_accu is 75.6094  pretex_accu is 75.0469 time is 10000.86288
#    batch 450/ 586 source_train_loss_1: 1.29314 source_train_loss_2: 0.72300 and main_accu is 75.8681  pretex_accu is 75.4201 time is 10156.38547
#    batch 500/ 586 source_train_loss_1: 1.27583 source_train_loss_2: 0.71454 and main_accu is 76.0406  pretex_accu is 75.6594 time is 10310.46265
#    batch 550/ 586 source_train_loss_1: 1.24940 source_train_loss_2: 0.66683 and main_accu is 76.2784  pretex_accu is 76.0568 time is 10463.82938
#  for main taks,loss source_test 1.44306218624115,..... acc source_test 61.782042494859496
#  for main taks, loss target_test 1.6078859567642212 , .... acc target_test 53.504126123906886
# EPOCH 6:
#    batch 50/ 586 source_train_loss_1: 1.25563 source_train_loss_2: 0.62591 and main_accu is 78.1562  pretex_accu is 80.0000 time is 11103.11105
#    batch 100/ 586 source_train_loss_1: 1.23608 source_train_loss_2: 0.62763 and main_accu is 78.0625  pretex_accu is 80.4219 time is 11259.54910
#    batch 150/ 586 source_train_loss_1: 1.21008 source_train_loss_2: 0.59195 and main_accu is 78.1875  pretex_accu is 80.7396 time is 11415.38347
#    batch 200/ 586 source_train_loss_1: 1.21458 source_train_loss_2: 0.58739 and main_accu is 78.3906  pretex_accu is 80.8750 time is 11570.69661
#    batch 250/ 586 source_train_loss_1: 1.19313 source_train_loss_2: 0.58323 and main_accu is 78.4437  pretex_accu is 81.1625 time is 11727.87618
#    batch 300/ 586 source_train_loss_1: 1.19650 source_train_loss_2: 0.54397 and main_accu is 78.5938  pretex_accu is 81.4323 time is 11890.55783
#    batch 350/ 586 source_train_loss_1: 1.19704 source_train_loss_2: 0.53051 and main_accu is 78.6830  pretex_accu is 81.8705 time is 12044.79085
#    batch 400/ 586 source_train_loss_1: 1.13923 source_train_loss_2: 0.52870 and main_accu is 79.0117  pretex_accu is 82.1016 time is 12205.18954
#    batch 450/ 586 source_train_loss_1: 1.14308 source_train_loss_2: 0.52214 and main_accu is 79.1875  pretex_accu is 82.3056 time is 12367.51446
#    batch 500/ 586 source_train_loss_1: 1.14269 source_train_loss_2: 0.51437 and main_accu is 79.2812  pretex_accu is 82.5000 time is 12528.48590
#    batch 550/ 586 source_train_loss_1: 1.16851 source_train_loss_2: 0.49573 and main_accu is 79.2585  pretex_accu is 82.6080 time is 12689.53361
#  for main taks,loss source_test 1.3991811275482178,..... acc source_test 61.8368745716244
#  for main taks, loss target_test 1.59211266040802 , .... acc target_test 53.23007759576303
# EPOCH 7:
#    batch 50/ 586 source_train_loss_1: 1.08611 source_train_loss_2: 0.45487 and main_accu is 81.3125  pretex_accu is 85.5000 time is 13339.36725
#    batch 100/ 586 source_train_loss_1: 1.11826 source_train_loss_2: 0.47889 and main_accu is 80.8750  pretex_accu is 85.2031 time is 13498.56321
#    batch 150/ 586 source_train_loss_1: 1.11722 source_train_loss_2: 0.45766 and main_accu is 80.8958  pretex_accu is 85.2917 time is 13657.25132
#    batch 200/ 586 source_train_loss_1: 1.11576 source_train_loss_2: 0.45294 and main_accu is 80.7969  pretex_accu is 85.4062 time is 13819.39329
#    batch 250/ 586 source_train_loss_1: 1.05992 source_train_loss_2: 0.42293 and main_accu is 81.0375  pretex_accu is 85.5625 time is 13977.49408
#    batch 300/ 586 source_train_loss_1: 1.06315 source_train_loss_2: 0.42226 and main_accu is 81.2031  pretex_accu is 85.7812 time is 14140.50681
#    batch 350/ 586 source_train_loss_1: 1.08191 source_train_loss_2: 0.42084 and main_accu is 81.2232  pretex_accu is 85.8839 time is 14299.53618
#    batch 400/ 586 source_train_loss_1: 1.07390 source_train_loss_2: 0.40784 and main_accu is 81.1953  pretex_accu is 86.0352 time is 14458.37674
#    batch 450/ 586 source_train_loss_1: 1.06144 source_train_loss_2: 0.41693 and main_accu is 81.3646  pretex_accu is 86.0833 time is 14614.74645
#    batch 500/ 586 source_train_loss_1: 1.02955 source_train_loss_2: 0.41149 and main_accu is 81.5219  pretex_accu is 86.1656 time is 14775.24524
#    batch 550/ 586 source_train_loss_1: 1.02973 source_train_loss_2: 0.39684 and main_accu is 81.6108  pretex_accu is 86.3125 time is 14932.95956
#  for main taks,loss source_test 1.3549749851226807,..... acc source_test 62.59081562714188
#  for main taks, loss target_test 1.6379263401031494 , .... acc target_test 53.00221702180072
# EPOCH 8:
#    batch 50/ 586 source_train_loss_1: 1.03451 source_train_loss_2: 0.38367 and main_accu is 82.7812  pretex_accu is 88.2812 time is 15576.97220
#    batch 100/ 586 source_train_loss_1: 0.98553 source_train_loss_2: 0.37907 and main_accu is 83.2656  pretex_accu is 88.0312 time is 15733.03381
#    batch 150/ 586 source_train_loss_1: 1.01324 source_train_loss_2: 0.42402 and main_accu is 83.4688  pretex_accu is 87.6042 time is 15895.94983
#    batch 200/ 586 source_train_loss_1: 1.00874 source_train_loss_2: 0.37183 and main_accu is 83.3438  pretex_accu is 87.7500 time is 16053.31801
#    batch 250/ 586 source_train_loss_1: 0.96164 source_train_loss_2: 0.37690 and main_accu is 83.7375  pretex_accu is 87.7938 time is 16211.73345
#    batch 300/ 586 source_train_loss_1: 0.97525 source_train_loss_2: 0.35818 and main_accu is 83.9479  pretex_accu is 88.0677 time is 16367.39842
#    batch 350/ 586 source_train_loss_1: 0.98870 source_train_loss_2: 0.35403 and main_accu is 83.9018  pretex_accu is 88.2857 time is 16523.54770
#    batch 400/ 586 source_train_loss_1: 0.96080 source_train_loss_2: 0.38213 and main_accu is 84.0039  pretex_accu is 88.2344 time is 16678.39437
#    batch 450/ 586 source_train_loss_1: 0.96517 source_train_loss_2: 0.37112 and main_accu is 83.9479  pretex_accu is 88.2986 time is 16837.47009
#    batch 500/ 586 source_train_loss_1: 0.96170 source_train_loss_2: 0.33569 and main_accu is 83.9969  pretex_accu is 88.4250 time is 16991.60744
#    batch 550/ 586 source_train_loss_1: 0.96243 source_train_loss_2: 0.35052 and main_accu is 84.0597  pretex_accu is 88.5028 time is 17153.15215
#  for main taks,loss source_test 1.3298286199569702,..... acc source_test 63.59150102810144
#  for main taks, loss target_test 1.746799349784851 , .... acc target_test 50.471117132651806
# EPOCH 9:
#    batch 50/ 586 source_train_loss_1: 0.93394 source_train_loss_2: 0.33278 and main_accu is 85.3750  pretex_accu is 89.6562 time is 17809.42480
#    batch 100/ 586 source_train_loss_1: 0.91500 source_train_loss_2: 0.34186 and main_accu is 85.6406  pretex_accu is 89.5312 time is 17969.71676
#    batch 150/ 586 source_train_loss_1: 0.91565 source_train_loss_2: 0.35557 and main_accu is 85.8021  pretex_accu is 89.3854 time is 18129.83652
#    batch 200/ 586 source_train_loss_1: 0.94971 source_train_loss_2: 0.33455 and main_accu is 85.5938  pretex_accu is 89.5000 time is 18291.84560
#    batch 250/ 586 source_train_loss_1: 0.93116 source_train_loss_2: 0.31531 and main_accu is 85.7062  pretex_accu is 89.7562 time is 18451.43275
#    batch 300/ 586 source_train_loss_1: 0.90665 source_train_loss_2: 0.34855 and main_accu is 85.8438  pretex_accu is 89.6510 time is 18610.86039
#    batch 350/ 586 source_train_loss_1: 0.92887 source_train_loss_2: 0.30971 and main_accu is 85.7321  pretex_accu is 89.7902 time is 18771.60530
#    batch 400/ 586 source_train_loss_1: 0.93666 source_train_loss_2: 0.32887 and main_accu is 85.7188  pretex_accu is 89.8047 time is 18933.22328
#    batch 450/ 586 source_train_loss_1: 0.88876 source_train_loss_2: 0.33196 and main_accu is 85.8472  pretex_accu is 89.8021 time is 19095.92833
#    batch 500/ 586 source_train_loss_1: 0.88894 source_train_loss_2: 0.29699 and main_accu is 85.8719  pretex_accu is 89.9313 time is 19257.02022
#    batch 550/ 586 source_train_loss_1: 0.88970 source_train_loss_2: 0.31765 and main_accu is 85.9318  pretex_accu is 89.9460 time is 19419.15819
#  for main taks,loss source_test 1.3164763450622559,..... acc source_test 64.49623029472241
#  for main taks, loss target_test 1.8003137111663818 , .... acc target_test 50.73284887301392
# EPOCH 10:
#    batch 50/ 586 source_train_loss_1: 0.87072 source_train_loss_2: 0.31106 and main_accu is 87.2500  pretex_accu is 90.8125 time is 20075.08486
#    batch 100/ 586 source_train_loss_1: 0.88655 source_train_loss_2: 0.30608 and main_accu is 86.9688  pretex_accu is 90.7031 time is 20236.33210
#    batch 150/ 586 source_train_loss_1: 0.90406 source_train_loss_2: 0.30401 and main_accu is 86.6875  pretex_accu is 90.8438 time is 20398.88150
#    batch 200/ 586 source_train_loss_1: 0.88633 source_train_loss_2: 0.31545 and main_accu is 86.7812  pretex_accu is 90.6641 time is 20560.52940
#    batch 250/ 586 source_train_loss_1: 0.86165 source_train_loss_2: 0.29254 and main_accu is 86.9688  pretex_accu is 90.7562 time is 20724.49293
#    batch 300/ 586 source_train_loss_1: 0.85608 source_train_loss_2: 0.29708 and main_accu is 87.1146  pretex_accu is 90.7969 time is 20884.23759
#    batch 350/ 586 source_train_loss_1: 0.86161 source_train_loss_2: 0.30246 and main_accu is 87.0938  pretex_accu is 90.9286 time is 21050.34905
#    batch 400/ 586 source_train_loss_1: 0.85679 source_train_loss_2: 0.28561 and main_accu is 87.2031  pretex_accu is 90.9766 time is 21213.97011
#    batch 450/ 586 source_train_loss_1: 0.84154 source_train_loss_2: 0.29264 and main_accu is 87.3229  pretex_accu is 91.0174 time is 21369.58200
#    batch 500/ 586 source_train_loss_1: 0.86271 source_train_loss_2: 0.28483 and main_accu is 87.2406  pretex_accu is 91.0844 time is 21525.58142
#    batch 550/ 586 source_train_loss_1: 0.84980 source_train_loss_2: 0.25383 and main_accu is 87.3494  pretex_accu is 91.2301 time is 21685.15086
#  for main taks,loss source_test 1.3296986818313599,..... acc source_test 63.564084989718985
#  for main taks, loss target_test 1.891251564025879 , .... acc target_test 49.374923020076366
# EPOCH 11:
#    batch 50/ 586 source_train_loss_1: 0.79924 source_train_loss_2: 0.27495 and main_accu is 89.0312  pretex_accu is 91.7188 time is 22335.05740
#    batch 100/ 586 source_train_loss_1: 0.83968 source_train_loss_2: 0.28474 and main_accu is 88.5938  pretex_accu is 91.8125 time is 22492.22368
#    batch 150/ 586 source_train_loss_1: 0.81073 source_train_loss_2: 0.26935 and main_accu is 88.7083  pretex_accu is 91.6979 time is 22654.81771
#    batch 200/ 586 source_train_loss_1: 0.83813 source_train_loss_2: 0.27738 and main_accu is 88.6250  pretex_accu is 91.5938 time is 22813.30767
#    batch 250/ 586 source_train_loss_1: 0.84280 source_train_loss_2: 0.28081 and main_accu is 88.4750  pretex_accu is 91.5750 time is 22972.91575
#    batch 300/ 586 source_train_loss_1: 0.83548 source_train_loss_2: 0.28635 and main_accu is 88.5312  pretex_accu is 91.5156 time is 23128.95655
#    batch 350/ 586 source_train_loss_1: 0.81583 source_train_loss_2: 0.26885 and main_accu is 88.5982  pretex_accu is 91.5982 time is 23292.80768
#    batch 400/ 586 source_train_loss_1: 0.83289 source_train_loss_2: 0.27388 and main_accu is 88.4922  pretex_accu is 91.6094 time is 23450.74003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-7f37755510ee> in <module>()
#      25
#      26
# ---> 27     avg_loss,avg_loss2= train_one_epoch(epoch_number, writer)
#      28
#      29     # We don't need gradients on to do reporting
#
# <ipython-input-22-1a504cb90eb7> in train_one_epoch(epoch_index, tb_writer)
#      15     # iter(training_loader) so that we can track the batch
#      16     # index and do some intra-epoch reporting
# ---> 17     for i, data in enumerate(SynROD_dataloader_train ,0):
#      18
#      19
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     650                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     651                 self._reset()  # type: ignore[call-arg]
# --> 652             data = self._next_data()
#     653             self._num_yielded += 1
#     654             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     690     def _next_data(self):
#     691         index = self._next_index()  # may raise StopIteration
# --> 692         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     693         if self._pin_memory:
#     694             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /content/drive/MyDrive/domian_adoptation/dataloader/dataloader.py in __getitem__(self, i)
#      47           img_path =   os.path.join(self.img_dir, (self.img_labels[i].replace('***','rgb')).split(' ')[0])
#      48           depth_path = os.path.join(self.depth_dir, (self.img_labels[i].replace('***','depth')).split(' ')[0])
# ---> 49           image = Image.open(img_path)
#      50           depth = Image.open(depth_path)
#      51           pre_label = self.img_labels[i].split('/')[0]
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2879         return None
#    2880
# -> 2881     im = _open_core(fp, filename, prefix)
#    2882
#    2883     if im is None:
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in _open_core(fp, filename, prefix)
#    2865                 elif result:
#    2866                     fp.seek(0)
# -> 2867                     im = factory(fp, filename)
#    2868                     _decompression_bomb_check(im.size)
#    2869                     return im
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#      79
#      80     def __init__(self, fp=None, filename=None):
# ---> 81         super().__init__()
#      82
#      83         self._min_frame = 0
#
# KeyboardInterrupt:
