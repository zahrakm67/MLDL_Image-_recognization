# %% [markdown]
# # 1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.5)

# %%
from colorama import Fore
import skimage.io as io
import os
import pandas as pd
import random
# torch 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.models as models
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import math
 
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/MyDrive/domian_adoptation
# Out:
# /content/drive/MyDrive/domian_adoptation

# %%
# from  mean_and_std import get_mean_and_std
from dataloader.dataloader import CustomImageDataset ,roteted_dataset
from visualization.data_plot import plot_pic

# %% [markdown]
# # 2. parameters

# %%
save_dir = '/content/drive/MyDrive/domian_adoptation/result' 

weight_rot = 1
weight_ent = 0.1
BATCH_size = 64
learning_rate = 0.0003
moment = 0.9
W_decay = 0.05
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
dropout =0.5

# save_dir = '/content/drive/MyDrive/domian_adoptation/result' 

# weight_rot = 2
# weight_ent = 0.1
# BATCH_size = 64
# learning_rate = 0.0003
# moment = 0.9
# W_decay = 0.04
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)
# dropout =0.5
# Out:
# cuda:0

# %% [markdown]
# # 3. Datasets

# %%
# ! wget 'https://www.dropbox.com/s/xdy5cfu7m63pk46/?dl=1' -O \ ROD-synROD.tar
# ! rm ' ROD-synROD.tar'
# !  cp ' ROD-synROD.tar'  /content/drive/MyDrive/domian_adoptation

# %%
if not os.path.isfile('/content/ROD-synROD/ROD/rgb-washington/apple/apple_1/apple_1_1_101_crop.png'):
        print(Fore.RED, 'This might take several minuets......')
        ! tar -xf     /content/drive/MyDrive/domian_adoptation/' ROD-synROD.tar'  -C /content
       
else:
         print(Fore.CYAN, 'dataset file already exist')
# Out:
#  dataset file already exist

# %% [markdown]
# # 2.1 ROD dataset
#
#
# ---
#
#
#
# 1.   Rod without label as a trainset
# 2.   Rod with label as testset

# %%
with open("/content/ROD-synROD/ROD/wrgbd_40k-split_sync.txt") as f:
 
    lines = f.read() 
    imgs = lines.split('\n')
imgs.remove('')
print(imgs[0])

all_labels = [imgs[i].split('/')[0] for i in range(len(imgs))]
all_labels=list(set(all_labels))
labelmap ={}
for i in range(len(all_labels)):
   labelmap[all_labels[i]] =i
print('total number of labels: ',Fore.RED,len(labelmap) )
print(Fore.BLUE,labelmap)

ROD_dataset = CustomImageDataset(dt= 'ROD',annotations_list = imgs,label_map=labelmap,
                                img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                                depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]), 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                                                        
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                     
                                    
                                )

ROD_dataloader = DataLoader(ROD_dataset, batch_size= BATCH_size,shuffle=True)
# Out:
# rubber_eraser/rubber_eraser_4/rubber_eraser_4_1_136_***.png 38
# total number of labels:   47
#  {'pitcher': 0, 'food_cup': 1, 'flashlight': 2, 'bell_pepper': 3, 'rubber_eraser': 4, 'soda_can': 5, 'food_bag': 6, 'toothpaste': 7, 'pear': 8, 'cap': 9, 'pliers': 10, 'lightbulb': 11, 'hand_towel': 12, 'plate': 13, 'ball': 14, 'bowl': 15, 'toothbrush': 16, 'calculator': 17, 'glue_stick': 18, 'cereal_box': 19, 'orange': 20, 'sponge': 21, 'apple': 22, 'coffee_mug': 23, 'camera': 24, 'banana': 25, 'marker': 26, 'dry_battery': 27, 'potato': 28, 'stapler': 29, 'notebook': 30, 'food_box': 31, 'comb': 32, 'water_bottle': 33, 'cell_phone': 34, 'binder': 35, 'greens': 36, 'mushroom': 37, 'food_can': 38, 'garlic': 39, 'shampoo': 40, 'lemon': 41, 'instant_noodles': 42, 'scissors': 43, 'kleenex': 44, 'keyboard': 45, 'food_jar': 46}

# %%
# visulasioan of ROD
X  = plot_pic(ROD_dataloader,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ROD_rotated = roteted_dataset(dt= 'ROD',annotations_list = imgs,
                               img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                               depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),                                
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                             
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                           )

ROD_rotated_dataloader = DataLoader(ROD_rotated, batch_size = BATCH_size,shuffle=True)

labelmap_rorated = {
    '0 degree' :0,
    '90 degree' :1,
    '180 degree' :2,
    '270 degree' :3

}

# %%
X  = plot_pic(ROD_rotated_dataloader ,labelmap_rorated,r =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2.2 SynROD dataset
#
#
# ---
#
#
#
# 1.   SynROD  with label as a trainset

# %%
with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_train1.txt") as f:
    lines = f.read() 
    syn_imgs = lines.split('\n')
syn_imgs.remove('')

with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_test1.txt") as f:
    lines = f.read() 
    syn_imgs_test = lines.split('\n')
# syn_imgs.remove('')

syn_imgs_test.remove('')


syn_all_labels = [syn_imgs[i].split('/')[0] for i in range(len(syn_imgs))]
syn_all_labels=list(set(syn_all_labels))

syn_all_labels_test = [syn_imgs_test[i].split('/')[0] for i in range(len(syn_imgs_test))]
syn_all_labels_test=list(set(syn_all_labels_test))

# checking labesls oncistency 
if set(syn_all_labels) == set(syn_all_labels_test):
  print('rod and synrod labels match')
else :
  for i in syn_all_labels :
    if i not in  syn_all_labels_test:
      print(i,"exist in synrod trainset but not testset")
  for i in syn_all_labels_test :
    if i not in  syn_all_labels:
      print(i," exist in synrod testset but not trainset")

if set(syn_all_labels) == set(all_labels):
  print(' datasets labels completly match')
else:
  print('sth is wrong')
  for i in syn_all_labels :
    if i not in  all_labels:
      print(i,"does not exist in ROD")
  for i in all_labels :
    if i not in  syn_all_labels:
      print(i," does not exist in synrod")
# Out:
# rod and synrod labels match
# sth is wrong
# bell_papper does not exist in ROD
# bell_pepper  does not exist in synrod

# %%
SynROD_train = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs,label_map=labelmap,
                                  img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))

   

SynROD_test = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs_test,label_map=labelmap,img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
         transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]))

SynROD_rotated = roteted_dataset(dt = 'SYNROD',annotations_list = syn_imgs,
                                 img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                 
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))





SynROD_dataloader_train = DataLoader(SynROD_train, batch_size=BATCH_size,shuffle=True)

SynROD_dataloader_test = DataLoader(SynROD_test, batch_size=BATCH_size,shuffle=True)

SynROD_rotated_dataloader = DataLoader(SynROD_rotated, batch_size=BATCH_size,shuffle=True)

# %%
X  = plot_pic(SynROD_dataloader_train ,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X  = plot_pic(SynROD_rotated_dataloader ,labelmap_rorated,r =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # models

# %%
# helper function
def load_cnn_model(model_name, pretrained=True):
    "Load and return a convolutional neural network."
    assert model_name in ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']
    return models.__dict__[model_name](pretrained= True)

# %%
class E(nn.Module):
    def __init__(self, model_name):
      
        super(E, self).__init__()  
        # load cnn and remove 2 last layers
        cnn = load_cnn_model(model_name)
        modules = list(cnn.children())[:-2]  # remove 2 last layers
        
        self.cnn = nn.Sequential(*modules)             
    
        
    def forward(self, x):
        x = self.cnn(x)  
              
        return x

class feature_extract(nn.Module):
    def __init__(self):
      
        super(feature_extract, self).__init__()  
        self.E_c = E(model_name ='resnet18')
        self.E_d = E(model_name ='resnet18') 
                
    def forward(self,  images, depths):
        features_c = self.E_c(images)
        features_d = self.E_d(depths)        
        X = torch.cat([features_c,features_d], dim=1 )     
              
        return X

class main_head(nn.Module):
    def __init__(self,num_classes,dropout):
      super(main_head, self).__init__() 
      self.gap = nn.AdaptiveAvgPool2d(output_size=(1, 1)) 

      self.fc1 = nn.Sequential(
          nn.Dropout(dropout),
          nn.Linear(1024, 1000),
          nn.BatchNorm1d(1000, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(dropout)
      )
      self.fc2 = nn.Linear(1000, num_classes)
      self.initilise_weight()
      

    def forward(self, features):
        x = self.gap(features)
        x = torch.squeeze(x)
        x = self.fc1(x)
        x = self.fc2(x)   
     
          
              
        return x
    
    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)


class pretext(nn.Module):
    def __init__(self):
      super(pretext, self).__init__() 
      self.p_conv_1x1 = nn.Sequential(
          nn.Conv2d(1024 ,100, [1,1], stride=[1,1]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_conv_3x3 = nn.Sequential(
          nn.Conv2d(100, 100, [3,3], stride=[2,2]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_fc1 = nn.Sequential(
          nn.Linear(100*3*3, 100),
          nn.BatchNorm1d(100, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(p=0.5)
          )
      self.p_fc2 = nn.Linear(100, 4)
      self.initilise_weight()
      
     
      

    def forward(self, features):
      
        y = self.p_conv_1x1(features)
        y = self.p_conv_3x3(y)
        y = y.view(y.size(0), -1)
        y = self.p_fc1(y)
        y = self.p_fc2(y)
      
     
        return y


    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

F_model = feature_extract()

main_model =  main_head(num_classes = len(labelmap),dropout =dropout)

pr_model =  pretext()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# # model training

# %%
def entropy_loss(logits):
    p_softmax = F.softmax(logits, dim=1)
    mask = p_softmax.ge(0.000001)  # greater or equal to
    mask_out = torch.masked_select(p_softmax, mask)
    entropy = -(torch.sum(mask_out * torch.log(mask_out)))
    return entropy / float(p_softmax.size(0))

# %%
loss_fn_1 = torch.nn.CrossEntropyLoss()
loss_fn_2 = torch.nn.CrossEntropyLoss()

optimizer1 = torch.optim.SGD(F_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
optimizer2 = torch.optim.SGD(main_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)
optimizer3 = torch.optim.SGD(pr_model.parameters(), lr=learning_rate, momentum=moment,weight_decay=W_decay)

# %%
F_model.to(device)
main_model.to(device)
pr_model.to(device)
# Out:
# pretext(
#   (p_conv_1x1): Sequential(
#     (0): Conv2d(1024, 100, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_conv_3x3): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_fc1): Sequential(
#     (0): Linear(in_features=900, out_features=100, bias=True)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (p_fc2): Linear(in_features=100, out_features=4, bias=True)
# )

# %%
swtt_batch = math.ceil(len(syn_imgs)/BATCH_size)
def train_one_epoch(epoch_index, tb_writer):
    running_loss_1 = 0.
    last_loss_1 = 0.
    running_loss_2 = 0.
    last_loss_2 = 0.
    acc = 0
    tot = 0
    cor = 0
    acc2 = 0
    tot2 = 0
    cor2 = 0

    # Here, we use enumerate(training_loader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for i, data in enumerate(SynROD_dataloader_train ,0):


      # Zero your gradients for every batch!
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        optimizer3.zero_grad()
       
       
        image_s,depth_s,label_s = data
        image_s,depth_s,label_s = image_s.to(device),depth_s.to(device),label_s.to(device)
        

        # Make predictions for this batch
        feat = F_model(image_s,depth_s)
        outputs = main_model(feat)
  
       
        if weight_ent >0:

                img_rgb, img_depth, _ = next(iter(ROD_dataloader))
                img_rgb, img_depth =img_rgb.to(device),img_depth.to(device)                
                logits = F_model(img_rgb, img_depth)
                logits_M = main_model(logits)
                loss_ent = entropy_loss(logits_M)

        else:
            loss_ent =0
         

        loss_1 = loss_fn_1(outputs,label_s) + (weight_ent) * loss_ent
      
       
        pr =  F.softmax(outputs, dim=1) 
        _, pr= torch.max( pr.data, 1)
        _, real= torch.max(label_s.data, 1)

        tot += label_s.size(0)
        cor += (pr ==  real).sum().item()
        acc = 100 * cor / tot    
        

        image_s_r,depth_s_r,rotation_syn = next(iter(SynROD_rotated_dataloader))
        image_rod_r,depth_rod_r,rotation_rod = next(iter(ROD_rotated_dataloader) )       
        
        image_s_r,depth_s_r,rotation_syn =  image_s_r.to(device),depth_s_r.to(device),rotation_syn.to(device)      
        image_rod_r,depth_rod_r,rotation_rod = image_rod_r.to(device),depth_rod_r.to(device),rotation_rod.to(device)
        # print(Fore.CYAN,',rotation_rod',rotation_rod)
        feat2 = F_model( image_s_r,depth_s_r)
        feat3= F_model(image_rod_r,depth_rod_r)
        
        outputs2 =pr_model( feat2 )        
        outputs3 =  pr_model(feat3)
       
        loss_2 = (loss_fn_2(outputs2,rotation_syn) + loss_fn_2(outputs3,rotation_rod))
             
        loss =  loss_1+ weight_rot *loss_2        
        loss.backward()


        optimizer1.step()
        optimizer2.step()
        optimizer3.step()
         
        pr2 =  F.softmax(outputs2, dim=1) 
        _, pr2= torch.max(pr2.data, 1)
        _, real2= torch.max(rotation_syn.data, 1)
        tot2 += rotation_syn.size(0)
        cor2 += (pr2 == real2).sum().item()
        acc2 = 100 * cor2 / tot2
        

        running_loss_2 += loss_2.item()  
        running_loss_1 += loss_1.item()      
        
        
       

        if i % 50 == 49:
          last_loss_1 = running_loss_1 / 50 # loss per batch
          last_loss_2 = running_loss_2 / 50
          print(Fore.BLUE,'  batch {}/ {} source_train_loss_1: {} source_train_loss_2: {} and main_accu is {}  pretex_accu is {} time is {}'.format(i + 1,swtt_batch, '%.5f' % last_loss_1,'%.5f' % last_loss_2,'%.4f' %acc,'%.4f' %acc2,'%.5f' %(time.time() - start_time)))
          
          running_loss_1 = 0.
          running_loss_2 = 0. 

        
    
   
    # model_name = F_model.module._get_name() if isinstance(F_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': F_model.state_dict(),
    #               'optimizer_state_dict': optimizer1.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = main_model.module._get_name() if isinstance(main_model, torch.nn.DataParallel) else main_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': main_model.state_dict(),
    #               'optimizer_state_dict': optimizer2.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = pr_model.module._get_name() if isinstance(pr_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint2 = {'epoch':epoch,
    #               'model_state_dict': pr_model.state_dict(),
    #               'optimizer_state_dict': optimizer3.state_dict(),
    #                'loss':  loss
                   
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint2,fpath)
    



    return last_loss_1,last_loss_2

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('runs/ROD_{}'.format(timestamp))
epoch_number = 0
import time
start_time = time.time()

EPOCHS = 20
best_vloss = 1_000_000.

source_test_loss =[]
source_test_accuracy =[]



target_test_loss = []
target_test_accuracy =[]
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    F_model.train(True)
    main_model.train(True)
    pr_model.train(True)
   

    avg_loss,avg_loss2= train_one_epoch(epoch_number, writer)

    # We don't need gradients on to do reporting
    F_model.train(False)
    main_model.train(False)
    pr_model.train(False)
   
   

    running_vloss = 0.0
    correct =0
    total = 0.
    for i, vdata in enumerate(SynROD_dataloader_test ):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    source_test_loss.append(avg_vloss)
    source_test_accuracy.append(accuracy)


    print(Fore.GREEN,'for main taks,loss source_test {},..... acc source_test {}'.format(avg_vloss, accuracy))


    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(ROD_dataloader):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    target_test_loss.append(avg_vloss)
    target_test_accuracy.append(accuracy)
    print(Fore.RED,'for main taks, loss target_test {} , .... acc target_test {}'.format( avg_vloss, accuracy))

    try:
            E= [i for i in range(len(target_test_loss))]

            fig, (axs, ax2) = plt.subplots(2)
            try:     
              t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              t_target_loss = [target_test_loss[i]  for i  in range(len(target_test_loss))]
            try:
                  s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                  s_test_loss =  [source_test_loss[i]  for i  in range(len(target_test_loss))]

            axs.plot(E, t_target_loss,label="target")
            axs.plot(E,s_test_loss,label="source_test")
            
            axs.set_xlabel('epoch')
            axs.set_ylabel('loss')
            axs.grid(True)
            
            try:
              t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                t_target_acc = [target_test_accuracy[i]  for i  in range(len(target_test_loss))]

            try:
                s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              s_test_acc =  [source_test_accuracy[i]  for i  in range(len(target_test_loss))]

            
            

            ax2.plot(E, t_target_acc,label="target" )
            ax2.plot(E,s_test_acc,label="source_test")

            
            ax2.set_xlabel('epoch')
            ax2.set_ylabel('accuracy')
            ax2.grid(True)

            fig.tight_layout()
          
            plt.savefig('2main_1.png')

    except:
            print(Fore.RED,'sth was wrng with saving')

    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        F_model_path = 'result/main/F_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(F_model.state_dict(), F_model_path)

        M_model_path = 'result/main/main_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(main_model.state_dict(), M_model_path)

        Fr_model_path = 'result/main/pr_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(pr_model.state_dict(),Fr_model_path)

    epoch_number += 1
# Out:
# EPOCH 1:
#    batch 50/ 586 source_train_loss_1: 4.24086 source_train_loss_2: 2.77773 and main_accu is 2.3750  pretex_accu is 25.7812 time is 173.28953
#    batch 100/ 586 source_train_loss_1: 4.17508 source_train_loss_2: 2.77794 and main_accu is 3.5781  pretex_accu is 26.0156 time is 328.67478
#    batch 150/ 586 source_train_loss_1: 4.08254 source_train_loss_2: 2.77759 and main_accu is 5.2500  pretex_accu is 25.6979 time is 481.73984
#    batch 200/ 586 source_train_loss_1: 4.01341 source_train_loss_2: 2.77585 and main_accu is 6.7578  pretex_accu is 25.5156 time is 634.92215
#    batch 250/ 586 source_train_loss_1: 3.93498 source_train_loss_2: 2.77586 and main_accu is 8.5188  pretex_accu is 25.2000 time is 787.37743
#    batch 300/ 586 source_train_loss_1: 3.84123 source_train_loss_2: 2.76954 and main_accu is 10.4948  pretex_accu is 25.4010 time is 941.41028
#    batch 350/ 586 source_train_loss_1: 3.74258 source_train_loss_2: 2.77054 and main_accu is 12.5580  pretex_accu is 25.5670 time is 1091.30573
#    batch 400/ 586 source_train_loss_1: 3.63768 source_train_loss_2: 2.77239 and main_accu is 14.7773  pretex_accu is 25.5312 time is 1242.23129
#    batch 450/ 586 source_train_loss_1: 3.55397 source_train_loss_2: 2.76922 and main_accu is 16.4931  pretex_accu is 25.7014 time is 1391.74514
#    batch 500/ 586 source_train_loss_1: 3.44000 source_train_loss_2: 2.76952 and main_accu is 18.3156  pretex_accu is 25.7219 time is 1543.22685
#    batch 550/ 586 source_train_loss_1: 3.31764 source_train_loss_2: 2.76662 and main_accu is 20.1108  pretex_accu is 25.7500 time is 1693.69812
#  for main taks,loss source_test 2.8870766162872314,..... acc source_test 40.603152844413984
#  for main taks, loss target_test 3.1147775650024414 , .... acc target_test 35.42924005419387
# EPOCH 2:
#    batch 50/ 586 source_train_loss_1: 3.15562 source_train_loss_2: 2.76539 and main_accu is 41.0625  pretex_accu is 26.8750 time is 2311.32810
#    batch 100/ 586 source_train_loss_1: 3.02790 source_train_loss_2: 2.76301 and main_accu is 43.2344  pretex_accu is 27.7031 time is 2459.38929
#    batch 150/ 586 source_train_loss_1: 2.94789 source_train_loss_2: 2.75895 and main_accu is 44.2604  pretex_accu is 28.0208 time is 2609.30771
#    batch 200/ 586 source_train_loss_1: 2.85640 source_train_loss_2: 2.75417 and main_accu is 45.3203  pretex_accu is 27.8750 time is 2758.91459
#    batch 250/ 586 source_train_loss_1: 2.77848 source_train_loss_2: 2.74932 and main_accu is 46.3312  pretex_accu is 28.1187 time is 2908.17732
#    batch 300/ 586 source_train_loss_1: 2.68401 source_train_loss_2: 2.73952 and main_accu is 47.3542  pretex_accu is 28.3906 time is 3057.12805
#    batch 350/ 586 source_train_loss_1: 2.61972 source_train_loss_2: 2.72060 and main_accu is 48.1741  pretex_accu is 28.7991 time is 3206.06460
#    batch 400/ 586 source_train_loss_1: 2.52457 source_train_loss_2: 2.70039 and main_accu is 48.9102  pretex_accu is 29.0820 time is 3354.73906
#    batch 450/ 586 source_train_loss_1: 2.49053 source_train_loss_2: 2.65996 and main_accu is 49.7118  pretex_accu is 29.6181 time is 3505.74223
#    batch 500/ 586 source_train_loss_1: 2.37728 source_train_loss_2: 2.61298 and main_accu is 50.6625  pretex_accu is 30.2219 time is 3655.20618
#    batch 550/ 586 source_train_loss_1: 2.32050 source_train_loss_2: 2.54817 and main_accu is 51.4773  pretex_accu is 30.8608 time is 3806.74256
#  for main taks,loss source_test 2.079665184020996,..... acc source_test 52.94037011651816
#  for main taks, loss target_test 2.3389089107513428 , .... acc target_test 47.84148294124892
# EPOCH 3:
#    batch 50/ 586 source_train_loss_1: 2.20933 source_train_loss_2: 2.41460 and main_accu is 62.6250  pretex_accu is 38.2188 time is 4424.00138
#    batch 100/ 586 source_train_loss_1: 2.17266 source_train_loss_2: 2.33263 and main_accu is 62.2188  pretex_accu is 39.4062 time is 4575.71703
#    batch 150/ 586 source_train_loss_1: 2.15260 source_train_loss_2: 2.26376 and main_accu is 62.3125  pretex_accu is 40.4688 time is 4726.16633
#    batch 200/ 586 source_train_loss_1: 2.08801 source_train_loss_2: 2.20325 and main_accu is 62.5391  pretex_accu is 41.0391 time is 4877.56619
#    batch 250/ 586 source_train_loss_1: 2.00433 source_train_loss_2: 2.14008 and main_accu is 63.1375  pretex_accu is 41.3375 time is 5030.31681
#    batch 300/ 586 source_train_loss_1: 1.98932 source_train_loss_2: 2.09461 and main_accu is 63.5312  pretex_accu is 41.6979 time is 5182.42273
#    batch 350/ 586 source_train_loss_1: 1.95532 source_train_loss_2: 2.04545 and main_accu is 63.7232  pretex_accu is 42.3125 time is 5336.85657
#    batch 400/ 586 source_train_loss_1: 1.89847 source_train_loss_2: 2.02305 and main_accu is 64.2578  pretex_accu is 42.6406 time is 5487.21335
#    batch 450/ 586 source_train_loss_1: 1.84373 source_train_loss_2: 1.98404 and main_accu is 64.7674  pretex_accu is 42.9132 time is 5637.92266
#    batch 500/ 586 source_train_loss_1: 1.81670 source_train_loss_2: 1.95751 and main_accu is 65.1562  pretex_accu is 43.0031 time is 5788.49173
#    batch 550/ 586 source_train_loss_1: 1.78701 source_train_loss_2: 1.92834 and main_accu is 65.5682  pretex_accu is 43.2159 time is 5938.55191
#  for main taks,loss source_test 1.7046561241149902,..... acc source_test 58.711446196024674
#  for main taks, loss target_test 1.8837792873382568 , .... acc target_test 55.0098534302254
# EPOCH 4:
#    batch 50/ 586 source_train_loss_1: 1.68661 source_train_loss_2: 1.90421 and main_accu is 71.8438  pretex_accu is 45.5312 time is 6545.91968
#    batch 100/ 586 source_train_loss_1: 1.69272 source_train_loss_2: 1.88213 and main_accu is 71.2031  pretex_accu is 46.1875 time is 6692.62479
#    batch 150/ 586 source_train_loss_1: 1.66797 source_train_loss_2: 1.86861 and main_accu is 71.4167  pretex_accu is 45.6250 time is 6839.51652
#    batch 200/ 586 source_train_loss_1: 1.64428 source_train_loss_2: 1.85785 and main_accu is 71.4219  pretex_accu is 46.0703 time is 6985.80706
#    batch 250/ 586 source_train_loss_1: 1.62594 source_train_loss_2: 1.83864 and main_accu is 71.6125  pretex_accu is 46.2250 time is 7130.91555
#    batch 300/ 586 source_train_loss_1: 1.57192 source_train_loss_2: 1.82570 and main_accu is 71.9635  pretex_accu is 46.7500 time is 7276.12562
#    batch 350/ 586 source_train_loss_1: 1.56165 source_train_loss_2: 1.80174 and main_accu is 72.1116  pretex_accu is 47.0089 time is 7419.47933
#    batch 400/ 586 source_train_loss_1: 1.53575 source_train_loss_2: 1.79568 and main_accu is 72.3633  pretex_accu is 47.1133 time is 7563.97354
#    batch 450/ 586 source_train_loss_1: 1.49873 source_train_loss_2: 1.79619 and main_accu is 72.6701  pretex_accu is 47.4861 time is 7708.87042
#    batch 500/ 586 source_train_loss_1: 1.47681 source_train_loss_2: 1.78107 and main_accu is 72.9375  pretex_accu is 47.6437 time is 7853.83532
#    batch 550/ 586 source_train_loss_1: 1.47533 source_train_loss_2: 1.77178 and main_accu is 73.1364  pretex_accu is 47.7159 time is 7999.67786
#  for main taks,loss source_test 1.5190588235855103,..... acc source_test 62.302947224126115
#  for main taks, loss target_test 1.690932273864746 , .... acc target_test 55.120704520261114
# EPOCH 5:
#    batch 50/ 586 source_train_loss_1: 1.40760 source_train_loss_2: 1.75867 and main_accu is 76.7188  pretex_accu is 49.9375 time is 8592.07492
#    batch 100/ 586 source_train_loss_1: 1.41645 source_train_loss_2: 1.75808 and main_accu is 76.3125  pretex_accu is 49.3750 time is 8735.64077
#    batch 150/ 586 source_train_loss_1: 1.38057 source_train_loss_2: 1.73815 and main_accu is 76.4271  pretex_accu is 49.0625 time is 8879.66518
#    batch 200/ 586 source_train_loss_1: 1.36724 source_train_loss_2: 1.72266 and main_accu is 76.8047  pretex_accu is 49.0703 time is 9023.32289
#    batch 250/ 586 source_train_loss_1: 1.33991 source_train_loss_2: 1.72789 and main_accu is 76.9437  pretex_accu is 49.5438 time is 9167.01609
#    batch 300/ 586 source_train_loss_1: 1.32331 source_train_loss_2: 1.71450 and main_accu is 77.1250  pretex_accu is 49.8646 time is 9311.63141
#    batch 350/ 586 source_train_loss_1: 1.32603 source_train_loss_2: 1.70697 and main_accu is 77.2634  pretex_accu is 49.7902 time is 9455.38476
#    batch 400/ 586 source_train_loss_1: 1.31680 source_train_loss_2: 1.69606 and main_accu is 77.4062  pretex_accu is 49.7656 time is 9600.97913
#    batch 450/ 586 source_train_loss_1: 1.28518 source_train_loss_2: 1.68337 and main_accu is 77.6354  pretex_accu is 49.8750 time is 9745.74160
#    batch 500/ 586 source_train_loss_1: 1.25546 source_train_loss_2: 1.68005 and main_accu is 77.9313  pretex_accu is 50.1094 time is 9889.92176
#    batch 550/ 586 source_train_loss_1: 1.27193 source_train_loss_2: 1.67418 and main_accu is 78.0369  pretex_accu is 50.2642 time is 10034.28497
#  for main taks,loss source_test 1.443138837814331,..... acc source_test 62.78272789581906
#  for main taks, loss target_test 1.6474673748016357 , .... acc target_test 56.33082891981771
# EPOCH 6:
#    batch 50/ 586 source_train_loss_1: 1.22956 source_train_loss_2: 1.65928 and main_accu is 79.5312  pretex_accu is 52.2188 time is 10623.58785
#    batch 100/ 586 source_train_loss_1: 1.21365 source_train_loss_2: 1.66378 and main_accu is 80.0000  pretex_accu is 52.5938 time is 10768.43300
#    batch 150/ 586 source_train_loss_1: 1.19658 source_train_loss_2: 1.64507 and main_accu is 80.5104  pretex_accu is 52.5729 time is 10913.59018
#    batch 200/ 586 source_train_loss_1: 1.20212 source_train_loss_2: 1.63963 and main_accu is 80.7109  pretex_accu is 52.5781 time is 11057.68896
#    batch 250/ 586 source_train_loss_1: 1.17447 source_train_loss_2: 1.61459 and main_accu is 80.7875  pretex_accu is 52.8125 time is 11202.46541
#    batch 300/ 586 source_train_loss_1: 1.17445 source_train_loss_2: 1.62297 and main_accu is 80.8542  pretex_accu is 52.6875 time is 11350.63486
#    batch 350/ 586 source_train_loss_1: 1.14314 source_train_loss_2: 1.61415 and main_accu is 81.0446  pretex_accu is 52.6205 time is 11498.28928
#    batch 400/ 586 source_train_loss_1: 1.14531 source_train_loss_2: 1.60975 and main_accu is 81.2344  pretex_accu is 52.6914 time is 11643.98171
#    batch 450/ 586 source_train_loss_1: 1.12829 source_train_loss_2: 1.59074 and main_accu is 81.4861  pretex_accu is 52.7465 time is 11789.98357
#    batch 500/ 586 source_train_loss_1: 1.14683 source_train_loss_2: 1.59286 and main_accu is 81.5125  pretex_accu is 52.7156 time is 11933.53110
#    batch 550/ 586 source_train_loss_1: 1.12377 source_train_loss_2: 1.58535 and main_accu is 81.5625  pretex_accu is 52.8153 time is 12076.44464
#  for main taks,loss source_test 1.3969876766204834,..... acc source_test 63.5229609321453
#  for main taks, loss target_test 1.6287446022033691 , .... acc target_test 57.020569035595514
# EPOCH 7:
#    batch 50/ 586 source_train_loss_1: 1.12093 source_train_loss_2: 1.55581 and main_accu is 82.9688  pretex_accu is 54.8750 time is 12666.62458
#    batch 100/ 586 source_train_loss_1: 1.09381 source_train_loss_2: 1.55118 and main_accu is 82.9375  pretex_accu is 55.0000 time is 12812.97693
#    batch 150/ 586 source_train_loss_1: 1.07741 source_train_loss_2: 1.54286 and main_accu is 83.0938  pretex_accu is 54.5729 time is 12957.51777
#    batch 200/ 586 source_train_loss_1: 1.06783 source_train_loss_2: 1.55243 and main_accu is 83.2344  pretex_accu is 54.5547 time is 13103.92289
#    batch 250/ 586 source_train_loss_1: 1.07538 source_train_loss_2: 1.51667 and main_accu is 83.3688  pretex_accu is 55.1313 time is 13250.09882
#    batch 300/ 586 source_train_loss_1: 1.06011 source_train_loss_2: 1.50503 and main_accu is 83.5938  pretex_accu is 55.4635 time is 13396.68055
#    batch 350/ 586 source_train_loss_1: 1.06359 source_train_loss_2: 1.50440 and main_accu is 83.6384  pretex_accu is 55.4196 time is 13540.39015
#    batch 400/ 586 source_train_loss_1: 1.01410 source_train_loss_2: 1.47738 and main_accu is 83.8555  pretex_accu is 55.8438 time is 13683.26461
#    batch 450/ 586 source_train_loss_1: 1.05208 source_train_loss_2: 1.46876 and main_accu is 83.9757  pretex_accu is 56.2465 time is 13826.93822
#    batch 500/ 586 source_train_loss_1: 1.04042 source_train_loss_2: 1.47339 and main_accu is 84.1281  pretex_accu is 56.3219 time is 13972.27777
#    batch 550/ 586 source_train_loss_1: 1.03728 source_train_loss_2: 1.43650 and main_accu is 84.1335  pretex_accu is 56.4915 time is 14116.39279
#  for main taks,loss source_test 1.3701303005218506,..... acc source_test 64.07128169979438
#  for main taks, loss target_test 1.6917017698287964 , .... acc target_test 56.31235373814509
# EPOCH 8:
#    batch 50/ 586 source_train_loss_1: 1.02023 source_train_loss_2: 1.41832 and main_accu is 85.2188  pretex_accu is 57.5312 time is 14698.76333
#    batch 100/ 586 source_train_loss_1: 1.01758 source_train_loss_2: 1.38446 and main_accu is 85.5156  pretex_accu is 58.5312 time is 14841.79050
#    batch 150/ 586 source_train_loss_1: 0.99848 source_train_loss_2: 1.36228 and main_accu is 85.6042  pretex_accu is 59.1354 time is 14985.08955
#    batch 200/ 586 source_train_loss_1: 0.96429 source_train_loss_2: 1.36594 and main_accu is 85.9922  pretex_accu is 59.2969 time is 15128.05301
#    batch 250/ 586 source_train_loss_1: 0.99878 source_train_loss_2: 1.34460 and main_accu is 85.9562  pretex_accu is 59.4750 time is 15269.69957
#    batch 300/ 586 source_train_loss_1: 0.96396 source_train_loss_2: 1.31838 and main_accu is 86.1823  pretex_accu is 59.9219 time is 15413.26944
#    batch 350/ 586 source_train_loss_1: 0.99115 source_train_loss_2: 1.29515 and main_accu is 86.1473  pretex_accu is 60.1562 time is 15556.58957
#    batch 400/ 586 source_train_loss_1: 0.99330 source_train_loss_2: 1.30028 and main_accu is 86.0977  pretex_accu is 60.4336 time is 15700.09591
#    batch 450/ 586 source_train_loss_1: 0.97554 source_train_loss_2: 1.27260 and main_accu is 86.1528  pretex_accu is 60.8264 time is 15845.86706
#    batch 500/ 586 source_train_loss_1: 0.96925 source_train_loss_2: 1.25025 and main_accu is 86.1844  pretex_accu is 61.1313 time is 15990.64288
#    batch 550/ 586 source_train_loss_1: 0.97224 source_train_loss_2: 1.25623 and main_accu is 86.1989  pretex_accu is 61.3068 time is 16135.58274
#  for main taks,loss source_test 1.3855770826339722,..... acc source_test 64.0301576422207
#  for main taks, loss target_test 1.7518200874328613 , .... acc target_test 57.057519398940755
# EPOCH 9:
#    batch 50/ 586 source_train_loss_1: 0.94018 source_train_loss_2: 1.20819 and main_accu is 88.4375  pretex_accu is 64.8438 time is 16723.06780
#    batch 100/ 586 source_train_loss_1: 0.95028 source_train_loss_2: 1.21141 and main_accu is 88.1094  pretex_accu is 64.8750 time is 16865.43838
#    batch 150/ 586 source_train_loss_1: 0.94999 source_train_loss_2: 1.18248 and main_accu is 88.0938  pretex_accu is 65.1667 time is 17009.24346
#    batch 200/ 586 source_train_loss_1: 0.91844 source_train_loss_2: 1.15687 and main_accu is 88.0938  pretex_accu is 65.5547 time is 17152.29822
#    batch 250/ 586 source_train_loss_1: 0.94969 source_train_loss_2: 1.14853 and main_accu is 88.0687  pretex_accu is 65.7500 time is 17292.85800
#    batch 300/ 586 source_train_loss_1: 0.92827 source_train_loss_2: 1.13864 and main_accu is 88.0104  pretex_accu is 66.1771 time is 17437.64915
#    batch 350/ 586 source_train_loss_1: 0.93255 source_train_loss_2: 1.10340 and main_accu is 88.1518  pretex_accu is 66.5714 time is 17583.05248
#    batch 400/ 586 source_train_loss_1: 0.94354 source_train_loss_2: 1.08545 and main_accu is 88.0625  pretex_accu is 66.8789 time is 17729.85835
#    batch 450/ 586 source_train_loss_1: 0.91219 source_train_loss_2: 1.06093 and main_accu is 88.1111  pretex_accu is 67.4271 time is 17874.23080
#    batch 500/ 586 source_train_loss_1: 0.92653 source_train_loss_2: 1.03930 and main_accu is 88.1188  pretex_accu is 67.8875 time is 18018.35843
#    batch 550/ 586 source_train_loss_1: 0.92486 source_train_loss_2: 1.01393 and main_accu is 88.0852  pretex_accu is 68.3210 time is 18159.78172
#  for main taks,loss source_test 1.4119700193405151,..... acc source_test 64.61960246744346
#  for main taks, loss target_test 1.821117639541626 , .... acc target_test 55.70575193989408
# EPOCH 10:
#    batch 50/ 586 source_train_loss_1: 0.88453 source_train_loss_2: 0.94848 and main_accu is 89.3438  pretex_accu is 74.7500 time is 18749.38917
#    batch 100/ 586 source_train_loss_1: 0.93157 source_train_loss_2: 0.91156 and main_accu is 88.4219  pretex_accu is 75.2812 time is 18899.65847
#    batch 150/ 586 source_train_loss_1: 0.89794 source_train_loss_2: 0.86735 and main_accu is 89.0521  pretex_accu is 75.9271 time is 19048.04929
#    batch 200/ 586 source_train_loss_1: 0.89454 source_train_loss_2: 0.83138 and main_accu is 89.1719  pretex_accu is 76.5781 time is 19196.61974
#    batch 250/ 586 source_train_loss_1: 0.91553 source_train_loss_2: 0.81086 and main_accu is 89.1562  pretex_accu is 77.0000 time is 19345.90984
#    batch 300/ 586 source_train_loss_1: 0.90972 source_train_loss_2: 0.76340 and main_accu is 89.2188  pretex_accu is 77.6250 time is 19494.53735
#    batch 350/ 586 source_train_loss_1: 0.89305 source_train_loss_2: 0.74186 and main_accu is 89.2812  pretex_accu is 78.1607 time is 19642.22335
#    batch 400/ 586 source_train_loss_1: 0.88991 source_train_loss_2: 0.70938 and main_accu is 89.3906  pretex_accu is 78.6172 time is 19787.06486
#    batch 450/ 586 source_train_loss_1: 0.89199 source_train_loss_2: 0.69916 and main_accu is 89.3785  pretex_accu is 78.9410 time is 19931.63093
#    batch 500/ 586 source_train_loss_1: 0.90230 source_train_loss_2: 0.66200 and main_accu is 89.3500  pretex_accu is 79.3031 time is 20077.70231
#    batch 550/ 586 source_train_loss_1: 0.91674 source_train_loss_2: 0.63880 and main_accu is 89.2727  pretex_accu is 79.6364 time is 20224.12327
#  for main taks,loss source_test 1.4447357654571533,..... acc source_test 64.78409869773817
#  for main taks, loss target_test 1.9588637351989746 , .... acc target_test 54.66190417539106
# EPOCH 11:
#    batch 50/ 586 source_train_loss_1: 0.89264 source_train_loss_2: 0.61107 and main_accu is 89.5625  pretex_accu is 83.9062 time is 20812.25660
#    batch 100/ 586 source_train_loss_1: 0.87442 source_train_loss_2: 0.60198 and main_accu is 90.2500  pretex_accu is 83.7812 time is 20958.11130
#    batch 150/ 586 source_train_loss_1: 0.86002 source_train_loss_2: 0.58971 and main_accu is 90.5625  pretex_accu is 83.8854 time is 21104.40218
#    batch 200/ 586 source_train_loss_1: 0.86370 source_train_loss_2: 0.56802 and main_accu is 90.7266  pretex_accu is 84.2422 time is 21249.07107
#    batch 250/ 586 source_train_loss_1: 0.87180 source_train_loss_2: 0.55226 and main_accu is 90.6125  pretex_accu is 84.4125 time is 21391.33457
#    batch 300/ 586 source_train_loss_1: 0.86268 source_train_loss_2: 0.55865 and main_accu is 90.6771  pretex_accu is 84.5417 time is 21535.20527
#    batch 350/ 586 source_train_loss_1: 0.87640 source_train_loss_2: 0.55535 and main_accu is 90.6830  pretex_accu is 84.5670 time is 21680.10896
#    batch 400/ 586 source_train_loss_1: 0.87513 source_train_loss_2: 0.55779 and main_accu is 90.5820  pretex_accu is 84.5195 time is 21825.22196
#    batch 450/ 586 source_train_loss_1: 0.87413 source_train_loss_2: 0.52146 and main_accu is 90.5243  pretex_accu is 84.7188 time is 21973.53891
#    batch 500/ 586 source_train_loss_1: 0.87574 source_train_loss_2: 0.51148 and main_accu is 90.4906  pretex_accu is 84.8000 time is 22118.93272
#    batch 550/ 586 source_train_loss_1: 0.87281 source_train_loss_2: 0.51497 and main_accu is 90.5142  pretex_accu is 84.9148 time is 22263.60424
#  for main taks,loss source_test 1.4480314254760742,..... acc source_test 65.49691569568198
#  for main taks, loss target_test 1.9754735231399536 , .... acc target_test 54.07069836186722
# EPOCH 12:
#    batch 50/ 586 source_train_loss_1: 0.86718 source_train_loss_2: 0.47964 and main_accu is 91.2812  pretex_accu is 87.0938 time is 22852.71006
#    batch 100/ 586 source_train_loss_1: 0.83811 source_train_loss_2: 0.49040 and main_accu is 91.3438  pretex_accu is 86.8281 time is 22996.57247
#    batch 150/ 586 source_train_loss_1: 0.86344 source_train_loss_2: 0.47696 and main_accu is 91.0833  pretex_accu is 86.8229 time is 23142.49281
#    batch 200/ 586 source_train_loss_1: 0.84562 source_train_loss_2: 0.45825 and main_accu is 91.1562  pretex_accu is 86.9766 time is 23288.41018
#    batch 250/ 586 source_train_loss_1: 0.86409 source_train_loss_2: 0.47068 and main_accu is 91.1312  pretex_accu is 87.0312 time is 23432.81428
#    batch 300/ 586 source_train_loss_1: 0.85305 source_train_loss_2: 0.47194 and main_accu is 91.2292  pretex_accu is 87.1406 time is 23577.07688
#    batch 350/ 586 source_train_loss_1: 0.85381 source_train_loss_2: 0.46401 and main_accu is 91.1562  pretex_accu is 87.2857 time is 23722.61330
#    batch 400/ 586 source_train_loss_1: 0.86810 source_train_loss_2: 0.45139 and main_accu is 91.0977  pretex_accu is 87.3281 time is 23868.28158
#    batch 450/ 586 source_train_loss_1: 0.86886 source_train_loss_2: 0.44674 and main_accu is 91.0903  pretex_accu is 87.4340 time is 24011.86804
#    batch 500/ 586 source_train_loss_1: 0.83558 source_train_loss_2: 0.46214 and main_accu is 91.2094  pretex_accu is 87.4250 time is 24156.08908
#    batch 550/ 586 source_train_loss_1: 0.83876 source_train_loss_2: 0.42997 and main_accu is 91.2443  pretex_accu is 87.5341 time is 24301.23656
#  for main taks,loss source_test 1.468649983406067,..... acc source_test 66.10006854009596
#  for main taks, loss target_test 2.0332891941070557 , .... acc target_test 54.00295602906762
# EPOCH 13:
#    batch 50/ 586 source_train_loss_1: 0.80053 source_train_loss_2: 0.42589 and main_accu is 93.5000  pretex_accu is 89.5938 time is 24891.74971
#    batch 100/ 586 source_train_loss_1: 0.82101 source_train_loss_2: 0.42409 and main_accu is 92.8438  pretex_accu is 89.1094 time is 25035.64483
#    batch 150/ 586 source_train_loss_1: 0.83344 source_train_loss_2: 0.41606 and main_accu is 92.5417  pretex_accu is 89.1250 time is 25180.40279
#    batch 200/ 586 source_train_loss_1: 0.82914 source_train_loss_2: 0.41713 and main_accu is 92.4141  pretex_accu is 89.1016 time is 25326.02569
#    batch 250/ 586 source_train_loss_1: 0.82851 source_train_loss_2: 0.39550 and main_accu is 92.4688  pretex_accu is 89.3000 time is 25470.84392
#    batch 300/ 586 source_train_loss_1: 0.82924 source_train_loss_2: 0.39238 and main_accu is 92.4896  pretex_accu is 89.4531 time is 25614.52096
#    batch 350/ 586 source_train_loss_1: 0.82045 source_train_loss_2: 0.39958 and main_accu is 92.5580  pretex_accu is 89.4732 time is 25759.25760
#    batch 400/ 586 source_train_loss_1: 0.84740 source_train_loss_2: 0.38885 and main_accu is 92.5000  pretex_accu is 89.5742 time is 25904.77072
#    batch 450/ 586 source_train_loss_1: 0.85468 source_train_loss_2: 0.41229 and main_accu is 92.4062  pretex_accu is 89.5139 time is 26051.68018
#    batch 500/ 586 source_train_loss_1: 0.84970 source_train_loss_2: 0.40650 and main_accu is 92.3375  pretex_accu is 89.4875 time is 26195.53118
#    batch 550/ 586 source_train_loss_1: 0.85054 source_train_loss_2: 0.38683 and main_accu is 92.2841  pretex_accu is 89.4943 time is 26343.36792
#  for main taks,loss source_test 1.5254076719284058,..... acc source_test 64.46881425633995
#  for main taks, loss target_test 2.0164883136749268 , .... acc target_test 54.378618056410886
# EPOCH 14:
#    batch 50/ 586 source_train_loss_1: 0.80928 source_train_loss_2: 0.38332 and main_accu is 93.6875  pretex_accu is 90.4062 time is 26930.89950
#    batch 100/ 586 source_train_loss_1: 0.81042 source_train_loss_2: 0.39243 and main_accu is 93.8594  pretex_accu is 90.3438 time is 27078.77804
#    batch 150/ 586 source_train_loss_1: 0.81433 source_train_loss_2: 0.36859 and main_accu is 93.6354  pretex_accu is 90.4479 time is 27226.61941
#    batch 200/ 586 source_train_loss_1: 0.82759 source_train_loss_2: 0.36392 and main_accu is 93.5547  pretex_accu is 90.6875 time is 27372.28669
#    batch 250/ 586 source_train_loss_1: 0.81272 source_train_loss_2: 0.38525 and main_accu is 93.4813  pretex_accu is 90.5625 time is 27518.40785
#    batch 300/ 586 source_train_loss_1: 0.80984 source_train_loss_2: 0.38367 and main_accu is 93.4479  pretex_accu is 90.4479 time is 27664.99236
#    batch 350/ 586 source_train_loss_1: 0.83139 source_train_loss_2: 0.38920 and main_accu is 93.5134  pretex_accu is 90.3705 time is 27811.13129
#    batch 400/ 586 source_train_loss_1: 0.84529 source_train_loss_2: 0.37273 and main_accu is 93.3633  pretex_accu is 90.4062 time is 27960.00365
#    batch 450/ 586 source_train_loss_1: 0.84037 source_train_loss_2: 0.37008 and main_accu is 93.2708  pretex_accu is 90.4444 time is 28107.78843
#    batch 500/ 586 source_train_loss_1: 0.81912 source_train_loss_2: 0.35807 and main_accu is 93.3094  pretex_accu is 90.5187 time is 28253.93122
#    batch 550/ 586 source_train_loss_1: 0.83900 source_train_loss_2: 0.37137 and main_accu is 93.2727  pretex_accu is 90.5341 time is 28400.74065
#  for main taks,loss source_test 1.5329301357269287,..... acc source_test 66.63468128855381
#  for main taks, loss target_test 2.0539052486419678 , .... acc target_test 54.30471732972041
# EPOCH 15:
#    batch 50/ 586 source_train_loss_1: 0.79816 source_train_loss_2: 0.35142 and main_accu is 94.4375  pretex_accu is 91.7188 time is 29007.24716
#    batch 100/ 586 source_train_loss_1: 0.80169 source_train_loss_2: 0.35398 and main_accu is 94.4531  pretex_accu is 91.4062 time is 29153.65341
#    batch 150/ 586 source_train_loss_1: 0.80999 source_train_loss_2: 0.36908 and main_accu is 94.2812  pretex_accu is 91.2292 time is 29298.49848
#    batch 200/ 586 source_train_loss_1: 0.82044 source_train_loss_2: 0.37056 and main_accu is 94.0547  pretex_accu is 91.1953 time is 29444.53835
#    batch 250/ 586 source_train_loss_1: 0.81112 source_train_loss_2: 0.33896 and main_accu is 94.0687  pretex_accu is 91.4688 time is 29592.93345
#    batch 300/ 586 source_train_loss_1: 0.82418 source_train_loss_2: 0.35541 and main_accu is 93.9896  pretex_accu is 91.5052 time is 29740.55236
#    batch 350/ 586 source_train_loss_1: 0.81497 source_train_loss_2: 0.34916 and main_accu is 94.0179  pretex_accu is 91.5446 time is 29886.81919
#    batch 400/ 586 source_train_loss_1: 0.82807 source_train_loss_2: 0.33335 and main_accu is 94.0781  pretex_accu is 91.6055 time is 30035.14947
#    batch 450/ 586 source_train_loss_1: 0.81307 source_train_loss_2: 0.35362 and main_accu is 94.1146  pretex_accu is 91.6146 time is 30181.45497
#    batch 500/ 586 source_train_loss_1: 0.81697 source_train_loss_2: 0.33501 and main_accu is 94.1094  pretex_accu is 91.6500 time is 30327.16908
#    batch 550/ 586 source_train_loss_1: 0.84617 source_train_loss_2: 0.32972 and main_accu is 94.0455  pretex_accu is 91.7188 time is 30474.64325
#  for main taks,loss source_test 1.6339929103851318,..... acc source_test 63.742289239204936
#  for main taks, loss target_test 2.0582432746887207 , .... acc target_test 54.66498337233649
# EPOCH 16:
#    batch 50/ 586 source_train_loss_1: 0.78085 source_train_loss_2: 0.33484 and main_accu is 95.4688  pretex_accu is 92.3125 time is 31074.98023
#    batch 100/ 586 source_train_loss_1: 0.79840 source_train_loss_2: 0.33637 and main_accu is 95.2656  pretex_accu is 92.3438 time is 31222.85614
#    batch 150/ 586 source_train_loss_1: 0.80553 source_train_loss_2: 0.34349 and main_accu is 95.0833  pretex_accu is 91.9688 time is 31371.09470
#    batch 200/ 586 source_train_loss_1: 0.81143 source_train_loss_2: 0.33652 and main_accu is 95.0078  pretex_accu is 92.0625 time is 31518.42809
#    batch 250/ 586 source_train_loss_1: 0.82302 source_train_loss_2: 0.33836 and main_accu is 94.8688  pretex_accu is 92.1562 time is 31664.48112
#    batch 300/ 586 source_train_loss_1: 0.81066 source_train_loss_2: 0.32617 and main_accu is 94.9010  pretex_accu is 92.1875 time is 31810.14399
#    batch 350/ 586 source_train_loss_1: 0.80441 source_train_loss_2: 0.32844 and main_accu is 94.9554  pretex_accu is 92.2768 time is 31958.28796
#    batch 400/ 586 source_train_loss_1: 0.81717 source_train_loss_2: 0.33012 and main_accu is 94.9414  pretex_accu is 92.2969 time is 32106.29189
#    batch 450/ 586 source_train_loss_1: 0.82539 source_train_loss_2: 0.33503 and main_accu is 94.8403  pretex_accu is 92.2014 time is 32253.51100
#    batch 500/ 586 source_train_loss_1: 0.80115 source_train_loss_2: 0.32820 and main_accu is 94.8594  pretex_accu is 92.2094 time is 32400.50843
#    batch 550/ 586 source_train_loss_1: 0.82165 source_train_loss_2: 0.33509 and main_accu is 94.8608  pretex_accu is 92.2045 time is 32547.49653
#  for main taks,loss source_test 1.6282055377960205,..... acc source_test 64.90747087045922
#  for main taks, loss target_test 2.0986387729644775 , .... acc target_test 54.87128956768075
# EPOCH 17:
#    batch 50/ 586 source_train_loss_1: 0.77703 source_train_loss_2: 0.31860 and main_accu is 95.9688  pretex_accu is 92.9688 time is 33143.89749
#    batch 100/ 586 source_train_loss_1: 0.80872 source_train_loss_2: 0.32137 and main_accu is 95.8594  pretex_accu is 92.7188 time is 33289.67001
#    batch 150/ 586 source_train_loss_1: 0.79561 source_train_loss_2: 0.32769 and main_accu is 95.7292  pretex_accu is 92.5833 time is 33437.16638
#    batch 200/ 586 source_train_loss_1: 0.81137 source_train_loss_2: 0.31310 and main_accu is 95.7188  pretex_accu is 92.8359 time is 33583.10862
#    batch 250/ 586 source_train_loss_1: 0.82532 source_train_loss_2: 0.32170 and main_accu is 95.5687  pretex_accu is 92.8937 time is 33726.34160
#    batch 300/ 586 source_train_loss_1: 0.81312 source_train_loss_2: 0.31524 and main_accu is 95.5156  pretex_accu is 93.0781 time is 33869.50639
#    batch 350/ 586 source_train_loss_1: 0.80743 source_train_loss_2: 0.31158 and main_accu is 95.4598  pretex_accu is 93.1830 time is 34014.29235
#    batch 400/ 586 source_train_loss_1: 0.82739 source_train_loss_2: 0.31504 and main_accu is 95.3984  pretex_accu is 93.1914 time is 34160.43654
#    batch 450/ 586 source_train_loss_1: 0.82736 source_train_loss_2: 0.31872 and main_accu is 95.3889  pretex_accu is 93.1979 time is 34306.57628
#    batch 500/ 586 source_train_loss_1: 0.80821 source_train_loss_2: 0.30365 and main_accu is 95.4031  pretex_accu is 93.2469 time is 34452.41813
#    batch 550/ 586 source_train_loss_1: 0.82531 source_train_loss_2: 0.29077 and main_accu is 95.3438  pretex_accu is 93.3068 time is 34597.47612
#  for main taks,loss source_test 1.6851806640625,..... acc source_test 66.41535298149418
#  for main taks, loss target_test 2.0848724842071533 , .... acc target_test 55.02217021800714
# EPOCH 18:
#    batch 50/ 586 source_train_loss_1: 0.77247 source_train_loss_2: 0.31175 and main_accu is 96.7188  pretex_accu is 92.9375 time is 35187.78027
#    batch 100/ 586 source_train_loss_1: 0.80854 source_train_loss_2: 0.30112 and main_accu is 96.4844  pretex_accu is 93.4531 time is 35331.33183
#    batch 150/ 586 source_train_loss_1: 0.82358 source_train_loss_2: 0.32404 and main_accu is 96.1875  pretex_accu is 93.0938 time is 35477.18280
#    batch 200/ 586 source_train_loss_1: 0.81459 source_train_loss_2: 0.29679 and main_accu is 96.0547  pretex_accu is 93.2734 time is 35622.13619
#    batch 250/ 586 source_train_loss_1: 0.80413 source_train_loss_2: 0.32742 and main_accu is 96.0687  pretex_accu is 93.2062 time is 35765.48192
#    batch 300/ 586 source_train_loss_1: 0.82699 source_train_loss_2: 0.30423 and main_accu is 95.8958  pretex_accu is 93.3125 time is 35907.41728
#    batch 350/ 586 source_train_loss_1: 0.83785 source_train_loss_2: 0.31632 and main_accu is 95.8036  pretex_accu is 93.2768 time is 36050.39582
#    batch 400/ 586 source_train_loss_1: 0.82505 source_train_loss_2: 0.30090 and main_accu is 95.7734  pretex_accu is 93.3203 time is 36193.48442
#    batch 450/ 586 source_train_loss_1: 0.84881 source_train_loss_2: 0.30919 and main_accu is 95.6528  pretex_accu is 93.2951 time is 36337.59660
#    batch 500/ 586 source_train_loss_1: 0.82400 source_train_loss_2: 0.29912 and main_accu is 95.6281  pretex_accu is 93.3281 time is 36483.70681
#    batch 550/ 586 source_train_loss_1: 0.83790 source_train_loss_2: 0.30814 and main_accu is 95.5767  pretex_accu is 93.3778 time is 36626.28391
#  for main taks,loss source_test 1.7595155239105225,..... acc source_test 64.63331048663468
#  for main taks, loss target_test 2.0861504077911377 , .... acc target_test 54.56029067619165
# EPOCH 19:
#    batch 50/ 586 source_train_loss_1: 0.80059 source_train_loss_2: 0.31588 and main_accu is 96.9062  pretex_accu is 93.0312 time is 37208.57169
#    batch 100/ 586 source_train_loss_1: 0.80992 source_train_loss_2: 0.30012 and main_accu is 96.7344  pretex_accu is 93.2969 time is 37347.66847
#    batch 150/ 586 source_train_loss_1: 0.82820 source_train_loss_2: 0.31464 and main_accu is 96.5104  pretex_accu is 93.3125 time is 37489.61289
