# %% [markdown]
# # 1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.5

# %%
from colorama import Fore
import skimage.io as io
import os
import pandas as pd
import random
# torch 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.models as models
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import math

# %%
# %cd /content/drive/MyDrive/domian_adoptation
# Out:
# /content/drive/MyDrive/domian_adoptation

# %%
# from  mean_and_std import get_mean_and_std
from dataloader.dataloader import CustomImageDataset ,roteted_dataset,continous_rotation_dataset
from visualization.data_plot import plot_pic

# %% [markdown]
# # 2. parameters

# %%
# save_dir = '/content/drive/MyDrive/domian_adoptation/result/aux_task' 

weight_rot = 1
weight_ent = 0
BATCH_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# second set of parameters:
# save_dir = '/content/drive/MyDrive/domian_adoptation/result/aux_task' 

# weight_rot = 0.6
# weight_ent = 0
# BATCH_size = 64
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)
# Out:
# cuda:0

# %% [markdown]
# # 3. Datasets

# %%
# ! wget 'https://www.dropbox.com/s/xdy5cfu7m63pk46/?dl=1' -O \ ROD-synROD.tar
# ! rm ' ROD-synROD.tar'
# !  cp ' ROD-synROD.tar'  /content/drive/MyDrive/domian_adoptation

# %%
if not os.path.isfile('/content/ROD-synROD/ROD/rgb-washington/apple/apple_1/apple_1_1_101_crop.png'):
        print(Fore.RED, 'This might take several minuets......')
        ! tar -xf     /content/drive/MyDrive/domian_adoptation/' ROD-synROD.tar'  -C /content
       
else:
         print(Fore.CYAN, 'dataset file already exist')
# Out:
#  This might take several minuets......

# %% [markdown]
# # 2.1 ROD dataset
#
#
# ---
#
#
#
# 1.   Rod without label as a trainset
# 2.   Rod with label as testset

# %%
with open("/content/ROD-synROD/ROD/wrgbd_40k-split_sync.txt") as f:
 
    lines = f.read() 
    imgs = lines.split('\n')
imgs.remove('')
print(imgs[0])

all_labels = [imgs[i].split('/')[0] for i in range(len(imgs))]
all_labels=list(set(all_labels))
labelmap ={}
for i in range(len(all_labels)):
   labelmap[all_labels[i]] =i
print('total number of labels: ',Fore.RED,len(labelmap) )
print(Fore.BLUE,labelmap)

ROD_dataset = CustomImageDataset(dt= 'ROD',annotations_list = imgs,label_map=labelmap,
                                img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                                depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]), 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                                                        
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                     
                                    
                                )

ROD_dataloader = DataLoader(ROD_dataset, batch_size= BATCH_size,shuffle=True)
# Out:
# rubber_eraser/rubber_eraser_4/rubber_eraser_4_1_136_***.png 38
# total number of labels:   47
#  {'toothbrush': 0, 'pear': 1, 'mushroom': 2, 'soda_can': 3, 'bowl': 4, 'stapler': 5, 'marker': 6, 'cereal_box': 7, 'glue_stick': 8, 'sponge': 9, 'orange': 10, 'food_cup': 11, 'notebook': 12, 'food_can': 13, 'rubber_eraser': 14, 'water_bottle': 15, 'kleenex': 16, 'banana': 17, 'greens': 18, 'camera': 19, 'instant_noodles': 20, 'comb': 21, 'pliers': 22, 'lightbulb': 23, 'flashlight': 24, 'potato': 25, 'apple': 26, 'food_bag': 27, 'toothpaste': 28, 'shampoo': 29, 'cap': 30, 'coffee_mug': 31, 'dry_battery': 32, 'cell_phone': 33, 'calculator': 34, 'pitcher': 35, 'plate': 36, 'food_box': 37, 'binder': 38, 'lemon': 39, 'garlic': 40, 'food_jar': 41, 'bell_pepper': 42, 'ball': 43, 'scissors': 44, 'hand_towel': 45, 'keyboard': 46}

# %%
# visulasioan of ROD
X  = plot_pic(ROD_dataloader,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ROD_rotated =continous_rotation_dataset (dt= 'ROD',annotations_list = imgs,
                               img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                               depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),                                
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                             
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                           )

ROD_rotated_dataloader = DataLoader(ROD_rotated, batch_size = BATCH_size,shuffle=True)

# %%
X  = plot_pic(ROD_rotated_dataloader ,labelmap =False,r =True,is_continous =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2.2 SynROD dataset
#
#
# ---
#
#
#
# 1.   SynROD  with label as a trainset

# %%
with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_train1.txt") as f:
    lines = f.read() 
    syn_imgs = lines.split('\n')
syn_imgs.remove('')

with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_test1.txt") as f:
    lines = f.read() 
    syn_imgs_test = lines.split('\n')
# syn_imgs.remove('')

syn_imgs_test.remove('')


syn_all_labels = [syn_imgs[i].split('/')[0] for i in range(len(syn_imgs))]
syn_all_labels=list(set(syn_all_labels))

syn_all_labels_test = [syn_imgs_test[i].split('/')[0] for i in range(len(syn_imgs_test))]
syn_all_labels_test=list(set(syn_all_labels_test))

# checking labesls oncistency 
if set(syn_all_labels) == set(syn_all_labels_test):
  print('rod and synrod labels match')
else :
  for i in syn_all_labels :
    if i not in  syn_all_labels_test:
      print(i,"exist in synrod trainset but not testset")
  for i in syn_all_labels_test :
    if i not in  syn_all_labels:
      print(i," exist in synrod testset but not trainset")

if set(syn_all_labels) == set(all_labels):
  print(' datasets labels completly match')
else:
  print('sth is wrong')
  for i in syn_all_labels :
    if i not in  all_labels:
      print(i,"does not exist in ROD")
  for i in all_labels :
    if i not in  syn_all_labels:
      print(i," does not exist in synrod")
# Out:
# rod and synrod labels match
# sth is wrong
# bell_papper does not exist in ROD
# bell_pepper  does not exist in synrod

# %%
SynROD_train = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs,label_map=labelmap,
                                  img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))

   

SynROD_test = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs_test,label_map=labelmap,img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
         transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]))

SynROD_rotated = continous_rotation_dataset(dt = 'SYNROD',annotations_list = syn_imgs,
                                 img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                 
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))





SynROD_dataloader_train = DataLoader(SynROD_train, batch_size=BATCH_size,shuffle=True)

SynROD_dataloader_test  =  DataLoader(SynROD_test, batch_size=BATCH_size,shuffle=True)

SynROD_rotated_dataloader = DataLoader(SynROD_rotated, batch_size=BATCH_size,shuffle=True)

# %%
X  = plot_pic(SynROD_dataloader_train ,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X  = plot_pic(SynROD_rotated_dataloader ,labelmap=False,r =True,is_continous =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # models

# %%
# helper function
def load_cnn_model(model_name, pretrained=True):
    "Load and return a convolutional neural network."
    assert model_name in ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']
    return models.__dict__[model_name](pretrained= True)

# %%
class E(nn.Module):
    def __init__(self, model_name):
      
        super(E, self).__init__()  
        # load cnn and remove 2 last layers
        cnn = load_cnn_model(model_name)
        modules = list(cnn.children())[:-2]  # remove 2 last layers
        
        self.cnn = nn.Sequential(*modules)             
    
        
    def forward(self, x):
        x = self.cnn(x)  
              
        return x

class feature_extract(nn.Module):
    def __init__(self):
      
        super(feature_extract, self).__init__()  
        self.E_c = E(model_name ='resnet18')
        self.E_d = E(model_name ='resnet18') 
                
    def forward(self,  images, depths):
        features_c = self.E_c(images)
        features_d = self.E_d(depths)        
        X = torch.cat([features_c,features_d], dim=1 )     
              
        return X

class main_head(nn.Module):
    def __init__(self,num_classes):
      super(main_head, self).__init__() 
      self.gap = nn.AdaptiveAvgPool2d(output_size=(1, 1)) 

      self.fc1 = nn.Sequential(
          nn.Dropout(p=0.5),
          nn.Linear(1024, 1000),
          nn.BatchNorm1d(1000, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(p=0.5)
      )
      self.fc2 = nn.Linear(1000, num_classes)
      self.initilise_weight()
      

    def forward(self, features):
        x = self.gap(features)
        x = torch.squeeze(x)
        x = self.fc1(x)
        x = self.fc2(x)   
        # x = F.softmax(x, dim=1)   
          
              
        return x
    
    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

class pretext(nn.Module):
    def __init__(self):
      super(pretext, self).__init__() 
      self.p_conv_1x1 = nn.Sequential(
          nn.Conv2d(1024 ,100, [1,1], stride=[1,1]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_conv_3x3 = nn.Sequential(
          nn.Conv2d(100, 100, [3,3], stride=[2,2]),
          nn.BatchNorm2d(100),
           nn.ReLU(inplace=True)
          )
      self.p_fc1 = nn.Sequential(
          nn.Linear(100*3*3, 360),
          nn.BatchNorm1d(360, affine=True),
           nn.ReLU(inplace=True),
          nn.Dropout(p=0)
          )     
      self.p_fc2 = nn.Linear(360, 2)
      self.initilise_weight()         
    def forward(self, features):      
        y = self.p_conv_1x1(features)
        y = self.p_conv_3x3(y)
        y = y.view(y.size(0), -1)
        y = self.p_fc1(y)
        y = self.p_fc2(y)        
        y =torch.atan2(y[:,0], y[:,1]) *180/3.14159265359         
       
        return y


    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

F_model = feature_extract()

main_model =  main_head(num_classes = len(labelmap))

pr_model =  pretext()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# # model training

# %%
loss_fn_1 = torch.nn.CrossEntropyLoss()

loss_fn_2 =torch.nn.MSELoss()


optimizer1 = torch.optim.SGD(F_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)
optimizer2 = torch.optim.SGD(main_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)
optimizer3 = torch.optim.SGD(pr_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)

# %%
F_model.to(device)
main_model.to(device)
pr_model.to(device)
# Out:
# pretext(
#   (p_conv_1x1): Sequential(
#     (0): Conv2d(1024, 100, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_conv_3x3): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_fc1): Sequential(
#     (0): Linear(in_features=900, out_features=360, bias=True)
#     (1): BatchNorm1d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0, inplace=False)
#   )
#   (p_fc2): Linear(in_features=360, out_features=2, bias=True)
# )

# %%
swtt_batch = math.ceil(len(syn_imgs)/BATCH_size)
def train_one_epoch(epoch_index):
    running_loss_1 = 0.
    last_loss_1 = 0.
    running_loss_2 = 0.
    last_loss_2 = 0.
    acc = 0
    tot = 0
    cor = 0
    acc2 = 0
    tot2 = 0
    cor2 = 0

    # Here, we use enumerate(training_loader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for i, data in enumerate(SynROD_dataloader_train ,0):


      # Zero your gradients for every batch!
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        optimizer3.zero_grad()
       
       
        image_s,depth_s,label_s = data
        image_s,depth_s,label_s = image_s.to(device),depth_s.to(device),label_s.to(device)
        

        # Make predictions for this batch
        feat = F_model(image_s,depth_s)
        outputs = main_model(feat)
       
        # if weight_ent >0:

        #         img_rgb, img_depth, _ = next(iter(ROD_dataloader))
        #         img_rgb, img_depth =img_rgb.to(device),img_depth.to(device)                
        #         logits = F_model(img_rgb, img_depth)
        #         logits_M = main_model(logits)
        #         loss_ent = entropy_loss(logits_M)

        # else:
        #     loss_ent =0
         

        loss_1 = loss_fn_1(outputs,label_s) 
        
       
        pr =  F.softmax(outputs, dim=1) 
        _, pr= torch.max( pr.data, 1)
        _, real= torch.max(label_s.data, 1)

        tot += label_s.size(0)
        cor += (pr ==  real).sum().item()
        acc = 100 * cor / tot    
        

        image_s_r,depth_s_r,rotation_syn = next(iter(SynROD_rotated_dataloader))
        image_rod_r,depth_rod_r,rotation_rod = next(iter(ROD_rotated_dataloader) )       
        
        image_s_r,depth_s_r,rotation_syn =  image_s_r.to(device),depth_s_r.to(device),rotation_syn.to(device)      
        image_rod_r,depth_rod_r,rotation_rod = image_rod_r.to(device),depth_rod_r.to(device),rotation_rod.to(device)
        # print(Fore.CYAN,',rotation_rod',rotation_rod)
        feat2 = F_model( image_s_r,depth_s_r)
        feat3= F_model(image_rod_r,depth_rod_r)
        
        outputs2 =pr_model( feat2 )        
        outputs3 =  pr_model(feat3)
        outputs2[outputs2<0] =outputs2[outputs2<0] +360
        outputs3[outputs3<0] =outputs3[outputs3<0] +360
        outputs2 =outputs2 *3.14159265359 /180
        outputs3 =outputs3 *3.14159265359 /180

        out2_sin = torch.sin(outputs2)
        out2_cos = torch.cos(outputs2)
        
        out3_sin = torch.sin(outputs3)
        out3_cos = torch.cos(outputs3)

        rotation_syn=  rotation_syn *3.14159265359 /180
        rotation_rod =    rotation_rod  *3.14159265359 /180
        
        rotation_syn_sin = torch.sin(rotation_syn)
        rotation_syn_cos = torch.cos(rotation_syn)

        rotation_rod_sin = torch.sin(rotation_rod)
        rotation_rod_cos = torch.cos(rotation_rod)
        


        loss_2 = loss_fn_2( out2_sin,rotation_syn_sin) + loss_fn_2( out2_cos,rotation_syn_cos) +loss_fn_2( out3_cos,rotation_rod_cos) + loss_fn_2( out3_sin,rotation_rod_sin )
             
        loss =  loss_1+ weight_rot *loss_2        
        loss.backward()


        optimizer1.step()
        optimizer2.step()
        optimizer3.step()
         
      
        

        running_loss_2 += loss_2.item()  
        running_loss_1 += loss_1.item()      
        
        
       

        if i % 50 == 49:
          last_loss_1 = running_loss_1 
          last_loss_2 = running_loss_2 
          print(Fore.BLUE,'  batch {}/ {} loss_1: {} loss_2: {} and source_train_acc is {}  time is {}'.format(i + 1,swtt_batch,'%.6f' % last_loss_1,
                                                                     '%.6f' %last_loss_2,   '%.4f'% acc,   '%.6f'%(time.time() - start_time)))
      
          running_loss_1 = 0.
          running_loss_2 = 0. 

        
    
   
    # model_name = F_model.module._get_name() if isinstance(F_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': F_model.state_dict(),
    #               'optimizer_state_dict': optimizer1.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = main_model.module._get_name() if isinstance(main_model, torch.nn.DataParallel) else main_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': main_model.state_dict(),
    #               'optimizer_state_dict': optimizer2.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = pr_model.module._get_name() if isinstance(pr_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint2 = {'epoch':epoch,
    #               'model_state_dict': pr_model.state_dict(),
    #               'optimizer_state_dict': optimizer3.state_dict(),
    #                'loss':  loss
                   
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint2,fpath)
    



    return last_loss_1+last_loss_2,acc

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
epoch_number = 0
import time
start_time = time.time()

EPOCHS = 20
best_vloss = 1_000_000.
source_train_loss =[]
source_train_accuracy =[]

source_test_loss =[]
source_test_accuracy =[]



target_test_loss = []
target_test_accuracy =[]



for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    F_model.train(True)
    main_model.train(True)
    pr_model.train(True)
   

    avg_loss,acc= train_one_epoch(epoch_number)
    source_train_loss.append(avg_loss)
    source_train_accuracy.append(acc)

    # We don't need gradients on to do reporting
    F_model.train(False)
    main_model.train(False)
    pr_model.train(False)
    
    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(SynROD_dataloader_test ):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    source_test_loss.append(avg_vloss)
    source_test_accuracy.append(accuracy)


    print(Fore.GREEN,'for main taks,loss source_test {},..... acc source_test {}'.format(avg_vloss, accuracy))   
   

    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(ROD_dataloader):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    target_test_loss.append(avg_vloss)
    target_test_accuracy.append(accuracy)

    print(Fore.RED,'for main taks, loss target_test {} , .... acc target_test {}'.format( avg_vloss, accuracy))
 
    try:
            E= [i for i in range(len(target_test_loss))]

            fig, (axs, ax2) = plt.subplots(2)
            try:     
              t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              t_target_loss = [target_test_loss[i]  for i  in range(len(target_test_loss))]
            try:
                  s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                  s_test_loss =  [source_test_loss[i]  for i  in range(len(target_test_loss))]

            axs.plot(E, t_target_loss,label="target")
            axs.plot(E,s_test_loss,label="source_test")
            
            axs.set_xlabel('epoch')
            axs.set_ylabel('loss')
            axs.grid(True)
            
            try:
              t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                t_target_acc = [target_test_accuracy[i]  for i  in range(len(target_test_loss))]

            try:
                s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                s_test_acc =  [source_test_accuracy[i]  for i  in range(len(target_test_loss))]

            
            

            ax2.plot(E, t_target_acc,label="target" )
            ax2.plot(E,s_test_acc,label="source_test")

            
            ax2.set_xlabel('epoch')
            ax2.set_ylabel('accuracy')
            ax2.grid(True)

            fig.tight_layout()
          
            plt.savefig('var11.png')

    except:
            print(Fore.RED,'sth was wrng with saving')


    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        F_model_path = 'result/aux_task/F_model1_{}_{}'.format(timestamp, epoch_number)
        torch.save(F_model.state_dict(), F_model_path)

        M_model_path = 'result/aux_task/main_model1_{}_{}'.format(timestamp, epoch_number)
        torch.save(main_model.state_dict(), M_model_path)

        Fr_model_path = 'result/aux_task/pr_model1_{}_{}'.format(timestamp, epoch_number)
        torch.save(pr_model.state_dict(),Fr_model_path)

    epoch_number += 1
# Out:
# EPOCH 1:
#    batch 50/ 586 loss_1: 193.614714 loss_2: 201.424477 and source_train_acc is 2.6562  time is 131.083511
#    batch 100/ 586 loss_1: 190.426454 loss_2: 196.948321 and source_train_acc is 3.1250  time is 250.096128
#    batch 150/ 586 loss_1: 186.251028 loss_2: 200.826918 and source_train_acc is 4.4896  time is 365.134121
#    batch 200/ 586 loss_1: 183.447194 loss_2: 198.920150 and source_train_acc is 5.6328  time is 480.403313
#    batch 250/ 586 loss_1: 179.071160 loss_2: 199.874848 and source_train_acc is 7.4938  time is 595.286276
#    batch 300/ 586 loss_1: 175.274419 loss_2: 197.079968 and source_train_acc is 9.2396  time is 710.890328
#    batch 350/ 586 loss_1: 172.482703 loss_2: 195.951193 and source_train_acc is 10.7321  time is 825.882194
#    batch 400/ 586 loss_1: 167.837791 loss_2: 196.830057 and source_train_acc is 12.5703  time is 940.996112
#    batch 450/ 586 loss_1: 163.635405 loss_2: 195.064514 and source_train_acc is 14.2535  time is 1055.550472
#    batch 500/ 586 loss_1: 160.689879 loss_2: 199.518278 and source_train_acc is 15.7219  time is 1170.483140
#    batch 550/ 586 loss_1: 155.129813 loss_2: 193.199417 and source_train_acc is 17.2273  time is 1284.416194
#  for main taks,loss source_test 3.0689854621887207,..... acc source_test 37.12131596984236
#  for main taks, loss target_test 3.3586301803588867 , .... acc target_test 19.642197314940265
# EPOCH 2:
#    batch 50/ 586 loss_1: 147.492926 loss_2: 190.794148 and source_train_acc is 37.4062  time is 1813.518885
#    batch 100/ 586 loss_1: 144.514365 loss_2: 190.312562 and source_train_acc is 37.3281  time is 1928.101497
#    batch 150/ 586 loss_1: 141.603130 loss_2: 184.865883 and source_train_acc is 38.1771  time is 2043.007759
#    batch 200/ 586 loss_1: 136.485638 loss_2: 175.733711 and source_train_acc is 38.9688  time is 2156.282840
#    batch 250/ 586 loss_1: 135.102361 loss_2: 175.480658 and source_train_acc is 39.4875  time is 2270.260089
#    batch 300/ 586 loss_1: 131.827971 loss_2: 164.983615 and source_train_acc is 40.4375  time is 2384.149492
#    batch 350/ 586 loss_1: 127.648196 loss_2: 144.957902 and source_train_acc is 41.2634  time is 2497.515961
#    batch 400/ 586 loss_1: 125.091395 loss_2: 124.881554 and source_train_acc is 41.9141  time is 2611.912257
#    batch 450/ 586 loss_1: 121.681515 loss_2: 117.255419 and source_train_acc is 42.6944  time is 2726.036512
#    batch 500/ 586 loss_1: 118.623419 loss_2: 111.803051 and source_train_acc is 43.4438  time is 2839.859504
#    batch 550/ 586 loss_1: 114.970823 loss_2: 104.899375 and source_train_acc is 44.2131  time is 2952.941082
#  for main taks,loss source_test 2.593445062637329,..... acc source_test 42.371487320082245
#  for main taks, loss target_test 3.070997476577759 , .... acc target_test 21.1078950609681
# EPOCH 3:
#    batch 50/ 586 loss_1: 115.283938 loss_2: 136.805006 and source_train_acc is 51.1562  time is 3483.532521
#    batch 100/ 586 loss_1: 111.071574 loss_2: 109.721835 and source_train_acc is 52.0625  time is 3597.828347
#    batch 150/ 586 loss_1: 108.383291 loss_2: 100.855935 and source_train_acc is 52.8958  time is 3711.986603
#    batch 200/ 586 loss_1: 104.614000 loss_2: 99.070508 and source_train_acc is 53.5469  time is 3825.857035
#    batch 250/ 586 loss_1: 102.994535 loss_2: 96.077212 and source_train_acc is 54.0312  time is 3940.326823
#    batch 300/ 586 loss_1: 100.368704 loss_2: 91.965938 and source_train_acc is 54.9062  time is 4055.444041
#    batch 350/ 586 loss_1: 98.490312 loss_2: 84.415262 and source_train_acc is 55.4732  time is 4168.945837
#    batch 400/ 586 loss_1: 95.619044 loss_2: 82.066563 and source_train_acc is 56.1250  time is 4282.535460
#    batch 450/ 586 loss_1: 93.500891 loss_2: 76.650635 and source_train_acc is 56.6597  time is 4396.063753
#    batch 500/ 586 loss_1: 91.305229 loss_2: 77.477640 and source_train_acc is 57.2188  time is 4509.977843
#    batch 550/ 586 loss_1: 90.469207 loss_2: 72.427785 and source_train_acc is 57.6335  time is 4624.956222
#  for main taks,loss source_test 2.139519453048706,..... acc source_test 50.253598355037695
#  for main taks, loss target_test 2.8654139041900635 , .... acc target_test 26.576548836063555
# EPOCH 4:
#    batch 50/ 586 loss_1: 87.233040 loss_2: 73.125288 and source_train_acc is 63.7500  time is 5157.228140
#    batch 100/ 586 loss_1: 85.427892 loss_2: 69.240485 and source_train_acc is 64.1562  time is 5271.843432
#    batch 150/ 586 loss_1: 85.866181 loss_2: 68.420557 and source_train_acc is 64.1875  time is 5386.314763
#    batch 200/ 586 loss_1: 82.146067 loss_2: 66.939510 and source_train_acc is 64.7188  time is 5499.974968
#    batch 250/ 586 loss_1: 82.188351 loss_2: 67.184767 and source_train_acc is 65.2375  time is 5614.348361
#    batch 300/ 586 loss_1: 80.805702 loss_2: 66.738833 and source_train_acc is 65.3646  time is 5728.273906
#    batch 350/ 586 loss_1: 79.579964 loss_2: 63.930474 and source_train_acc is 65.6250  time is 5841.037902
#    batch 400/ 586 loss_1: 77.384084 loss_2: 62.231122 and source_train_acc is 66.0312  time is 5954.716697
#    batch 450/ 586 loss_1: 77.563405 loss_2: 62.346938 and source_train_acc is 66.2222  time is 6069.392972
#    batch 500/ 586 loss_1: 75.692169 loss_2: 60.728340 and source_train_acc is 66.5500  time is 6183.035053
#    batch 550/ 586 loss_1: 74.038347 loss_2: 60.313787 and source_train_acc is 66.8580  time is 6297.814571
#  for main taks,loss source_test 1.901344656944275,..... acc source_test 54.76353666895134
#  for main taks, loss target_test 2.7296905517578125 , .... acc target_test 29.554132282300777
# EPOCH 5:
#    batch 50/ 586 loss_1: 72.096329 loss_2: 58.176801 and source_train_acc is 70.4688  time is 6825.711207
#    batch 100/ 586 loss_1: 72.951369 loss_2: 57.039387 and source_train_acc is 70.3906  time is 6939.493331
#    batch 150/ 586 loss_1: 71.646686 loss_2: 61.555029 and source_train_acc is 70.8333  time is 7053.631746
#    batch 200/ 586 loss_1: 69.954329 loss_2: 60.003360 and source_train_acc is 71.5859  time is 7165.586191
#    batch 250/ 586 loss_1: 70.292607 loss_2: 62.812939 and source_train_acc is 71.7125  time is 7278.810841
#    batch 300/ 586 loss_1: 69.730228 loss_2: 57.605030 and source_train_acc is 71.6927  time is 7391.657733
#    batch 350/ 586 loss_1: 69.328399 loss_2: 58.334452 and source_train_acc is 71.7188  time is 7505.112923
#    batch 400/ 586 loss_1: 67.553152 loss_2: 55.241376 and source_train_acc is 71.9531  time is 7617.692946
#    batch 450/ 586 loss_1: 64.569869 loss_2: 52.354210 and source_train_acc is 72.3090  time is 7731.314637
#    batch 500/ 586 loss_1: 65.362895 loss_2: 54.065435 and source_train_acc is 72.5938  time is 7845.222982
#    batch 550/ 586 loss_1: 64.056821 loss_2: 53.501136 and source_train_acc is 72.7983  time is 7957.156474
#  for main taks,loss source_test 1.7729495763778687,..... acc source_test 57.94379712131597
#  for main taks, loss target_test 2.578558921813965 , .... acc target_test 33.65562261362237
# EPOCH 6:
#    batch 50/ 586 loss_1: 63.514697 loss_2: 53.574687 and source_train_acc is 74.6250  time is 8486.455556
#    batch 100/ 586 loss_1: 62.766887 loss_2: 51.943166 and source_train_acc is 75.3125  time is 8600.981635
#    batch 150/ 586 loss_1: 62.354797 loss_2: 51.522944 and source_train_acc is 75.6771  time is 8714.583061
#    batch 200/ 586 loss_1: 61.668851 loss_2: 52.224840 and source_train_acc is 75.8516  time is 8827.994290
#    batch 250/ 586 loss_1: 61.773418 loss_2: 48.703830 and source_train_acc is 75.8750  time is 8942.358708
#    batch 300/ 586 loss_1: 62.481534 loss_2: 48.530634 and source_train_acc is 76.0260  time is 9055.997245
#    batch 350/ 586 loss_1: 60.278547 loss_2: 48.331484 and source_train_acc is 76.1161  time is 9170.006741
#    batch 400/ 586 loss_1: 60.180831 loss_2: 53.315802 and source_train_acc is 76.3477  time is 9283.406811
#    batch 450/ 586 loss_1: 61.412110 loss_2: 55.301695 and source_train_acc is 76.2951  time is 9395.860667
#    batch 500/ 586 loss_1: 59.014951 loss_2: 51.925522 and source_train_acc is 76.4625  time is 9509.750885
#    batch 550/ 586 loss_1: 60.745604 loss_2: 50.866635 and source_train_acc is 76.3920  time is 9623.034061
#  for main taks,loss source_test 1.7259117364883423,..... acc source_test 58.60178204249486
#  for main taks, loss target_test 2.6682517528533936 , .... acc target_test 31.65106540214312
# EPOCH 7:
#    batch 50/ 586 loss_1: 58.748426 loss_2: 47.885898 and source_train_acc is 78.0312  time is 10150.806625
#    batch 100/ 586 loss_1: 57.611439 loss_2: 49.243746 and source_train_acc is 78.0156  time is 10265.650236
#    batch 150/ 586 loss_1: 57.385283 loss_2: 49.054092 and source_train_acc is 78.4688  time is 10378.078172
#    batch 200/ 586 loss_1: 57.705032 loss_2: 54.080317 and source_train_acc is 78.8594  time is 10490.846307
#    batch 250/ 586 loss_1: 58.456408 loss_2: 48.476647 and source_train_acc is 78.7687  time is 10603.718475
#    batch 300/ 586 loss_1: 55.515887 loss_2: 44.772209 and source_train_acc is 78.9427  time is 10716.973247
#    batch 350/ 586 loss_1: 56.954958 loss_2: 47.740451 and source_train_acc is 78.8616  time is 10829.530380
#    batch 400/ 586 loss_1: 56.852586 loss_2: 44.252801 and source_train_acc is 78.8750  time is 10943.207758
#    batch 450/ 586 loss_1: 56.946133 loss_2: 47.844097 and source_train_acc is 78.8403  time is 11056.581189
#    batch 500/ 586 loss_1: 54.552234 loss_2: 44.093964 and source_train_acc is 78.9125  time is 11170.497531
#    batch 550/ 586 loss_1: 62.708148 loss_2: 72.829131 and source_train_acc is 78.6364  time is 11283.239255
#  for main taks,loss source_test 1.7833367586135864,..... acc source_test 56.504455106237145
#  for main taks, loss target_test 2.574699878692627 , .... acc target_test 33.153713511516195
# EPOCH 8:
#    batch 50/ 586 loss_1: 61.351230 loss_2: 64.176648 and source_train_acc is 77.3438  time is 11810.927242
#    batch 100/ 586 loss_1: 59.297032 loss_2: 58.651420 and source_train_acc is 77.7969  time is 11925.049047
#    batch 150/ 586 loss_1: 57.529703 loss_2: 50.506410 and source_train_acc is 78.3125  time is 12040.004570
#    batch 200/ 586 loss_1: 55.996341 loss_2: 49.234829 and source_train_acc is 78.8203  time is 12152.864639
#    batch 250/ 586 loss_1: 55.666462 loss_2: 48.397815 and source_train_acc is 79.1437  time is 12265.756559
#    batch 300/ 586 loss_1: 54.808128 loss_2: 46.278919 and source_train_acc is 79.3177  time is 12378.161366
#    batch 350/ 586 loss_1: 54.001141 loss_2: 44.375952 and source_train_acc is 79.4196  time is 12491.626885
#    batch 400/ 586 loss_1: 54.623858 loss_2: 46.249395 and source_train_acc is 79.6289  time is 12604.327220
#    batch 450/ 586 loss_1: 53.633692 loss_2: 42.661518 and source_train_acc is 79.8403  time is 12718.331881
#    batch 500/ 586 loss_1: 53.108781 loss_2: 42.992103 and source_train_acc is 79.9750  time is 12831.554671
#    batch 550/ 586 loss_1: 51.437522 loss_2: 42.566108 and source_train_acc is 80.1648  time is 12945.978673
#  for main taks,loss source_test 1.7061840295791626,..... acc source_test 58.34132967786155
#  for main taks, loss target_test 2.633004665374756 , .... acc target_test 33.72028574947654
# EPOCH 9:
#    batch 50/ 586 loss_1: 51.677640 loss_2: 43.221459 and source_train_acc is 82.0625  time is 13473.228394
#    batch 100/ 586 loss_1: 51.359668 loss_2: 41.453088 and source_train_acc is 82.3906  time is 13588.490351
#    batch 150/ 586 loss_1: 49.481491 loss_2: 40.291320 and source_train_acc is 82.7292  time is 13701.746167
#    batch 200/ 586 loss_1: 52.392139 loss_2: 45.907595 and source_train_acc is 82.4453  time is 13813.037524
#    batch 250/ 586 loss_1: 50.992411 loss_2: 43.323730 and source_train_acc is 82.5875  time is 13926.946047
#    batch 300/ 586 loss_1: 50.827108 loss_2: 41.187648 and source_train_acc is 82.5781  time is 14039.609085
#    batch 350/ 586 loss_1: 50.969745 loss_2: 43.147011 and source_train_acc is 82.5446  time is 14152.225886
#    batch 400/ 586 loss_1: 50.047749 loss_2: 41.921641 and source_train_acc is 82.6562  time is 14265.579735
#    batch 450/ 586 loss_1: 49.309531 loss_2: 39.540472 and source_train_acc is 82.7847  time is 14377.854033
#    batch 500/ 586 loss_1: 51.146066 loss_2: 39.626125 and source_train_acc is 82.7906  time is 14490.942745
#    batch 550/ 586 loss_1: 50.231913 loss_2: 39.610873 and source_train_acc is 82.8466  time is 14603.960703
#  for main taks,loss source_test 1.6347914934158325,..... acc source_test 61.41192597669637
#  for main taks, loss target_test 2.664165496826172 , .... acc target_test 32.938169725335634
# EPOCH 10:
#    batch 50/ 586 loss_1: 48.538853 loss_2: 38.663763 and source_train_acc is 84.8438  time is 15127.294262
#    batch 100/ 586 loss_1: 48.633632 loss_2: 37.473605 and source_train_acc is 84.6562  time is 15240.512681
#    batch 150/ 586 loss_1: 47.512688 loss_2: 39.518109 and source_train_acc is 84.8021  time is 15354.468517
#    batch 200/ 586 loss_1: 48.386720 loss_2: 36.778313 and source_train_acc is 84.8125  time is 15467.143477
#    batch 250/ 586 loss_1: 48.019871 loss_2: 38.647680 and source_train_acc is 84.8750  time is 15579.600754
#    batch 300/ 586 loss_1: 48.212237 loss_2: 38.600785 and source_train_acc is 84.8802  time is 15692.306515
#    batch 350/ 586 loss_1: 48.599836 loss_2: 39.468170 and source_train_acc is 84.8795  time is 15805.119939
#    batch 400/ 586 loss_1: 46.958357 loss_2: 35.692322 and source_train_acc is 85.0586  time is 15917.752764
#    batch 450/ 586 loss_1: 47.466396 loss_2: 39.213299 and source_train_acc is 85.0174  time is 16030.190236
#    batch 500/ 586 loss_1: 48.133326 loss_2: 36.802054 and source_train_acc is 84.9906  time is 16143.858379
#    batch 550/ 586 loss_1: 48.546238 loss_2: 38.312718 and source_train_acc is 84.9261  time is 16256.112666
#  for main taks,loss source_test 1.7553514242172241,..... acc source_test 58.656614119259764
#  for main taks, loss target_test 2.6669435501098633 , .... acc target_test 32.9104569528267
# EPOCH 11:
#    batch 50/ 586 loss_1: 49.427003 loss_2: 43.548804 and source_train_acc is 84.3750  time is 16779.750318
#    batch 100/ 586 loss_1: 48.022952 loss_2: 42.502671 and source_train_acc is 85.2812  time is 16892.408402
#    batch 150/ 586 loss_1: 46.512800 loss_2: 38.337581 and source_train_acc is 85.8229  time is 17004.790815
#    batch 200/ 586 loss_1: 48.369881 loss_2: 35.679504 and source_train_acc is 85.6328  time is 17116.697321
#    batch 250/ 586 loss_1: 46.264132 loss_2: 35.765828 and source_train_acc is 85.8750  time is 17229.290399
#    batch 300/ 586 loss_1: 46.353262 loss_2: 36.561837 and source_train_acc is 85.9792  time is 17340.996523
#    batch 350/ 586 loss_1: 46.514781 loss_2: 39.796061 and source_train_acc is 86.1250  time is 17454.004660
#    batch 400/ 586 loss_1: 48.770185 loss_2: 42.077592 and source_train_acc is 86.0430  time is 17567.702670
#    batch 450/ 586 loss_1: 47.168567 loss_2: 42.584895 and source_train_acc is 86.0729  time is 17680.852114
#    batch 500/ 586 loss_1: 47.994259 loss_2: 37.801960 and source_train_acc is 86.0000  time is 17793.939250
#    batch 550/ 586 loss_1: 48.152677 loss_2: 38.560150 and source_train_acc is 85.8722  time is 17906.928211
#  for main taks,loss source_test 1.7285667657852173,..... acc source_test 60.52090472926662
#  for main taks, loss target_test 2.7479727268218994 , .... acc target_test 31.133760315309768
# EPOCH 12:
#    batch 50/ 586 loss_1: 46.275319 loss_2: 39.564136 and source_train_acc is 87.0938  time is 18429.583191
#    batch 100/ 586 loss_1: 46.542209 loss_2: 40.172123 and source_train_acc is 87.0625  time is 18544.054139
#    batch 150/ 586 loss_1: 46.648401 loss_2: 37.443303 and source_train_acc is 87.1458  time is 18656.327883
#    batch 200/ 586 loss_1: 46.931996 loss_2: 36.864458 and source_train_acc is 86.9141  time is 18768.830058
#    batch 250/ 586 loss_1: 46.439607 loss_2: 35.909116 and source_train_acc is 86.9688  time is 18882.442991
#    batch 300/ 586 loss_1: 54.036361 loss_2: 58.250380 and source_train_acc is 86.4062  time is 18994.895210
#    batch 350/ 586 loss_1: 52.250437 loss_2: 44.989870 and source_train_acc is 86.1473  time is 19107.925065
#    batch 400/ 586 loss_1: 50.805409 loss_2: 47.818933 and source_train_acc is 86.0742  time is 19220.642864
#    batch 450/ 586 loss_1: 50.542736 loss_2: 47.723444 and source_train_acc is 85.9236  time is 19333.719323
#    batch 500/ 586 loss_1: 51.842683 loss_2: 48.767504 and source_train_acc is 85.7687  time is 19447.618344
#    batch 550/ 586 loss_1: 50.286255 loss_2: 41.913479 and source_train_acc is 85.7330  time is 19560.563802
#  for main taks,loss source_test 1.872588038444519,..... acc source_test 55.558601782042494
#  for main taks, loss target_test 2.7515337467193604 , .... acc target_test 32.78113068111836
# EPOCH 13:
#    batch 50/ 586 loss_1: 47.933059 loss_2: 41.620555 and source_train_acc is 86.9062  time is 20085.344619
#    batch 100/ 586 loss_1: 47.723569 loss_2: 38.859757 and source_train_acc is 87.1250  time is 20199.405021
#    batch 150/ 586 loss_1: 47.840758 loss_2: 38.736827 and source_train_acc is 87.1979  time is 20312.533154
#    batch 200/ 586 loss_1: 50.208781 loss_2: 43.928750 and source_train_acc is 86.9219  time is 20424.239133
#    batch 250/ 586 loss_1: 48.579991 loss_2: 39.673524 and source_train_acc is 86.7562  time is 20536.383766
#    batch 300/ 586 loss_1: 47.061561 loss_2: 36.624259 and source_train_acc is 86.9115  time is 20650.065394
#    batch 350/ 586 loss_1: 47.268971 loss_2: 37.992241 and source_train_acc is 86.9062  time is 20763.515947
#    batch 400/ 586 loss_1: 47.216488 loss_2: 39.005903 and source_train_acc is 86.9570  time is 20876.526995
#    batch 450/ 586 loss_1: 48.288040 loss_2: 39.577264 and source_train_acc is 86.8646  time is 20989.405825
#    batch 500/ 586 loss_1: 48.285045 loss_2: 39.263942 and source_train_acc is 86.8781  time is 21102.385099
#    batch 550/ 586 loss_1: 48.360120 loss_2: 39.364347 and source_train_acc is 86.9375  time is 21216.316787
#  for main taks,loss source_test 1.9200576543807983,..... acc source_test 57.17614804660727
#  for main taks, loss target_test 2.812469005584717 , .... acc target_test 32.824239438354475
# EPOCH 14:
#    batch 50/ 586 loss_1: 51.058810 loss_2: 48.234782 and source_train_acc is 86.1875  time is 21742.753124
#    batch 100/ 586 loss_1: 49.742030 loss_2: 44.031225 and source_train_acc is 86.7031  time is 21854.927170
#    batch 150/ 586 loss_1: 47.583910 loss_2: 43.207677 and source_train_acc is 86.7917  time is 21967.140364
#    batch 200/ 586 loss_1: 48.452616 loss_2: 41.955398 and source_train_acc is 87.0078  time is 22080.331583
#    batch 250/ 586 loss_1: 50.180696 loss_2: 42.677544 and source_train_acc is 86.9000  time is 22193.855980
#    batch 300/ 586 loss_1: 48.941383 loss_2: 44.655789 and source_train_acc is 87.0156  time is 22307.043327
#    batch 350/ 586 loss_1: 48.957946 loss_2: 42.398215 and source_train_acc is 87.0580  time is 22419.078190
#    batch 400/ 586 loss_1: 47.379390 loss_2: 36.627103 and source_train_acc is 87.1992  time is 22531.287688
#    batch 450/ 586 loss_1: 47.276529 loss_2: 34.492577 and source_train_acc is 87.2222  time is 22644.447970
#    batch 500/ 586 loss_1: 47.274316 loss_2: 37.199743 and source_train_acc is 87.2781  time is 22756.363608
#    batch 550/ 586 loss_1: 46.605802 loss_2: 38.467841 and source_train_acc is 87.4716  time is 22870.226813
#  for main taks,loss source_test 1.9761838912963867,..... acc source_test 57.77930089102125
#  for main taks, loss target_test 2.8897383213043213 , .... acc target_test 28.4548589727799
# EPOCH 15:
#    batch 50/ 586 loss_1: 47.906259 loss_2: 38.545068 and source_train_acc is 88.3438  time is 23392.862431
#    batch 100/ 586 loss_1: 47.021334 loss_2: 37.049718 and source_train_acc is 88.4219  time is 23505.665396
#    batch 150/ 586 loss_1: 47.662847 loss_2: 38.839681 and source_train_acc is 88.3021  time is 23618.196568
#    batch 200/ 586 loss_1: 47.661427 loss_2: 36.907420 and source_train_acc is 88.3359  time is 23731.123304
#    batch 250/ 586 loss_1: 47.323086 loss_2: 39.097474 and source_train_acc is 88.4250  time is 23844.316293
#    batch 300/ 586 loss_1: 47.598341 loss_2: 38.960826 and source_train_acc is 88.4427  time is 23956.159017
#    batch 350/ 586 loss_1: 48.149900 loss_2: 36.045270 and source_train_acc is 88.4375  time is 24068.864121
#    batch 400/ 586 loss_1: 46.458589 loss_2: 35.512122 and source_train_acc is 88.5859  time is 24181.749426
#    batch 450/ 586 loss_1: 48.157493 loss_2: 39.467826 and source_train_acc is 88.5521  time is 24294.449188
#    batch 500/ 586 loss_1: 47.915328 loss_2: 36.891201 and source_train_acc is 88.5062  time is 24407.398879
#    batch 550/ 586 loss_1: 49.776469 loss_2: 43.091002 and source_train_acc is 88.4489  time is 24519.928372
#  for main taks,loss source_test 1.8655623197555542,..... acc source_test 60.21932830705963
#  for main taks, loss target_test 2.9432830810546875 , .... acc target_test 27.250892967114176
# EPOCH 16:
#    batch 50/ 586 loss_1: 47.048730 loss_2: 39.409603 and source_train_acc is 89.2812  time is 25043.267573
#    batch 100/ 586 loss_1: 48.465687 loss_2: 40.078715 and source_train_acc is 89.1719  time is 25157.663187
#    batch 150/ 586 loss_1: 47.288386 loss_2: 39.231976 and source_train_acc is 89.5417  time is 25270.388136
#    batch 200/ 586 loss_1: 47.208503 loss_2: 36.229776 and source_train_acc is 89.4141  time is 25383.720306
#    batch 250/ 586 loss_1: 46.968837 loss_2: 36.173483 and source_train_acc is 89.5125  time is 25496.325034
#    batch 300/ 586 loss_1: 46.996716 loss_2: 34.732582 and source_train_acc is 89.5365  time is 25608.771058
#    batch 350/ 586 loss_1: 47.391167 loss_2: 34.506036 and source_train_acc is 89.5357  time is 25723.140028
#    batch 400/ 586 loss_1: 49.169094 loss_2: 39.165585 and source_train_acc is 89.4336  time is 25836.369411
#    batch 450/ 586 loss_1: 47.526189 loss_2: 36.039834 and source_train_acc is 89.3993  time is 25949.611129
#    batch 500/ 586 loss_1: 52.359150 loss_2: 53.773929 and source_train_acc is 89.2313  time is 26063.106066
#    batch 550/ 586 loss_1: 50.188919 loss_2: 40.416885 and source_train_acc is 89.1818  time is 26175.420538
#  for main taks,loss source_test 2.0328662395477295,..... acc source_test 57.066483893077454
#  for main taks, loss target_test 3.0173323154449463 , .... acc target_test 29.163074270230325
# EPOCH 17:
#    batch 50/ 586 loss_1: 47.724776 loss_2: 38.316974 and source_train_acc is 89.5000  time is 26701.353298
#    batch 100/ 586 loss_1: 48.417829 loss_2: 38.275465 and source_train_acc is 89.3438  time is 26814.300946
#    batch 150/ 586 loss_1: 47.215024 loss_2: 35.999937 and source_train_acc is 89.6354  time is 26927.152740
#    batch 200/ 586 loss_1: 47.821243 loss_2: 37.486475 and source_train_acc is 89.6094  time is 27039.323876
#    batch 250/ 586 loss_1: 47.779540 loss_2: 38.274677 and source_train_acc is 89.6875  time is 27152.144408
#    batch 300/ 586 loss_1: 49.746573 loss_2: 40.593798 and source_train_acc is 89.5833  time is 27265.209973
#    batch 350/ 586 loss_1: 52.429342 loss_2: 48.483718 and source_train_acc is 89.3393  time is 27378.630609
#    batch 400/ 586 loss_1: 51.087907 loss_2: 45.779763 and source_train_acc is 89.2852  time is 27491.483205
#    batch 450/ 586 loss_1: 50.479503 loss_2: 40.115700 and source_train_acc is 89.2326  time is 27604.519814
#    batch 500/ 586 loss_1: 48.263870 loss_2: 35.619993 and source_train_acc is 89.2781  time is 27718.107676
#    batch 550/ 586 loss_1: 47.921734 loss_2: 33.010435 and source_train_acc is 89.2784  time is 27832.619875
#  for main taks,loss source_test 2.0682373046875,..... acc source_test 58.94448252227553
#  for main taks, loss target_test 3.0048861503601074 , .... acc target_test 28.614977213942606
# EPOCH 18:
#    batch 50/ 586 loss_1: 46.891424 loss_2: 33.395983 and source_train_acc is 91.0000  time is 28360.376068
#    batch 100/ 586 loss_1: 48.982920 loss_2: 37.932413 and source_train_acc is 90.2500  time is 28474.345157
#    batch 150/ 586 loss_1: 47.880760 loss_2: 35.268546 and source_train_acc is 90.1354  time is 28586.613984
#    batch 200/ 586 loss_1: 53.040028 loss_2: 55.710056 and source_train_acc is 89.7188  time is 28699.931940
#    batch 250/ 586 loss_1: 53.234347 loss_2: 45.661862 and source_train_acc is 89.4562  time is 28812.452349
#    batch 300/ 586 loss_1: 50.778412 loss_2: 41.422270 and source_train_acc is 89.4583  time is 28925.188981
#    batch 350/ 586 loss_1: 50.080048 loss_2: 40.940973 and source_train_acc is 89.5000  time is 29037.243564
#    batch 400/ 586 loss_1: 50.554564 loss_2: 40.804680 and source_train_acc is 89.5000  time is 29152.094088
#    batch 450/ 586 loss_1: 52.125687 loss_2: 40.256019 and source_train_acc is 89.4931  time is 29265.562546
#    batch 500/ 586 loss_1: 50.134098 loss_2: 40.029536 and source_train_acc is 89.4906  time is 29378.788392
#    batch 550/ 586 loss_1: 50.241145 loss_2: 39.496935 and source_train_acc is 89.5000  time is 29491.903073
#  for main taks,loss source_test 2.250718355178833,..... acc source_test 51.706648389307745
#  for main taks, loss target_test 3.078688621520996 , .... acc target_test 26.505727306318512
# EPOCH 19:
#    batch 50/ 586 loss_1: 52.818756 loss_2: 48.781177 and source_train_acc is 88.3125  time is 30019.224725
#    batch 100/ 586 loss_1: 51.460139 loss_2: 42.417900 and source_train_acc is 89.1250  time is 30133.592720
#    batch 150/ 586 loss_1: 50.676852 loss_2: 41.181908 and source_train_acc is 89.2083  time is 30246.629636
#    batch 200/ 586 loss_1: 51.580792 loss_2: 47.255469 and source_train_acc is 89.2188  time is 30359.981839
#    batch 250/ 586 loss_1: 50.905758 loss_2: 43.228311 and source_train_acc is 89.2438  time is 30473.753476
#    batch 300/ 586 loss_1: 51.696705 loss_2: 41.233216 and source_train_acc is 89.3594  time is 30589.498145
#    batch 350/ 586 loss_1: 52.312307 loss_2: 41.999011 and source_train_acc is 89.2411  time is 30704.514923
#    batch 400/ 586 loss_1: 49.882481 loss_2: 36.908587 and source_train_acc is 89.3594  time is 30818.473243
#    batch 450/ 586 loss_1: 51.006356 loss_2: 40.272610 and source_train_acc is 89.3299  time is 30931.959798
#    batch 500/ 586 loss_1: 52.247526 loss_2: 42.033596 and source_train_acc is 89.2938  time is 31046.337962
#    batch 550/ 586 loss_1: 50.621163 loss_2: 39.085487 and source_train_acc is 89.3636  time is 31162.077543
#  for main taks,loss source_test 2.1008949279785156,..... acc source_test 58.56065798492118
#  for main taks, loss target_test 3.0999341011047363 , .... acc target_test 22.87843330459416
# EPOCH 20:
#    batch 50/ 586 loss_1: 51.480654 loss_2: 43.212591 and source_train_acc is 89.7812  time is 31692.467896
#    batch 100/ 586 loss_1: 50.897608 loss_2: 40.296746 and source_train_acc is 90.2656  time is 31807.887836
#    batch 150/ 586 loss_1: 58.770281 loss_2: 54.645660 and source_train_acc is 89.0417  time is 31920.687141
#    batch 200/ 586 loss_1: 57.271314 loss_2: 52.500963 and source_train_acc is 88.3281  time is 32034.005172
#    batch 250/ 586 loss_1: 71.695951 loss_2: 80.943993 and source_train_acc is 86.4062  time is 32146.155919
#    batch 300/ 586 loss_1: 66.476268 loss_2: 62.755352 and source_train_acc is 85.5156  time is 32258.904184
#    batch 350/ 586 loss_1: 62.827138 loss_2: 58.566851 and source_train_acc is 85.2098  time is 32373.078845
#    batch 400/ 586 loss_1: 59.270441 loss_2: 46.145066 and source_train_acc is 85.2539  time is 32485.865916
#    batch 450/ 586 loss_1: 59.709821 loss_2: 51.889919 and source_train_acc is 85.3021  time is 32599.626986
#    batch 500/ 586 loss_1: 61.164388 loss_2: 52.296984 and source_train_acc is 85.3094  time is 32713.766722
#    batch 550/ 586 loss_1: 58.987435 loss_2: 51.611675 and source_train_acc is 85.3011  time is 32826.406321
#  for main taks,loss source_test 2.2867696285247803,..... acc source_test 50.4592186429061
#  for main taks, loss target_test 3.107276678085327 , .... acc target_test 26.939894075625077
