# %% [markdown]
# # 1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.5)

# %%
from colorama import Fore
import skimage.io as io
import os
import pandas as pd
import random
# torch 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
import torchvision.models as models
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import math

# %%
# %cd /content/drive/MyDrive/domian_adoptation
# Out:
# /content/drive/MyDrive/domian_adoptation

# %%
# from  mean_and_std import get_mean_and_std
from dataloader.dataloader import CustomImageDataset ,roteted_dataset,continous_rotation_dataset
from visualization.data_plot import plot_pic

# %% [markdown]
# # 2. parameters

# %%
# save_dir = '/content/drive/MyDrive/domian_adoptation/result/aux_task' 

# weight_rot = 1
# weight_ent = 0
# BATCH_size = 64
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)

# second set of parameters:
save_dir = '/content/drive/MyDrive/domian_adoptation/result/aux_task' 

weight_rot = 0.6
weight_ent = 0
BATCH_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # 3. Datasets

# %%
# ! wget 'https://www.dropbox.com/s/xdy5cfu7m63pk46/?dl=1' -O \ ROD-synROD.tar
# ! rm ' ROD-synROD.tar'
# !  cp ' ROD-synROD.tar'  /content/drive/MyDrive/domian_adoptation

# %%
if not os.path.isfile('/content/ROD-synROD/ROD/rgb-washington/apple/apple_1/apple_1_1_101_crop.png'):
        print(Fore.RED, 'This might take several minuets......')
        ! tar -xf     /content/drive/MyDrive/domian_adoptation/' ROD-synROD.tar'  -C /content
       
else:
         print(Fore.CYAN, 'dataset file already exist')
# Out:
#  This might take several minuets......

# %% [markdown]
# # 2.1 ROD dataset
#
#
# ---
#
#
#
# 1.   Rod without label as a trainset
# 2.   Rod with label as testset

# %%
with open("/content/ROD-synROD/ROD/wrgbd_40k-split_sync.txt") as f:
 
    lines = f.read() 
    imgs = lines.split('\n')
imgs.remove('')
print(imgs[0])

all_labels = [imgs[i].split('/')[0] for i in range(len(imgs))]
all_labels=list(set(all_labels))
labelmap ={}
for i in range(len(all_labels)):
   labelmap[all_labels[i]] =i
print('total number of labels: ',Fore.RED,len(labelmap) )
print(Fore.BLUE,labelmap)

ROD_dataset = CustomImageDataset(dt= 'ROD',annotations_list = imgs,label_map=labelmap,
                                img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                                depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]), 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                                                        
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                                     
                                    
                                )

ROD_dataloader = DataLoader(ROD_dataset, batch_size= BATCH_size,shuffle=True)
# Out:
# rubber_eraser/rubber_eraser_4/rubber_eraser_4_1_136_***.png 38
# total number of labels:   47
#  {'lemon': 0, 'soda_can': 1, 'food_can': 2, 'pitcher': 3, 'food_box': 4, 'water_bottle': 5, 'scissors': 6, 'greens': 7, 'garlic': 8, 'shampoo': 9, 'toothbrush': 10, 'orange': 11, 'calculator': 12, 'flashlight': 13, 'apple': 14, 'notebook': 15, 'coffee_mug': 16, 'banana': 17, 'bowl': 18, 'ball': 19, 'plate': 20, 'rubber_eraser': 21, 'bell_pepper': 22, 'stapler': 23, 'food_cup': 24, 'cap': 25, 'comb': 26, 'sponge': 27, 'pear': 28, 'binder': 29, 'keyboard': 30, 'dry_battery': 31, 'instant_noodles': 32, 'kleenex': 33, 'glue_stick': 34, 'pliers': 35, 'potato': 36, 'lightbulb': 37, 'camera': 38, 'food_jar': 39, 'marker': 40, 'cereal_box': 41, 'mushroom': 42, 'cell_phone': 43, 'food_bag': 44, 'hand_towel': 45, 'toothpaste': 46}

# %%
# visulasioan of ROD
X  = plot_pic(ROD_dataloader,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ROD_rotated =continous_rotation_dataset (dt= 'ROD',annotations_list = imgs,
                               img_dir ="/content/ROD-synROD/ROD/rgb-washington",
                               depth_dir ="/content/ROD-synROD/ROD/surfnorm-washington",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),                                
                                transforms.Normalize(mean=[0.5547, 0.5310, 0.5189], std=[0.2122, 0.2184, 0.2499],)  ]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                             
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]) 
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                           )

ROD_rotated_dataloader = DataLoader(ROD_rotated, batch_size = BATCH_size,shuffle=True)

# %%
X  = plot_pic(ROD_rotated_dataloader ,labelmap =False,r =True,is_continous =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2.2 SynROD dataset
#
#
# ---
#
#
#
# 1.   SynROD  with label as a trainset

# %%
with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_train1.txt") as f:
    lines = f.read() 
    syn_imgs = lines.split('\n')
syn_imgs.remove('')

with open("/content/ROD-synROD/synROD/synARID_50k-split_sync_test1.txt") as f:
    lines = f.read() 
    syn_imgs_test = lines.split('\n')
# syn_imgs.remove('')

syn_imgs_test.remove('')


syn_all_labels = [syn_imgs[i].split('/')[0] for i in range(len(syn_imgs))]
syn_all_labels=list(set(syn_all_labels))

syn_all_labels_test = [syn_imgs_test[i].split('/')[0] for i in range(len(syn_imgs_test))]
syn_all_labels_test=list(set(syn_all_labels_test))

# checking labesls oncistency 
if set(syn_all_labels) == set(syn_all_labels_test):
  print('rod and synrod labels match')
else :
  for i in syn_all_labels :
    if i not in  syn_all_labels_test:
      print(i,"exist in synrod trainset but not testset")
  for i in syn_all_labels_test :
    if i not in  syn_all_labels:
      print(i," exist in synrod testset but not trainset")

if set(syn_all_labels) == set(all_labels):
  print(' datasets labels completly match')
else:
  print('sth is wrong')
  for i in syn_all_labels :
    if i not in  all_labels:
      print(i,"does not exist in ROD")
  for i in all_labels :
    if i not in  syn_all_labels:
      print(i," does not exist in synrod")
# Out:
# rod and synrod labels match
# sth is wrong
# bell_papper does not exist in ROD
# bell_pepper  does not exist in synrod

# %%
SynROD_train = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs,label_map=labelmap,
                                  img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))

   

SynROD_test = CustomImageDataset(dt = 'SYNROD',annotations_list = syn_imgs_test,label_map=labelmap,img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
         transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)]),

                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))
                                # transforms.Normalize(mean=[0.7426, 0.2956, 0.4785], std=[0.2012, 0.2030, 0.2916],)   ]))

SynROD_rotated = continous_rotation_dataset(dt = 'SYNROD',annotations_list = syn_imgs,
                                 img_dir ='/content/ROD-synROD/synROD',depth_dir ="/content/ROD-synROD/synROD",
                                transform = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                transforms.Normalize(mean=[0.3107, 0.2884, 0.2595], std=[0.2352, 0.2268, 0.2336],)]),
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]),
                                 
                                transform_d = transforms.Compose([
                                transforms.Resize(256),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),    
                                # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],)  ]))
                                transforms.Normalize(mean=[0.4422, 0.4014, 0.6852], std=[0.1382, 0.2507, 0.3628],)   ]))





SynROD_dataloader_train = DataLoader(SynROD_train, batch_size=BATCH_size,shuffle=True)

SynROD_dataloader_test  =  DataLoader(SynROD_test, batch_size=BATCH_size,shuffle=True)

SynROD_rotated_dataloader = DataLoader(SynROD_rotated, batch_size=BATCH_size,shuffle=True)

# %%
X  = plot_pic(SynROD_dataloader_train ,labelmap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X  = plot_pic(SynROD_rotated_dataloader ,labelmap=False,r =True,is_continous =True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # models

# %%
# helper function
def load_cnn_model(model_name, pretrained=True):
    "Load and return a convolutional neural network."
    assert model_name in ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']
    return models.__dict__[model_name](pretrained= True)

# %%
class E(nn.Module):
    def __init__(self, model_name):
      
        super(E, self).__init__()  
        # load cnn and remove 2 last layers
        cnn = load_cnn_model(model_name)
        modules = list(cnn.children())[:-2]  # remove 2 last layers
        
        self.cnn = nn.Sequential(*modules)             
    
        
    def forward(self, x):
        x = self.cnn(x)  
              
        return x

class feature_extract(nn.Module):
    def __init__(self):
      
        super(feature_extract, self).__init__()  
        self.E_c = E(model_name ='resnet18')
        self.E_d = E(model_name ='resnet18') 
                
    def forward(self,  images, depths):
        features_c = self.E_c(images)
        features_d = self.E_d(depths)        
        X = torch.cat([features_c,features_d], dim=1 )     
              
        return X

class main_head(nn.Module):
    def __init__(self,num_classes):
      super(main_head, self).__init__() 
      self.gap = nn.AdaptiveAvgPool2d(output_size=(1, 1)) 

      self.fc1 = nn.Sequential(
          nn.Dropout(p=0.5),
          nn.Linear(1024, 1000),
          nn.BatchNorm1d(1000, affine=True),
          nn.ReLU(inplace=True),
          nn.Dropout(p=0.5)
      )
      self.fc2 = nn.Linear(1000, num_classes)
      self.initilise_weight()
      

    def forward(self, features):
        x = self.gap(features)
        x = torch.squeeze(x)
        x = self.fc1(x)
        x = self.fc2(x)   
        # x = F.softmax(x, dim=1)   
          
              
        return x
    
    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

class pretext(nn.Module):
    def __init__(self):
      super(pretext, self).__init__() 
      self.p_conv_1x1 = nn.Sequential(
          nn.Conv2d(1024 ,100, [1,1], stride=[1,1]),
          nn.BatchNorm2d(100),
          nn.ReLU(inplace=True)
          )
      self.p_conv_3x3 = nn.Sequential(
          nn.Conv2d(100, 100, [3,3], stride=[2,2]),
          nn.BatchNorm2d(100),
           nn.ReLU(inplace=True)
          )
      self.p_fc1 = nn.Sequential(
          nn.Linear(100*3*3, 360),
          nn.BatchNorm1d(360, affine=True),
           nn.ReLU(inplace=True),
          nn.Dropout(p=0)
          )     
      self.p_fc2 = nn.Linear(360, 2)
      self.initilise_weight()         
    def forward(self, features):      
        y = self.p_conv_1x1(features)
        y = self.p_conv_3x3(y)
        y = y.view(y.size(0), -1)
        y = self.p_fc1(y)
        y = self.p_fc2(y)        
        y =torch.atan2(y[:,0], y[:,1]) *180/3.14159265359         
       
        return y


    def initilise_weight(self):
        for m in self.modules():
          if isinstance(m,nn.Conv2d):
             torch.nn.init.xavier_uniform_(m.weight)
             torch.nn.init.zeros_(m.bias)
          if isinstance(m,nn.BatchNorm1d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if isinstance(m,nn.BatchNorm2d):
               m.weight.data.normal_(1.0, 0.01)
               m.bias.data.fill_(0)
          if  isinstance(m,nn.Linear):
               m.weight.data.normal_(0.0, 0.01)
               m.bias.data.normal_(0.0, 0.01)

F_model = feature_extract()

main_model =  main_head(num_classes = len(labelmap))

pr_model =  pretext()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# # model training

# %%
loss_fn_1 = torch.nn.CrossEntropyLoss()

loss_fn_2 =torch.nn.MSELoss()


optimizer1 = torch.optim.SGD(F_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)
optimizer2 = torch.optim.SGD(main_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)
optimizer3 = torch.optim.SGD(pr_model.parameters(), lr=0.0003, momentum=0.9,weight_decay=0.05)

# %%
F_model.to(device)
main_model.to(device)
pr_model.to(device)
# Out:
# pretext(
#   (p_conv_1x1): Sequential(
#     (0): Conv2d(1024, 100, kernel_size=(1, 1), stride=(1, 1))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_conv_3x3): Sequential(
#     (0): Conv2d(100, 100, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (p_fc1): Sequential(
#     (0): Linear(in_features=900, out_features=360, bias=True)
#     (1): BatchNorm1d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0, inplace=False)
#   )
#   (p_fc2): Linear(in_features=360, out_features=2, bias=True)
# )

# %%
swtt_batch = math.ceil(len(syn_imgs)/BATCH_size)
def train_one_epoch(epoch_index):
    running_loss_1 = 0.
    last_loss_1 = 0.
    running_loss_2 = 0.
    last_loss_2 = 0.
    acc = 0
    tot = 0
    cor = 0
    acc2 = 0
    tot2 = 0
    cor2 = 0

    # Here, we use enumerate(training_loader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for i, data in enumerate(SynROD_dataloader_train ,0):


      # Zero your gradients for every batch!
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        optimizer3.zero_grad()
       
       
        image_s,depth_s,label_s = data
        image_s,depth_s,label_s = image_s.to(device),depth_s.to(device),label_s.to(device)
        

        # Make predictions for this batch
        feat = F_model(image_s,depth_s)
        outputs = main_model(feat)
       
        # if weight_ent >0:

        #         img_rgb, img_depth, _ = next(iter(ROD_dataloader))
        #         img_rgb, img_depth =img_rgb.to(device),img_depth.to(device)                
        #         logits = F_model(img_rgb, img_depth)
        #         logits_M = main_model(logits)
        #         loss_ent = entropy_loss(logits_M)

        # else:
        #     loss_ent =0
         

        loss_1 = loss_fn_1(outputs,label_s) 
        
       
        pr =  F.softmax(outputs, dim=1) 
        _, pr= torch.max( pr.data, 1)
        _, real= torch.max(label_s.data, 1)

        tot += label_s.size(0)
        cor += (pr ==  real).sum().item()
        acc = 100 * cor / tot    
        

        image_s_r,depth_s_r,rotation_syn = next(iter(SynROD_rotated_dataloader))
        image_rod_r,depth_rod_r,rotation_rod = next(iter(ROD_rotated_dataloader) )       
        
        image_s_r,depth_s_r,rotation_syn =  image_s_r.to(device),depth_s_r.to(device),rotation_syn.to(device)      
        image_rod_r,depth_rod_r,rotation_rod = image_rod_r.to(device),depth_rod_r.to(device),rotation_rod.to(device)
        # print(Fore.CYAN,',rotation_rod',rotation_rod)
        feat2 = F_model( image_s_r,depth_s_r)
        feat3= F_model(image_rod_r,depth_rod_r)
        
        outputs2 =pr_model( feat2 )        
        outputs3 =  pr_model(feat3)
        outputs2[outputs2<0] =outputs2[outputs2<0] +360
        outputs3[outputs3<0] =outputs3[outputs3<0] +360
        outputs2 =outputs2 *3.14159265359 /180
        outputs3 =outputs3 *3.14159265359 /180

        out2_sin = torch.sin(outputs2)
        out2_cos = torch.cos(outputs2)
        
        out3_sin = torch.sin(outputs3)
        out3_cos = torch.cos(outputs3)

        rotation_syn=  rotation_syn *3.14159265359 /180
        rotation_rod =    rotation_rod  *3.14159265359 /180
        
        rotation_syn_sin = torch.sin(rotation_syn)
        rotation_syn_cos = torch.cos(rotation_syn)

        rotation_rod_sin = torch.sin(rotation_rod)
        rotation_rod_cos = torch.cos(rotation_rod)
        


        loss_2 = loss_fn_2( out2_sin,rotation_syn_sin) + loss_fn_2( out2_cos,rotation_syn_cos) +loss_fn_2( out3_cos,rotation_rod_cos) + loss_fn_2( out3_sin,rotation_rod_sin )
             
        loss =  loss_1+ weight_rot *loss_2        
        loss.backward()


        optimizer1.step()
        optimizer2.step()
        optimizer3.step()
         
      
        

        running_loss_2 += loss_2.item()  
        running_loss_1 += loss_1.item()      
        
        
       

        if i % 50 == 49:
          last_loss_1 = running_loss_1 
          last_loss_2 = running_loss_2 
          print(Fore.BLUE,'  batch {}/ {} loss_1: {} loss_2: {} and source_train_acc is {}  time is {}'.format(i + 1,swtt_batch,'%.6f' % last_loss_1,
                                                                     '%.6f' %last_loss_2,   '%.4f'% acc,   '%.6f'%(time.time() - start_time)))
      
          running_loss_1 = 0.
          running_loss_2 = 0. 

        
    
   
    # model_name = F_model.module._get_name() if isinstance(F_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': F_model.state_dict(),
    #               'optimizer_state_dict': optimizer1.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = main_model.module._get_name() if isinstance(main_model, torch.nn.DataParallel) else main_model._get_name()
    # checkpoint1 = {'epoch':epoch,
    #               'model_state_dict': main_model.state_dict(),
    #               'optimizer_state_dict': optimizer2.state_dict(),
    #                'loss':  loss
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint1,fpath)

    # model_name = pr_model.module._get_name() if isinstance(pr_model, torch.nn.DataParallel) else F_model._get_name()
    # checkpoint2 = {'epoch':epoch,
    #               'model_state_dict': pr_model.state_dict(),
    #               'optimizer_state_dict': optimizer3.state_dict(),
    #                'loss':  loss
                   
    #                  }
    # fpath = f'{save_dir}/{model_name}_checkpoint_dict.pt'
    # torch.save(checkpoint2,fpath)
    



    return last_loss_1+last_loss_2,acc

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
epoch_number = 0
import time
start_time = time.time()

EPOCHS = 20
best_vloss = 1_000_000.
source_train_loss =[]
source_train_accuracy =[]

source_test_loss =[]
source_test_accuracy =[]



target_test_loss = []
target_test_accuracy =[]



for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    F_model.train(True)
    main_model.train(True)
    pr_model.train(True)
   

    avg_loss,acc= train_one_epoch(epoch_number)
    source_train_loss.append(avg_loss)
    source_train_accuracy.append(acc)

    # We don't need gradients on to do reporting
    F_model.train(False)
    main_model.train(False)
    pr_model.train(False)
    
    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(SynROD_dataloader_test ):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    source_test_loss.append(avg_vloss)
    source_test_accuracy.append(accuracy)


    print(Fore.GREEN,'for main taks,loss source_test {},..... acc source_test {}'.format(avg_vloss, accuracy))   
   

    running_vloss = 0.0
    correct =0
    total = 0.
    
    for i, vdata in enumerate(ROD_dataloader):
        with torch.no_grad():
          v_image,v_depth, vlabels = vdata
          v_image,v_depth, vlabels =  v_image.to(device),v_depth.to(device), vlabels.to(device)
          feat_o  = F_model(v_image,v_depth)
          voutputs= main_model(feat_o)
           
          vloss = loss_fn_1(voutputs, vlabels)
          running_vloss += vloss

          _, predicted = torch.max(voutputs.data, 1)
          _, real_label = torch.max(vlabels.data, 1)
          total += vlabels.size(0)
          correct += (predicted ==real_label).sum().item()
         
    accuracy = 100 * correct / total
    avg_vloss = running_vloss / (i + 1)
    target_test_loss.append(avg_vloss)
    target_test_accuracy.append(accuracy)

    print(Fore.RED,'for main taks, loss target_test {} , .... acc target_test {}'.format( avg_vloss, accuracy))
 
    try:
            E= [i for i in range(len(target_test_loss))]

            fig, (axs, ax2) = plt.subplots(2)
            try:     
              t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
              t_target_loss = [target_test_loss[i]  for i  in range(len(target_test_loss))]
            try:
                  s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                  s_test_loss =  [source_test_loss[i]  for i  in range(len(target_test_loss))]

            axs.plot(E, t_target_loss,label="target")
            axs.plot(E,s_test_loss,label="source_test")
            
            axs.set_xlabel('epoch')
            axs.set_ylabel('loss')
            axs.grid(True)
            
            try:
              t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                t_target_acc = [target_test_accuracy[i]  for i  in range(len(target_test_loss))]

            try:
                s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
            except:
                s_test_acc =  [source_test_accuracy[i]  for i  in range(len(target_test_loss))]

            
            

            ax2.plot(E, t_target_acc,label="target" )
            ax2.plot(E,s_test_acc,label="source_test")

            
            ax2.set_xlabel('epoch')
            ax2.set_ylabel('accuracy')
            ax2.grid(True)

            fig.tight_layout()
          
            plt.savefig('var22.png')

    except:
            print(Fore.RED,'sth was wrng with saving')


    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        F_model_path = 'result/aux_task/F_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(F_model.state_dict(), F_model_path)

        M_model_path = 'result/aux_task/main_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(main_model.state_dict(), M_model_path)

        Fr_model_path = 'result/aux_task/pr_model_{}_{}'.format(timestamp, epoch_number)
        torch.save(pr_model.state_dict(),Fr_model_path)

    epoch_number += 1
# Out:
# EPOCH 1:
#    batch 50/ 586 loss_1: 193.598139 loss_2: 201.009934 and source_train_acc is 2.9375  time is 136.273573
#    batch 100/ 586 loss_1: 189.945417 loss_2: 197.809536 and source_train_acc is 3.3906  time is 260.054098
#    batch 150/ 586 loss_1: 186.681226 loss_2: 198.693211 and source_train_acc is 4.5104  time is 380.144798
#    batch 200/ 586 loss_1: 183.007277 loss_2: 198.858535 and source_train_acc is 5.8672  time is 499.049665
#    batch 250/ 586 loss_1: 178.636432 loss_2: 196.993074 and source_train_acc is 7.6375  time is 617.676761
#    batch 300/ 586 loss_1: 174.401459 loss_2: 200.045508 and source_train_acc is 9.6250  time is 734.644722
#    batch 350/ 586 loss_1: 170.447251 loss_2: 198.347808 and source_train_acc is 11.6250  time is 850.733809
#    batch 400/ 586 loss_1: 165.308828 loss_2: 198.205829 and source_train_acc is 13.5898  time is 968.306832
#    batch 450/ 586 loss_1: 159.842145 loss_2: 197.474557 and source_train_acc is 15.6181  time is 1083.745607
#    batch 500/ 586 loss_1: 155.088384 loss_2: 199.943068 and source_train_acc is 17.5094  time is 1198.409819
#    batch 550/ 586 loss_1: 150.289334 loss_2: 201.358448 and source_train_acc is 19.2699  time is 1313.531153
#  for main taks,loss source_test 3.028740882873535,..... acc source_test 41.2748457847841
#  for main taks, loss target_test 3.2758336067199707 , .... acc target_test 23.88533070575194
# EPOCH 2:
#    batch 50/ 586 loss_1: 142.483525 loss_2: 198.667934 and source_train_acc is 41.4375  time is 1848.054146
#    batch 100/ 586 loss_1: 137.718696 loss_2: 199.725406 and source_train_acc is 42.9062  time is 1962.867090
#    batch 150/ 586 loss_1: 132.828897 loss_2: 195.070482 and source_train_acc is 43.8333  time is 2078.039212
#    batch 200/ 586 loss_1: 127.850209 loss_2: 197.053757 and source_train_acc is 44.7812  time is 2193.635501
#    batch 250/ 586 loss_1: 124.095971 loss_2: 198.077164 and source_train_acc is 45.7625  time is 2307.477160
#    batch 300/ 586 loss_1: 121.263979 loss_2: 191.291106 and source_train_acc is 46.6146  time is 2421.741982
#    batch 350/ 586 loss_1: 116.917354 loss_2: 189.611789 and source_train_acc is 47.5268  time is 2535.467344
#    batch 400/ 586 loss_1: 115.006678 loss_2: 189.587117 and source_train_acc is 48.2227  time is 2650.673473
#    batch 450/ 586 loss_1: 110.849561 loss_2: 183.368840 and source_train_acc is 49.1771  time is 2764.756541
#    batch 500/ 586 loss_1: 108.672576 loss_2: 181.516546 and source_train_acc is 49.7219  time is 2880.959547
#    batch 550/ 586 loss_1: 106.162587 loss_2: 181.611574 and source_train_acc is 50.3920  time is 2994.495788
#  for main taks,loss source_test 2.321488618850708,..... acc source_test 48.2111034955449
#  for main taks, loss target_test 2.780827760696411 , .... acc target_test 32.750338711664
#  sth was wrng with saving
# EPOCH 3:
#    batch 50/ 586 loss_1: 99.775023 loss_2: 172.252555 and source_train_acc is 60.7188  time is 3528.233026
#    batch 100/ 586 loss_1: 97.900703 loss_2: 170.587570 and source_train_acc is 60.6562  time is 3643.375790
#    batch 150/ 586 loss_1: 95.717856 loss_2: 157.166472 and source_train_acc is 61.2188  time is 3759.372441
#    batch 200/ 586 loss_1: 93.717413 loss_2: 150.839866 and source_train_acc is 61.5469  time is 3874.956521
#    batch 250/ 586 loss_1: 92.607836 loss_2: 131.265749 and source_train_acc is 62.0562  time is 3989.348945
#    batch 300/ 586 loss_1: 92.155133 loss_2: 117.960233 and source_train_acc is 62.1146  time is 4102.417570
#    batch 350/ 586 loss_1: 89.403274 loss_2: 109.070261 and source_train_acc is 62.6205  time is 4219.149080
#    batch 400/ 586 loss_1: 88.939150 loss_2: 110.339741 and source_train_acc is 62.9844  time is 4336.367870
#    batch 450/ 586 loss_1: 85.212539 loss_2: 99.760487 and source_train_acc is 63.3958  time is 4450.583261
#    batch 500/ 586 loss_1: 87.845393 loss_2: 112.915149 and source_train_acc is 63.4969  time is 4564.392461
#    batch 550/ 586 loss_1: 87.095392 loss_2: 122.731907 and source_train_acc is 63.5312  time is 4678.700070
#  for main taks,loss source_test 2.0702884197235107,..... acc source_test 52.18642906100069
#  for main taks, loss target_test 2.5485174655914307 , .... acc target_test 34.3392043355093
#  sth was wrng with saving
# EPOCH 4:
#    batch 50/ 586 loss_1: 81.863055 loss_2: 94.714808 and source_train_acc is 67.5938  time is 5214.006177
#    batch 100/ 586 loss_1: 78.493495 loss_2: 90.584588 and source_train_acc is 68.3594  time is 5328.466271
#    batch 150/ 586 loss_1: 78.428970 loss_2: 83.203502 and source_train_acc is 68.3750  time is 5444.482508
#    batch 200/ 586 loss_1: 74.836280 loss_2: 79.468067 and source_train_acc is 68.9062  time is 5559.650988
#    batch 250/ 586 loss_1: 75.029494 loss_2: 78.560590 and source_train_acc is 69.1937  time is 5674.324456
#    batch 300/ 586 loss_1: 74.612562 loss_2: 74.762674 and source_train_acc is 69.4115  time is 5787.879187
#    batch 350/ 586 loss_1: 71.699640 loss_2: 75.197386 and source_train_acc is 69.8304  time is 5903.763331
#    batch 400/ 586 loss_1: 71.353418 loss_2: 72.515984 and source_train_acc is 70.1172  time is 6018.161043
#    batch 450/ 586 loss_1: 70.342668 loss_2: 70.400935 and source_train_acc is 70.4132  time is 6133.356697
#    batch 500/ 586 loss_1: 69.383665 loss_2: 67.796240 and source_train_acc is 70.6063  time is 6248.838482
#    batch 550/ 586 loss_1: 68.874820 loss_2: 66.782623 and source_train_acc is 70.8636  time is 6362.352613
#  for main taks,loss source_test 1.8214588165283203,..... acc source_test 57.518848526387934
#  for main taks, loss target_test 2.473893642425537 , .... acc target_test 35.40768567557581
#  sth was wrng with saving
# EPOCH 5:
#    batch 50/ 586 loss_1: 65.430987 loss_2: 68.581115 and source_train_acc is 74.9375  time is 6893.495956
#    batch 100/ 586 loss_1: 64.353111 loss_2: 67.894098 and source_train_acc is 75.5156  time is 7008.831057
#    batch 150/ 586 loss_1: 64.221629 loss_2: 65.227894 and source_train_acc is 75.4167  time is 7124.347767
#    batch 200/ 586 loss_1: 63.809792 loss_2: 64.750958 and source_train_acc is 75.5156  time is 7239.878480
#    batch 250/ 586 loss_1: 64.582001 loss_2: 71.980589 and source_train_acc is 75.2313  time is 7353.174303
#    batch 300/ 586 loss_1: 62.530882 loss_2: 64.872536 and source_train_acc is 75.5260  time is 7467.292181
#    batch 350/ 586 loss_1: 62.272248 loss_2: 61.404808 and source_train_acc is 75.5804  time is 7582.991546
#    batch 400/ 586 loss_1: 61.214159 loss_2: 58.205577 and source_train_acc is 75.6914  time is 7699.567731
#    batch 450/ 586 loss_1: 61.038220 loss_2: 57.365445 and source_train_acc is 75.7604  time is 7817.433319
#    batch 500/ 586 loss_1: 59.477686 loss_2: 55.284715 and source_train_acc is 75.9562  time is 7931.141963
#    batch 550/ 586 loss_1: 58.985883 loss_2: 58.159930 and source_train_acc is 76.1364  time is 8044.445844
#  for main taks,loss source_test 1.7129298448562622,..... acc source_test 59.10897875257025
#  for main taks, loss target_test 2.4787685871124268 , .... acc target_test 37.5169355831999
#  sth was wrng with saving
# EPOCH 6:
#    batch 50/ 586 loss_1: 55.928465 loss_2: 57.532013 and source_train_acc is 79.9375  time is 8576.218049
#    batch 100/ 586 loss_1: 57.250350 loss_2: 53.428678 and source_train_acc is 79.2188  time is 8690.960881
#    batch 150/ 586 loss_1: 57.923272 loss_2: 64.829290 and source_train_acc is 78.9062  time is 8804.766220
#    batch 200/ 586 loss_1: 58.266023 loss_2: 69.494344 and source_train_acc is 78.7812  time is 8918.322052
#    batch 250/ 586 loss_1: 56.829647 loss_2: 55.743911 and source_train_acc is 78.8375  time is 9034.851204
#    batch 300/ 586 loss_1: 55.515241 loss_2: 56.758647 and source_train_acc is 79.0312  time is 9151.287308
#    batch 350/ 586 loss_1: 55.390891 loss_2: 55.574569 and source_train_acc is 79.1473  time is 9265.440362
#    batch 400/ 586 loss_1: 54.667977 loss_2: 54.113385 and source_train_acc is 79.2773  time is 9379.477906
#    batch 450/ 586 loss_1: 55.642311 loss_2: 57.356574 and source_train_acc is 79.2014  time is 9494.137696
#    batch 500/ 586 loss_1: 55.885188 loss_2: 53.726186 and source_train_acc is 79.2375  time is 9607.996358
#    batch 550/ 586 loss_1: 55.079025 loss_2: 53.021524 and source_train_acc is 79.2670  time is 9723.076039
#  for main taks,loss source_test 1.6454079151153564,..... acc source_test 61.0692254969157
#  for main taks, loss target_test 2.4712512493133545 , .... acc target_test 36.667077226259394
#  sth was wrng with saving
# EPOCH 7:
#    batch 50/ 586 loss_1: 51.651249 loss_2: 50.398816 and source_train_acc is 81.5312  time is 10255.819854
#    batch 100/ 586 loss_1: 53.159671 loss_2: 50.207138 and source_train_acc is 81.0000  time is 10371.615666
#    batch 150/ 586 loss_1: 50.542820 loss_2: 50.536109 and source_train_acc is 81.7292  time is 10487.421399
#    batch 200/ 586 loss_1: 52.330786 loss_2: 48.460133 and source_train_acc is 81.3047  time is 10602.859215
#    batch 250/ 586 loss_1: 51.856822 loss_2: 46.726949 and source_train_acc is 81.2250  time is 10718.236459
#    batch 300/ 586 loss_1: 49.428451 loss_2: 46.678123 and source_train_acc is 81.5729  time is 10832.276712
#    batch 350/ 586 loss_1: 49.695795 loss_2: 47.162828 and source_train_acc is 81.7679  time is 10948.280744
#    batch 400/ 586 loss_1: 50.180344 loss_2: 44.803030 and source_train_acc is 81.8633  time is 11063.539129
#    batch 450/ 586 loss_1: 50.085570 loss_2: 46.139358 and source_train_acc is 81.8438  time is 11176.556840
#    batch 500/ 586 loss_1: 50.765525 loss_2: 47.726165 and source_train_acc is 81.9469  time is 11291.592959
#    batch 550/ 586 loss_1: 48.639581 loss_2: 48.922832 and source_train_acc is 82.1193  time is 11404.604439
#  for main taks,loss source_test 1.6659566164016724,..... acc source_test 60.39753255654558
#  for main taks, loss target_test 2.5291531085968018 , .... acc target_test 37.15666954058381
#  sth was wrng with saving
# EPOCH 8:
#    batch 50/ 586 loss_1: 47.638198 loss_2: 47.350065 and source_train_acc is 84.3438  time is 11938.833575
#    batch 100/ 586 loss_1: 48.560425 loss_2: 44.483937 and source_train_acc is 84.0938  time is 12053.572076
#    batch 150/ 586 loss_1: 48.510360 loss_2: 44.897658 and source_train_acc is 83.8438  time is 12167.349767
#    batch 200/ 586 loss_1: 48.608598 loss_2: 45.130894 and source_train_acc is 83.7812  time is 12284.328711
#    batch 250/ 586 loss_1: 47.606860 loss_2: 47.287519 and source_train_acc is 83.7687  time is 12403.438435
#    batch 300/ 586 loss_1: 47.861613 loss_2: 52.443808 and source_train_acc is 83.9531  time is 12522.205676
#    batch 350/ 586 loss_1: 48.238234 loss_2: 55.938670 and source_train_acc is 84.0134  time is 12641.643953
#    batch 400/ 586 loss_1: 47.930498 loss_2: 48.402373 and source_train_acc is 84.0312  time is 12759.944132
#    batch 450/ 586 loss_1: 47.808965 loss_2: 45.824204 and source_train_acc is 84.0382  time is 12875.792376
#    batch 500/ 586 loss_1: 46.438340 loss_2: 45.618005 and source_train_acc is 84.1219  time is 12990.912610
#    batch 550/ 586 loss_1: 47.672261 loss_2: 46.651992 and source_train_acc is 84.1250  time is 13107.065938
#  for main taks,loss source_test 1.6873831748962402,..... acc source_test 61.08293351610692
#  for main taks, loss target_test 2.536238193511963 , .... acc target_test 37.10740238945683
#  sth was wrng with saving
# EPOCH 9:
#    batch 50/ 586 loss_1: 46.638766 loss_2: 42.077368 and source_train_acc is 85.2188  time is 13648.157234
#    batch 100/ 586 loss_1: 45.274058 loss_2: 44.167595 and source_train_acc is 85.4062  time is 13764.651218
#    batch 150/ 586 loss_1: 45.925185 loss_2: 43.149280 and source_train_acc is 85.1562  time is 13881.143619
#    batch 200/ 586 loss_1: 45.058944 loss_2: 42.663309 and source_train_acc is 85.2344  time is 13997.920515
#    batch 250/ 586 loss_1: 43.321664 loss_2: 40.923604 and source_train_acc is 85.5875  time is 14115.704901
#    batch 300/ 586 loss_1: 45.257218 loss_2: 41.302116 and source_train_acc is 85.4792  time is 14231.210805
#    batch 350/ 586 loss_1: 44.615268 loss_2: 41.010148 and source_train_acc is 85.6295  time is 14347.105381
#    batch 400/ 586 loss_1: 43.576507 loss_2: 40.763514 and source_train_acc is 85.8320  time is 14462.827418
#    batch 450/ 586 loss_1: 44.660221 loss_2: 41.587987 and source_train_acc is 85.8924  time is 14578.071087
#    batch 500/ 586 loss_1: 42.724384 loss_2: 37.775991 and source_train_acc is 86.0781  time is 14693.019714
#    batch 550/ 586 loss_1: 44.073793 loss_2: 43.545559 and source_train_acc is 86.1477  time is 14808.438898
#  for main taks,loss source_test 1.7130016088485718,..... acc source_test 61.13776559287183
#  for main taks, loss target_test 2.6005866527557373 , .... acc target_test 35.66941741593792
#  sth was wrng with saving
# EPOCH 10:
#    batch 50/ 586 loss_1: 43.692063 loss_2: 40.450683 and source_train_acc is 87.2188  time is 15345.930224
#    batch 100/ 586 loss_1: 43.252559 loss_2: 40.223193 and source_train_acc is 87.2969  time is 15461.501739
#    batch 150/ 586 loss_1: 43.469666 loss_2: 40.657631 and source_train_acc is 87.3333  time is 15576.747256
#    batch 200/ 586 loss_1: 42.336005 loss_2: 39.394250 and source_train_acc is 87.3281  time is 15691.581886
#    batch 250/ 586 loss_1: 42.449839 loss_2: 43.558752 and source_train_acc is 87.4250  time is 15806.610767
#    batch 300/ 586 loss_1: 44.798706 loss_2: 58.669536 and source_train_acc is 87.4062  time is 15919.681128
#    batch 350/ 586 loss_1: 43.826136 loss_2: 50.553210 and source_train_acc is 87.4018  time is 16034.902022
#    batch 400/ 586 loss_1: 46.209280 loss_2: 49.060643 and source_train_acc is 87.2461  time is 16149.570565
#    batch 450/ 586 loss_1: 45.434225 loss_2: 49.919093 and source_train_acc is 87.0521  time is 16264.055712
#    batch 500/ 586 loss_1: 45.997091 loss_2: 43.392163 and source_train_acc is 86.9250  time is 16378.464034
#    batch 550/ 586 loss_1: 49.129453 loss_2: 66.852292 and source_train_acc is 86.7500  time is 16492.809824
#  for main taks,loss source_test 1.6856266260147095,..... acc source_test 62.508567511994514
#  for main taks, loss target_test 2.6278913021087646 , .... acc target_test 36.078950609680994
#  sth was wrng with saving
# EPOCH 11:
#    batch 50/ 586 loss_1: 43.544640 loss_2: 45.172778 and source_train_acc is 87.5938  time is 17021.388693
#    batch 100/ 586 loss_1: 44.360813 loss_2: 48.873138 and source_train_acc is 87.4531  time is 17135.668279
#    batch 150/ 586 loss_1: 43.889998 loss_2: 46.055268 and source_train_acc is 87.3021  time is 17249.627236
#    batch 200/ 586 loss_1: 43.761585 loss_2: 42.189774 and source_train_acc is 87.5547  time is 17364.563360
#    batch 250/ 586 loss_1: 42.852858 loss_2: 44.421848 and source_train_acc is 87.8375  time is 17478.203366
#    batch 300/ 586 loss_1: 42.766799 loss_2: 41.296335 and source_train_acc is 87.8177  time is 17591.654554
#    batch 350/ 586 loss_1: 42.431466 loss_2: 40.110193 and source_train_acc is 87.8795  time is 17704.576752
#    batch 400/ 586 loss_1: 43.051217 loss_2: 42.051099 and source_train_acc is 87.9414  time is 17819.681487
#    batch 450/ 586 loss_1: 42.276726 loss_2: 39.631383 and source_train_acc is 87.9826  time is 17936.587204
#    batch 500/ 586 loss_1: 41.990046 loss_2: 39.550976 and source_train_acc is 88.0969  time is 18050.703391
#    batch 550/ 586 loss_1: 41.314608 loss_2: 40.067434 and source_train_acc is 88.2472  time is 18165.773505
#  for main taks,loss source_test 1.7384283542633057,..... acc source_test 60.65798492117889
#  for main taks, loss target_test 2.712721824645996 , .... acc target_test 33.868087202857495
#  sth was wrng with saving
# EPOCH 12:
#    batch 50/ 586 loss_1: 40.596138 loss_2: 40.156451 and source_train_acc is 89.9062  time is 18699.570060
#    batch 100/ 586 loss_1: 40.954764 loss_2: 38.577601 and source_train_acc is 89.7969  time is 18814.173234
#    batch 150/ 586 loss_1: 42.025110 loss_2: 42.346725 and source_train_acc is 89.8438  time is 18928.944114
#    batch 200/ 586 loss_1: 42.541690 loss_2: 44.657073 and source_train_acc is 89.5234  time is 19044.119771
#    batch 250/ 586 loss_1: 42.581344 loss_2: 46.024503 and source_train_acc is 89.4437  time is 19158.381174
#    batch 300/ 586 loss_1: 42.338857 loss_2: 40.345314 and source_train_acc is 89.5417  time is 19271.229187
#    batch 350/ 586 loss_1: 41.544769 loss_2: 38.555953 and source_train_acc is 89.5759  time is 19385.587108
#    batch 400/ 586 loss_1: 40.751581 loss_2: 39.149888 and source_train_acc is 89.6367  time is 19500.680488
#    batch 450/ 586 loss_1: 41.177516 loss_2: 37.298812 and source_train_acc is 89.6528  time is 19614.971251
#    batch 500/ 586 loss_1: 41.908472 loss_2: 35.927100 and source_train_acc is 89.6469  time is 19729.632145
#    batch 550/ 586 loss_1: 42.593615 loss_2: 41.246604 and source_train_acc is 89.5597  time is 19843.968007
#  for main taks,loss source_test 1.6886943578720093,..... acc source_test 63.34475668265936
#  for main taks, loss target_test 2.7555463314056396 , .... acc target_test 34.30841236605493
#  sth was wrng with saving
# EPOCH 13:
#    batch 50/ 586 loss_1: 42.586577 loss_2: 42.036701 and source_train_acc is 89.9688  time is 20370.041936
#    batch 100/ 586 loss_1: 41.423462 loss_2: 38.027487 and source_train_acc is 90.1875  time is 20484.863949
#    batch 150/ 586 loss_1: 42.361482 loss_2: 42.921935 and source_train_acc is 90.1354  time is 20600.128345
#    batch 200/ 586 loss_1: 42.804798 loss_2: 42.762265 and source_train_acc is 89.9766  time is 20714.020451
#    batch 250/ 586 loss_1: 42.001519 loss_2: 46.343060 and source_train_acc is 89.9188  time is 20827.435305
#    batch 300/ 586 loss_1: 43.252077 loss_2: 43.765606 and source_train_acc is 89.8229  time is 20941.075907
#    batch 350/ 586 loss_1: 44.455480 loss_2: 47.848122 and source_train_acc is 89.6741  time is 21054.408847
#    batch 400/ 586 loss_1: 43.035814 loss_2: 40.033227 and source_train_acc is 89.6758  time is 21169.895780
#    batch 450/ 586 loss_1: 41.105949 loss_2: 38.412728 and source_train_acc is 89.7917  time is 21284.177181
#    batch 500/ 586 loss_1: 42.250482 loss_2: 38.058246 and source_train_acc is 89.8312  time is 21398.059440
#    batch 550/ 586 loss_1: 40.935363 loss_2: 35.276216 and source_train_acc is 89.8665  time is 21511.824380
#  for main taks,loss source_test 1.7892069816589355,..... acc source_test 60.86360520904729
#  for main taks, loss target_test 2.7950150966644287 , .... acc target_test 34.04975982263826
#  sth was wrng with saving
# EPOCH 14:
#    batch 50/ 586 loss_1: 40.839259 loss_2: 39.741967 and source_train_acc is 91.0312  time is 22040.918379
#    batch 100/ 586 loss_1: 41.416428 loss_2: 42.126381 and source_train_acc is 90.9219  time is 22154.600997
#    batch 150/ 586 loss_1: 40.767349 loss_2: 37.522308 and source_train_acc is 90.9896  time is 22267.631384
#    batch 200/ 586 loss_1: 41.312409 loss_2: 36.116719 and source_train_acc is 90.8047  time is 22381.428852
#    batch 250/ 586 loss_1: 40.785907 loss_2: 38.720997 and source_train_acc is 90.9188  time is 22495.521069
#    batch 300/ 586 loss_1: 41.412142 loss_2: 36.562186 and source_train_acc is 91.0000  time is 22610.187886
#    batch 350/ 586 loss_1: 40.230964 loss_2: 36.845296 and source_train_acc is 91.1518  time is 22724.370463
#    batch 400/ 586 loss_1: 40.989348 loss_2: 38.173864 and source_train_acc is 91.1641  time is 22839.094675
#    batch 450/ 586 loss_1: 41.764405 loss_2: 36.474362 and source_train_acc is 91.1458  time is 22953.713252
#    batch 500/ 586 loss_1: 41.090564 loss_2: 35.240802 and source_train_acc is 91.1531  time is 23068.823888
#    batch 550/ 586 loss_1: 43.312357 loss_2: 38.169691 and source_train_acc is 91.0398  time is 23184.003163
#  for main taks,loss source_test 2.0489678382873535,..... acc source_test 56.120630568882795
#  for main taks, loss target_test 2.8637657165527344 , .... acc target_test 29.7327257051361
#  sth was wrng with saving
# EPOCH 15:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-45ca5a6d65be> in <module>()
#      29
#      30
# ---> 31     avg_loss,acc= train_one_epoch(epoch_number)
#      32     source_test_loss.append(avg_loss)
#      33     source_test_accuracy.append(acc)
#
# <ipython-input-21-fbfdef91b11e> in train_one_epoch(epoch_index)
#      95
#      96
# ---> 97         optimizer1.step()
#      98         optimizer2.step()
#      99         optimizer3.step()
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     107                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     108                 with torch.autograd.profiler.record_function(profile_name):
# --> 109                     return func(*args, **kwargs)
#     110             return wrapper
#     111
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/sgd.py in step(self, closure)
#     154                 maximize=group['maximize'],
#     155                 has_sparse_grad=has_sparse_grad,
# --> 156                 foreach=group['foreach'])
#     157
#     158             # update momentum_buffers in state
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/sgd.py in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     204          nesterov=nesterov,
#     205          has_sparse_grad=has_sparse_grad,
# --> 206          maximize=maximize)
#     207
#     208 def _single_tensor_sgd(params: List[Tensor],
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/sgd.py in _single_tensor_sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     239
#     240         alpha = lr if maximize else -lr
# --> 241         param.add_(d_p, alpha=alpha)
#     242
#     243
#
# KeyboardInterrupt:

# %%
E= [i for i in range(len(target_test_loss))]

fig, (axs, ax2) = plt.subplots(2)
try:     
  t_target_loss = [target_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
except:
  t_target_loss = [target_test_loss[i]  for i  in range(len(target_test_loss))]
try:
      s_test_loss =  [source_test_loss[i].cpu()  for i  in range(len(target_test_loss))]
except:
      s_test_loss =  [source_test_loss[i]  for i  in range(len(target_test_loss))]

axs.plot(E, t_target_loss,label="target")
axs.plot(E,s_test_loss,label="source_test")

axs.set_xlabel('epoch')
axs.set_ylabel('loss')
axs.grid(True)

try:
  t_target_acc = [target_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
except:
    t_target_acc = [target_test_accuracy[i]  for i  in range(len(target_test_loss))]

try:
    s_test_acc =  [source_test_accuracy[i].cpu()  for i  in range(len(target_test_loss))]
except:
    s_test_acc =  [source_test_accuracy[i]  for i  in range(len(target_test_loss))]




ax2.plot(E, t_target_acc,label="target" )
ax2.plot(E,s_test_acc,label="source_test")


ax2.set_xlabel('epoch')
ax2.set_ylabel('accuracy')
ax2.grid(True)

fig.tight_layout()

plt.savefig('var22.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2a661b8a0c6c> in <module>()
#      13
#      14 axs.plot(E, t_target_loss,label="target")
# ---> 15 axs.plot(E,s_test_loss,label="source_test")
#      16
#      17 axs.set_xlabel('epoch')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     330         if len(tup) == 2:
#     331             x = _check_1d(tup[0])
# --> 332             y = _check_1d(tup[-1])
#     333         else:
#     334             x, y = index_of(tup[-1])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1324     '''
#    1325     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 1326         return np.atleast_1d(x)
#    1327     else:
#    1328         try:
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/shape_base.py in atleast_1d(*arys)
#      63     res = []
#      64     for ary in arys:
# ---> 65         ary = asanyarray(ary)
#      66         if ary.ndim == 0:
#      67             result = ary.reshape(1)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __array__(self, dtype)
#     755             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     756         if dtype is None:
# --> 757             return self.numpy()
#     758         else:
#     759             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
s_test_acc =  [source_test_accuracy[i]  for i  in range(1,len(source_test_accuracy),2)]

# %%
s_test_loss =  [float(source_test_loss[i])  for i  in range(1,len(source_test_loss),2)]
s_test_loss
# Out:
# [3.028740882873535,
#  2.321488618850708,
#  2.0702884197235107,
#  1.8214588165283203,
#  1.7129298448562622,
#  1.6454079151153564,
#  1.6659566164016724,
#  1.6873831748962402,
#  1.7130016088485718,
#  1.6856266260147095,
#  1.7384283542633057,
#  1.6886943578720093,
#  1.7892069816589355,
#  2.0489678382873535]

# %%
fig, (axs, ax2) = plt.subplots(2)
axs.plot(E, t_target_loss,label="target")
axs.plot(E,s_test_loss,label="source_test")

axs.set_xlabel('epoch')
axs.set_ylabel('loss')
axs.grid(True)






ax2.plot(E, t_target_acc,label="target" )
ax2.plot(E,s_test_acc,label="source_test")


ax2.set_xlabel('epoch')
ax2.set_ylabel('accuracy')
ax2.grid(True)

fig.tight_layout()

plt.savefig('var22.png')
